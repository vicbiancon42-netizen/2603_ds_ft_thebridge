# %% [markdown]
# # WEB SCRAPING WITH BEAUTIFUL SOUP

# %% [markdown]
# Web scraping is the process of extracting data from websites, and Python provides powerful libraries
# like Beautiful Soup 4 that make it easier to scrape and parse HTML and XML content.

# %%
# !pip install cloudscraper
# Out:
# Requirement already satisfied: cloudscraper in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.71)
# Requirement already satisfied: pyparsing>=2.4.7 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cloudscraper) (3.2.1)
# Requirement already satisfied: requests>=2.9.2 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cloudscraper) (2.32.4)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.9.2->cloudscraper) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.9.2->cloudscraper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.9.2->cloudscraper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Alberto Romero\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.9.2->cloudscraper) (2024.12.14)

# %% [markdown]
# Imports

# %%
import cloudscraper     # de momento funciona para que Cloudfare no nos bloquee
from bs4 import BeautifulSoup

scraper = cloudscraper.create_scraper()
html = scraper.get("https://mdcomputers.in").text

soup = BeautifulSoup(html, "html.parser")
print(soup.title)
# Out:
# <title>MDComputers.in | India’s Trusted Computer Hardware Store</title>

# %%
import requests
import pandas as pd

# %% [markdown]
# We are collecting data of computer peripherals from "MD Computers" site using Beautiful Soup 4

# %% [markdown]
# Enter the item which you wanted to collect information.

# %%
search_item = input("Which item do you want to search? ")

# %% [markdown]
# From the dynamic url of the website we are formatting the search result to the url.

# %%
url = f"https://mdcomputers.in/index.php?submit_search=&route=product%2Fsearch&&search={search_item}"

# %% [markdown]
# Parsing the html content of the page.

# %%
page_ = requests.get(url).text
doc = BeautifulSoup(page_, "html.parser")

# %%
url
# Out:
# 'https://mdcomputers.in/index.php?submit_search=&route=product%2Fsearch&&search=mouse'

# %%
doc
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <title>Attention Required! | Cloudflare</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" rel="stylesheet"/>
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
#     window.addEventListener('DOMContentLoaded', function () {
#       var cookieEl = document.getElementById('cookie-alert');
#       cookieEl.style.display = 'block';
#     })
#   }
# </script>
# <!--<![endif]-->
# </head>
# <body>
# <div id="cf-wrapper">
# <div class="cf-alert cf-alert-error cf-cookie-error" data-translate="enable_cookies" id="cookie-alert">Please enable cookies.</div>
# <div class="cf-error-details-wrapper" id="cf-error-details">
# <div class="cf-wrapper cf-header cf-error-overview">
# <h1 data-translate="block_headline">Sorry, you have been blocked</h1>
# <h2 class="cf-subheadline"><span data-translate="unable_to_access">You are unable to access</span> mdcomputers.in</h2>
# </div><!-- /.header -->
# <div class="cf-section cf-highlight">
# <div class="cf-wrapper">
# <div class="cf-screenshot-container cf-screenshot-full">
# <span class="cf-no-screenshot error"></span>
# </div>
# </div>
# </div><!-- /.captcha-container -->
# <div class="cf-section cf-wrapper">
# <div class="cf-columns two">
# <div class="cf-column">
# <h2 data-translate="blocked_why_headline">Why have I been blocked?</h2>
# <p data-translate="blocked_why_detail">This website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.</p>
# </div>
# <div class="cf-column">
# <h2 data-translate="blocked_resolve_headline">What can I do to resolve this?</h2>
# <p data-translate="blocked_resolve_detail">You can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.</p>
# </div>
# </div>
# </div><!-- /.section -->
# <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
# <p class="text-13">
# <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">9dcdda7bcfeca5f5</strong></span>
# <span class="cf-footer-separator sm:hidden">•</span>
# <span class="cf-footer-item hidden sm:block sm:mb-1" id="cf-footer-item-ip">
#         Your IP:
#         <button class="cf-footer-ip-reveal-btn" id="cf-footer-ip-reveal" type="button">Click to reveal</button>
# <span class="hidden" id="cf-footer-ip">81.44.114.120</span>
# <span class="cf-footer-separator sm:hidden">•</span>
# </span>
# <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">Cloudflare</a></span>
# </p>
# <script>(function(){function d(){var b=a.getElementById("cf-footer-item-ip"),c=a.getElementById("cf-footer-ip-reveal");b&&"classList"in b&&(b.classList.remove("hidden"),c.addEventListener("click",function(){c.classList.add("hidden");a.getElementById("cf-footer-ip").classList.remove("hidden")}))}var a=document;document.addEventListener&&a.addEventListener("DOMContentLoaded",d)})();</script>
# </div><!-- /.error-footer -->
# </div><!-- /#cf-error-details -->
# </div><!-- /#cf-wrapper -->
# <script>
#     window._cf_translation = {};
#
#
#   </script>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'9dcdda7bcfeca5f5',t:'MTc3MzYwMjE5NQ=='};var a=document.createElement('script');a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>

# %% [markdown]
# Finding the total number of result pages by filtering the html tags through class name

# %%
# como Cloudfare nos bloquearía si vamos por lo de antes, tomamos otro camino

html = scraper.get(url).text

soup = BeautifulSoup(html, "html.parser")
print(soup.title)
# Out:
# <title>Search - mouse</title>

# %%
#total_pages_x = doc.find(class_="col-sm-6 text-right")
total_pages_x = soup.find(class_="col-md-6 text-md-end mb-2")

# %%
total_pages_x
# Out:
# <div class="col-md-6 text-md-end mb-2">Showing 1 to 20 of 153 (8 Pages)</div>

# %%
total_pages_x.text.split("(")[1].split(" ")[0]
# Out:
# '8'

# %%
total_pages = int(total_pages_x.text.split("(")[1].split(" ")[0])

# %%
total_pages
# Out:
# 8

# %% [markdown]
# Total page results obtained for the search

# %%
total_pages
# Out:
# 8

# %% [markdown]
# We are going to gather the item's name , its link , its price (old and new) below

# %% [markdown]
# Creating empty lists for the data

# %%
link = []
item_name = []
new_price = []
old_price = []

# %% [markdown]
# Here is the main code which scrape the information from the html code

# %% [markdown]
# From this url , we can search for the products we need , through iterating the pages till the total page results we obtained earlier.

# %%
for page in range(1, total_pages + 1):
    url = f"https://mdcomputers.in/index.php?route=product/search&page={page}&search={search_item}"
    print(url)
    #page_ = requests.get(url).text
    page_ = scraper.get(url).text
    doc = BeautifulSoup(page_, "html.parser")
    
    items = doc.find_all(class_ = "product-wrapper") #Finding the main div tag for each product which holds the data. 
    print(items)
    for item in items:
        
        link.append((item.find("h3")).find("a")['href']) #finding the link through href attribute
        item_name.append(((item.find("h3")).find("a")).text) #finding the name in the h3 tag
        old_price.append(((item.find("span",class_ = "del")).find("span",class_ = "amount")).text[1:]) #finding the old price
        new_price.append(((item.find("span",class_ = "ins")).find("span",class_ = "amount")).text[1:])
        #try:
            #In some Products, there is no old price so in order to clear the error , finding the old price in this try block
        #    old_price.append(((item.find("div",class_ = "price")).find("span",class_ = "price-old")).string[1:])    
        #except:
        #    #For the products having no old price , it is declared as null
        #    old_price.append(None)
# Out:
# https://mdcomputers.in/index.php?route=product/search&page=1&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/dell-mouse-d-select-ds111"><div class="product-labels labels-rectangular"><span class="onsale product-label">-44%</span></div><img alt="Dell D SELECT DS111 Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/dell/ds111-black/ds111-black-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-225c09d7e78a3cb9a2b78e33-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('24175');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/dell-mouse-d-select-ds111"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-225c09d7e78a3cb9a2b78e33-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('24175');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-225c09d7e78a3cb9a2b78e33-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('24175');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/dell-mouse-d-select-ds111">Dell D SELECT DS111 Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹499</span></span></span><span class="ins"><span class="amount"> ₹280<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/fingers-megahit-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-29%</span></div><img alt="Fingers MegaHit Wired Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/fingers/megahit-black/megahit-black-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-225c09d7e78a3cb9a2b78e33-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('25207');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/fingers-megahit-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-225c09d7e78a3cb9a2b78e33-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('25207');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-225c09d7e78a3cb9a2b78e33-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('25207');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div> ...
# https://mdcomputers.in/index.php?route=product/search&page=2&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-gm105-pro-wireless-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-59%</span></div><img alt="Ant Esports GM105 Pro Wireless Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/ant-esports/gm105-pro/gm105-pro-image-00.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-ef658ffa42f80e2130732b5d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('25915');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-gm105-pro-wireless-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-ef658ffa42f80e2130732b5d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('25915');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-ef658ffa42f80e2130732b5d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('25915');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/ant-esports-gm105-pro-wireless-mouse">Ant Esports GM105 Pro Wireless Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,499</span></span></span><span class="ins"><span class="amount"> ₹610<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-gm320-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-78%</span></div><img alt="Ant Esports GM320 RGB Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/ant-esports/gm320-rgb/gm320-rgb-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-ef658ffa42f80e2130732b5d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('13274');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-gm320-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-ef658ffa42f80e2130732b5d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('13274');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-ef658ffa42f80e2130732b5d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('13274') ...
# https://mdcomputers.in/index.php?route=product/search&page=3&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/acer-wl-keyboard-mouse-combo-zc-a01si-2dp"><div class="product-labels labels-rectangular"><span class="onsale product-label">-50%</span></div><img alt="Acer ZC.A01SI.2DP Wireless Keyboard and Mouse Combo" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/combo-offer/acer/zc-a01si-2dp/zc-a01si-2dp-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-5dc59377ee8cd86176204e6f-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('25077');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/acer-wl-keyboard-mouse-combo-zc-a01si-2dp"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-5dc59377ee8cd86176204e6f-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('25077');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-5dc59377ee8cd86176204e6f-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('25077');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/acer-wl-keyboard-mouse-combo-zc-a01si-2dp">Acer ZC.A01SI.2DP Wireless Keyboard and Mouse Combo</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,999</span></span></span><span class="ins"><span class="amount"> ₹990<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/dawg-slay-25-gaming-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-67%</span></div><img alt="Dawg Slay 25 Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/dawg/slay-25-black/slay-25-black-image-main.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-5dc59377ee8cd86176204e6f-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('25852');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/dawg-slay-25-gaming-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-5dc59377ee8cd86176204e6f-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('25852');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-5dc59377ee8cd86176204e6f-="" onclick="if (!window.__cfRLUnblockHandlers) return false; ...
# https://mdcomputers.in/index.php?route=product/search&page=4&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/dell-km3322w-wl-keyboard-mouse-combo"><div class="product-labels labels-rectangular"><span class="onsale product-label">-44%</span></div><img alt="Dell KM3322W Keyboard and Mouse Wireless Combo" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/keyboard-mouse-combo/dell/km3322w/km3322w-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-43f5014e1df55d18e529dd31-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('17474');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/dell-km3322w-wl-keyboard-mouse-combo"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-43f5014e1df55d18e529dd31-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('17474');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-43f5014e1df55d18e529dd31-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('17474');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/dell-km3322w-wl-keyboard-mouse-combo">Dell KM3322W Keyboard and Mouse Wireless Combo</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹2,499</span></span></span><span class="ins"><span class="amount"> ₹1,400<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/avermedia-large-elena-chan-mouse-pad"><div class="product-labels labels-rectangular"><span class="onsale product-label">-28%</span></div><img alt="AVerMedia Elena Chan Mouse Pad (Large)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse%20pad/avermedia/elena_chan/elena_chan_img_main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-43f5014e1df55d18e529dd31-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('11128');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/avermedia-large-elena-chan-mouse-pad"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-43f5014e1df55d18e529dd31-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('11128');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-43f5014e1df55d18e529dd31-="" onclick="if (!window.__cfRLUnblockHandle ...
# https://mdcomputers.in/index.php?route=product/search&page=5&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/asus-tuf-gaming-m3-gen-ii-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-41%</span></div><img alt="Asus TUF Gaming M3 Gen II Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/asus/tuf-gaming-m3-gen-ii/tuf-gaming-m3-gen-ii-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-8f8a7cac9892ab133d1fc251-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('21070');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/asus-tuf-gaming-m3-gen-ii-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-8f8a7cac9892ab133d1fc251-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('21070');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-8f8a7cac9892ab133d1fc251-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('21070');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/asus-tuf-gaming-m3-gen-ii-mouse">Asus TUF Gaming M3 Gen II Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹3,499</span></span></span><span class="ins"><span class="amount"> ₹2,050<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/aula-sc550-dual-mode-wireless-gaming-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-47%</span></div><img alt="Aula SC550 Dual Mode RGB Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/aula/sc550-black/sc550-black-image-main.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-8f8a7cac9892ab133d1fc251-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('25893');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/aula-sc550-dual-mode-wireless-gaming-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-8f8a7cac9892ab133d1fc251-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('25893');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-8f8a7cac9892ab133d1fc251-="" onclick="if (!window.__cfRLUnblockHandlers) return fals ...
# https://mdcomputers.in/index.php?route=product/search&page=6&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-orochi-v2-white-wireless-mouse-rz01-03730400-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-54%</span></div><img alt="Razer Orochi V2 Wireless Gaming Mouse (White)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/razer/rz01-03730400-r3a1/rz01-03730400-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-15868d126b58944b7720cec1-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('15112');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-orochi-v2-white-wireless-mouse-rz01-03730400-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-15868d126b58944b7720cec1-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('15112');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-15868d126b58944b7720cec1-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('15112');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-orochi-v2-white-wireless-mouse-rz01-03730400-r3a1">Razer Orochi V2 Wireless Gaming Mouse (White)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹8,999</span></span></span><span class="ins"><span class="amount"> ₹4,100<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-orochi-v2-wireless-mouse-rz01-03730100-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-54%</span></div><img alt="Razer Orochi V2 Wireless Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/razer/rz01-03730100-r3a1/rz01-03730100-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-15868d126b58944b7720cec1-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('15113');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-orochi-v2-wireless-mouse-rz01-03730100-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-15868d126b58944b7720cec1-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('15113');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishl ...
# https://mdcomputers.in/index.php?route=product/search&page=7&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-naga-v2-hyperspeed-wireless-mouse-rz01-03600100-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-49%</span></div><img alt="Razer Naga V2 HyperSpeed Wireless Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/razer/rz01-03600100-r3a1/rz01-03600100-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-784120dbf38ef10319fae736-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('20635');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-naga-v2-hyperspeed-wireless-mouse-rz01-03600100-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-784120dbf38ef10319fae736-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('20635');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-784120dbf38ef10319fae736-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('20635');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-naga-v2-hyperspeed-wireless-mouse-rz01-03600100-r3a1">Razer Naga V2 HyperSpeed Wireless Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹13,499</span></span></span><span class="ins"><span class="amount"> ₹6,900<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-mouse-dock-pro-rz81-01990100-b3m1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-44%</span></div><img alt="Razer Mouse Dock Pro (Magnetic Wireless Charging Dock for Razer Basillisk V3 Pro, Chroma RGB Underglow)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/accessories/mouse-accesories/razer/rz81-01990100-b3m1/rz81-01990100-b3m1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-784120dbf38ef10319fae736-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('18856');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-mouse-dock-pro-rz81-01990100-b3m1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-784120dbf38ef10319fae736-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('18856');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button>< ...
# https://mdcomputers.in/index.php?route=product/search&page=8&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-g-pro-x-superlight-2-dex-wl-pink-mouse-910-007375"><div class="product-labels labels-rectangular"><span class="onsale product-label">-32%</span></div><img alt="Logitech G Pro X Superlight 2 DEX Pink Wireless Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/logitech/910-007375/910-007375-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-0f30d0be9927e475dcb19e7d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('24231');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-g-pro-x-superlight-2-dex-wl-pink-mouse-910-007375"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-0f30d0be9927e475dcb19e7d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('24231');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button data-cf-modified-0f30d0be9927e475dcb19e7d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; wishlist.add('24231');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/logitech-g-pro-x-superlight-2-dex-wl-pink-mouse-910-007375">Logitech G Pro X Superlight 2 DEX Pink Wireless Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹17,995</span></span></span><span class="ins"><span class="amount"> ₹12,238<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-g502-x-plus-lightspeed-white-wireless-mouse-910-006173"><div class="product-labels labels-rectangular"><span class="onsale product-label">-17%</span></div><img alt="Logitech G502 X Plus Lightspeed RGB Wireless Gaming Mouse (White)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/image/catalog/mouse/logitech/910-006173/910-006173-imagr-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" data-cf-modified-0f30d0be9927e475dcb19e7d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; cart.add('18672');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-g502-x-plus-lightspeed-white-wireless-mouse-910-006173"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button data-cf-modified-0f30d0be9927e475dcb19e7d-="" onclick="if (!window.__cfRLUnblockHandlers) return false; compare.add('18672');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishl ...

# %%
len(item_name)
# Out:
# 153

# %%
len(link)
# Out:
# 153

# %%
sorted(item_name)
# Out:
# ['ANT ESPORTS KM550 Keyboard and Mouse Combo',
#  'ANT ESPORTS Thunder 10 RGB Keyboard and Mouse Combo with Brown Switches',
#  'ASUS CW101 Keyboard and Mouse Combo',
#  'AVerMedia Elena Chan Mouse Pad (Large)',
#  'Acer Wireless White Keyboard and Mouse Combo',
#  'Acer Wireless White and Green Mouse',
#  'Acer ZC.A01SI.2DP Wireless Keyboard and Mouse Combo',
#  'Adata XPG Battleground L Gaming Mouse Pad (Large)',
#  'Adata XPG Infarex M20 RGB',
#  'Adata XPG Slingshot RGB Gaming Mouse',
#  'Ant Esports GM105 Pro Wireless Gaming Mouse',
#  'Ant Esports GM320 RGB Gaming Mouse (Black)',
#  'Ant Esports GM340 RGB Gaming Mouse',
#  'Ant Esports GM610 RGB Gaming Mouse',
#  'Ant Esports GM700 Wireless Gaming Mouse (Black)',
#  'Ant Esports KM1600 Gaming Keyboard and Mouse Combo',
#  'Ant Esports KM1610 Gaming Keyboard and Mouse Combo',
#  'Ant Esports KM1650 Pro Gaming Keyboard and Mouse Combo (Black)',
#  'Ant Esports KM500 Gaming Keyboard and Mouse Combo',
#  'Ant Esports KM500W Gaming Keyboard And Mouse Combo',
#  'Ant Esports KM500W Pro Wireless Gaming Keyboard Mouse Combo',
#  'Ant Esports KM540 Keyboard Mouse Combo',
#  'Ant Esports KM550 Pro Wireless Keyboard and Mouse Combo',
#  'Ant Esports MP 290 Gaming Mouse Pad (Large)',
#  'Ant Esports MP320C Control Gaming Mouse Pad (Large Extended)',
#  'Ant Esports MP320S Speed Gaming Mouse Pad (Large Extended)',
#  'Ant Esports MP400R RGB XL Gaming Mouse Pad (Extra Large)',
#  'Asus MW103 Wireless Mouse',
#  'Asus Marshmallow MD100 Lilac Mist Purple Wireless Mouse',
#  'Asus ROG Balteus RGB Medium Gaming Mouse Pad',
#  'Asus ROG Gladius III Core Gaming Mouse',
#  'Asus ROG Hone Ace Aim Lab Edition Large Mouse Pad',
#  'Asus ROG Moonstone Ace L Mouse Pad',
#  'Asus TUF Gaming M3 Gen II Gaming Mouse',
#  'Aula F3061 Gaming Keyboard and Mouse Combo',
#  'Aula F815 RGB Gaming Mouse',
#  'Aula S12 Pro RGB Gaming Mouse',
#  'Aula S31 Gaming Mouse',
#  'Aula SC550 Dual Mode RGB Gaming Mouse',
#  'Aula SC800 Tri-Mode Wireless White Gaming Mouse',
#  'Aula SC800 Wireless Gaming Mouse',
#  'Aula SC900 Pro Tri-Mode Wireless White Gaming Mouse',
#  'Aula SC900Pro Tri-Mode Wireless Gaming Mouse',
#  'Cooler Master MM311 Wireless Gaming Mouse',
#  'Cooler Master MP511 Mouse Pad, Large Extended',
#  'Corsair Katar Pro Ultra-Light Gaming Mouse',
#  'Cybeart Mortal Kombat Gaming Mouse Pad (Large)',
#  'Cybeart Mortal Kombat Gaming Mouse Pad (XXL)',
#  'Dawg Slay 25 Gaming Mouse',
#  'Dawg Slay 25 Red Gaming Mouse',
#  'Dawg Slay 50 Wireless Gaming Mouse',
#  'Dell D SELECT DS111 Mouse',
#  'Dell D SELECT DS320 Wireless Mouse',
#  'Dell KM3322W Keyboard and Mouse Wireless Combo',
#  'Dell MS116 Wired Mouse',
#  'Dell WM118 Wireless Mouse',
#  'EVM EnGrip EWLM-360 Wireless Silver PC Mouse',
#  'Fingers BlazingHit RGB Mouse',
#  'Fingers Cheesy Keyboard and Mouse Combo',
#  'Fingers CuteClicks WB4 Wireless White Mouse',
#  'Fingers Duo-Recharge Keyboard and Mouse Combo',
#  'Fingers Magnifico Duo Keyboard and Mouse Combo (Black)',
#  'Fingers MegaHit Wired Mouse',
#  'Galax Xanova Deimos Luxe-R RGB Gaming Mouse Pad',
#  'Gamdias Aura GS 2 Gaming Mouse (Black)',
#  'Gamdias Aura GS4 Gaming Mouse (Black)',
#  'Glorious Model D RGB Wireless Gaming Mouse (Matte Black)',
#  'Glorious PC Gaming Race Cleaning Kit for Keyboard and Mouse',
#  'HP 110 Wireless Mouse',
#  'HP KM160 Keyboard and Mouse Combo',
#  'HP KM260 Wireless Keyboard and Mouse Combo',
#  'HP M120 Wireless Mouse',
#  'HP M310 Dual Mode Wireless Mouse',
#  'HyperX Pulsefire Core RGB Gaming Mouse (Black)',
#  'HyperX Pulsefire Haste 2 Wireless RGB Gaming Mouse',
#  'HyperX Pulsefire Mat 2XL Gaming Mouse Pad',
#  'Lenovo 120 Wired Mouse (Black)',
#  'Lenovo 130 Wireless Mouse',
#  'Lenovo 160 Wired Keyboard and Mouse Combo',
#  'Lenovo 600 Bluetooth Silent Iron Grey Wireless Mouse',
#  'Lenovo M210 RGB Gaming Mouse',
#  'Logitech G Pro 2 Lightspeed Wireless Gaming Mouse',
#  'Logitech G Pro Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX Pink Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX White Wireless Gaming Mouse',
#  'Logitech G203 Lightsync RGB Gaming Mouse',
#  'Logitech G203 Lightsync RGB Gaming Mouse (White)',
#  'Logitech G309 Lightspeed Wireless Gaming Mouse (Black)',
#  'Logitech G309 Lightspeed Wireless Gaming Mouse (White)',
#  'Logitech G402 Hyperion Fury Gaming Mouse',
#  'Logitech G502 HERO RGB Gaming Mouse (Black)',
#  'Logitech G502 X Lightspeed Wireless Gaming Mouse (Black)',
#  'Logitech G502 X Plus Lightspeed RGB Wireless Gaming Mouse (Black)',
#  'Logitech G502 X Plus Lightspeed RGB Wireless Gaming Mouse (White)',
#  'Logitech G502 X White Gaming Mouse',
#  'Logitech G840 XL Black Gaming Mouse Pad (Extra Large)',
#  'Logitech M170 Grey And Black Wireless Mouse',
#  'Logitech M185 Grey Wireless Mouse',
#  'Logitech M90 Mouse (Black)',
#  'Logitech MK120 Keyboard and Mouse Combo',
#  'Logitech MK200 Keyboard and Mouse Combo',
#  'Logitech MK220 Wireless Combo',
#  'Logitech MK240 Wireless Keyboard and Mouse Combo, White-Red',
#  'Logitech MK275 Wireless Keyboard and Mouse Combo',
#  'Logitech MK470 Slim Wireless Keyboard and Mouse Combo, Off-White',
#  'Logitech MX Anywhere 3S Wireless Mouse (Graphite)',
#  'Logitech MX Master 3S Wireless Mouse (Graphite)',
#  'Logitech MX Master 4 Graphite Wireless Mouse',
#  'Rapoo V280 Gaming Mouse (Black)',
#  'Rapoo VT200 Gaming Mouse',
#  'Rapoo VT30 Gaming Mouse (Black)',
#  'Rapoo VT300 Gaming Mouse',
#  'Rapoo VT900 Gaming Mouse',
#  'Razer Basilisk Mobile Wireless Gaming Mouse',
#  'Razer Basilisk V3 35k Gaming Mouse (Black)',
#  'Razer Basilisk V3 Pro 35K Phantom Green Gaming Mouse',
#  'Razer Basilisk V3 Pro 35k Gaming Mouse',
#  'Razer Basilisk V3 Pro 35k White Gaming Mouse',
#  'Razer Basilisk V3 Pro White Wireless Gaming Mouse',
#  'Razer Basilisk V3 X HyperSpeed Wireless Gaming Mouse',
#  'Razer Bungee V3 Chroma Mouse Cable Management',
#  'Razer Cobra HyperSpeed Wireless Gaming Mouse',
#  'Razer Cobra Minecraft Edition RGB Gaming Mouse',
#  'Razer Cobra Pro Wireless Gaming Mouse (Black)',
#  'Razer Cobra Pro Wireless Gaming Mouse (White)',
#  'Razer Cobra RGB Black Gaming Mouse',
#  'Razer DeathAdder V3 Pro Wireless Gaming Mouse (White)',
#  'Razer DeathAdder V4 Pro White Wireless Gaming Mouse',
#  'Razer DeathAdder V4 Pro Wireless Gaming Mouse',
#  'Razer Deathadder Essential White Wired Gaming Mouse',
#  'Razer GOLIATHUS MOBILE Small',
#  'Razer Game On Bundle of Mouse, Mouse Cable Holder and Headset',
#  'Razer Gigantus V2 Gaming Mouse Mat (3XL)',
#  'Razer Gigantus V2 Soft Gaming Minecraft Edition Medium Mouse Pad',
#  'Razer Goliathus Mobile Stealth Edition Soft Gaming Mouse Pad',
#  'Razer Mouse Dock Pro (Magnetic Wireless Charging Dock for Razer Basillisk V3 Pro, Chroma RGB Underglow)',
#  'Razer Naga V2 HyperSpeed Wireless Gaming Mouse (Black)',
#  'Razer Naga V2 Pro Wireless Gaming Mouse (Black)',
#  'Razer Orochi V2 Wireless Gaming Mouse (Black)',
#  'Razer Orochi V2 Wireless Gaming Mouse (Quartz)',
#  'Razer Orochi V2 Wireless Gaming Mouse (White)',
#  'Razer Pro Click Mini White Wireless Mouse',
#  'Razer Pro Click V2 Vertical Wireless Mouse',
#  'Razer Pro Click V2 Wireless RGB Gaming Mouse',
#  'Razer Sphex V3 Ultra Thin Gaming Mouse Pad (Large)',
#  'Razer Strider Extended Extra Large Gaming Mouse Pad',
#  'Razer Strider Gaming Mouse Pad (Large)',
#  'Razer Viper V3 Pro Counter Strike 2 Edition Wireless Mouse',
#  'Razer Viper V3 Pro Sentinels Edition Wireless Mouse',
#  'Razer Viper V3 Pro White Wireless Gaming Mouse',
#  'Razer Viper V3 Pro Wireless Gaming Mouse (Black)',
#  'Razer Wireless Mouse Charging Dock',
#  'Thermaltake Argent M5 Gaming Mouse (Black)']

# %% [markdown]
# Converting the lists to Dictionary and then to DataFrame.

# %%
my_dict = {'item_name': item_name , 'link': link , 'new_price': new_price , 'old_price': old_price}

# %%
len(old_price)
# Out:
# 153

# %%
for key in my_dict:
    print(len(my_dict[key]))
# Out:
# 153
# 153
# 153
# 153

# %%
df = pd.DataFrame(my_dict)

# %% [markdown]
# Here is our DataFrame with required data

# %%
df
# Out:
#                                              item_name  \
# 0                            Dell D SELECT DS111 Mouse
# 1                          Fingers MegaHit Wired Mouse
# 2                         Fingers BlazingHit RGB Mouse
# 3          Ant Esports MP 290 Gaming Mouse Pad (Large)
# 4                       Lenovo 120 Wired Mouse (Black)
# ..                                                 ...
# 148  Razer DeathAdder V4 Pro White Wireless Gaming ...
# 149  Razer Basilisk V3 Pro 35K Phantom Green Gaming...
# 150    Razer Naga V2 Pro Wireless Gaming Mouse (Black)
# 151  Razer Viper V3 Pro Sentinels Edition Wireless ...
# 152  Razer Viper V3 Pro Counter Strike 2 Edition Wi...
#
#                                                   link new_price old_price
# 0    https://mdcomputers.in/product/dell-mouse-d-se...      ₹280       499
# 1    https://mdcomputers.in/product/fingers-megahit...      ₹300       425
# 2    https://mdcomputers.in/product/fingers-blazing...      ₹310       495
# 3    https://mdcomputers.in/product/ant-esports-mp-...      ₹315       599
# 4      https://mdcomputers.in/product/lenovo-120-mouse      ₹325       490
# ..                                                 ...       ...       ...
# 148  https://mdcomputers.in/product/razer-deathadde...   ₹16,050    31,099
# 149  https://mdcomputers.in/product/razer-basilisk-...   ₹16,500    27,999
# 150  https://mdcomputers.in/product/razer-wireless-...   ₹17,100    31,999
# 151  https://mdcomputers.in/product/razer-viper-v3-...   ₹17,100    28,999
# 152  https://mdcomputers.in/product/razer-viper-v3-...   ₹17,150    29,999
#
# [153 rows x 4 columns]

# %% [markdown]
# Converting the Dataframe to excel document with file name as the item we searched

# %%
df.to_excel(f'{search_item}_list_mdcomputers.xlsx')

# %% [markdown]
# Finally we scraped the data from website(MD Computers) successfully through BeautifulSoup4.
