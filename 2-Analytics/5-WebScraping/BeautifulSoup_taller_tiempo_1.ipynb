# %% [markdown]
# # Beautiful Soup Tutorial

# %% [markdown]
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!

# %% [markdown]
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página en la cual se encuentran alquileres de pisos en Barcelona

# %% [markdown]
# ### Conoce a tus nuevos mejores amigos:

# %% [markdown]
# - Beautiful Soup
# - Requests

# %%
# %pip install beautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# "c:\Users\Alberto" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parser, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib

# %% [markdown]
# Vamos a utilizar el lxml ya que es el mas rápido

# %%
# %pip install lxml
# Out:
# Note: you may need to restart the kernel to use updated packages.
# "c:\Users\Alberto" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web.

# %%
# %pip install requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# "c:\Users\Alberto" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# Ahora asi manos a la obra..

# %% [markdown]
# ## Mi primer scraping

# %% [markdown]
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
city=str(input("Introduzca la ciudad:"))
url = "https://www.weather-forecast.com/locations/"+city+"/forecasts/latest"

# %%
url
# Out:
# 'https://www.weather-forecast.com/locations/Vigo/forecasts/latest'

# %%
response=requests.get(url)

# %%
response.status_code # ¡conexión correcta!
# Out:
# 200

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %%
type(html)
# Out:
# bytes

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'<!DOCTYPE html><html lang="en"><head><link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect" /><link href="https://www.googletagmanager.com/" rel="dns-prefetch" /><meta charset="utf-8" /><meta content="width=device-width" name="viewport" /><title>Vigo Weather Forecast</title><meta name="description" content="12 day Vigo Weather Forecast. Live Weather Warnings, hourly weather updates. Accurate Vigo weather today, forecast for sun, rain, wind and temperature." /><meta name="keywords" content="Vigo weather forecast,12 day weather forecast,Vigo weather,weather today,hourly weather,Vigo climate,weather warning,rain,snow,wind,humidity,UV index,temperature,www.weather-forecast.com" /><meta content="460425463983282" property="fb:app_id" /><link rel="stylesheet" media="all" href="https://www.weather-forecast.com/assets/application-a82b6935c112359c4a18a49dbd42a9b13cfe22f15108cd884b58f91427ccaed1.css" /><link rel="stylesheet" media="screen" href="https://www.weather-forecast.com/packs/css/application-209d4ff1.css" /><link rel="stylesheet" media="print" href="https://www.weather-forecast.com/assets/print-e673d5458c4517ead933e17820dcf873699d55751720ce6cbfaf6036aaf48319.css" /><!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->\n<script type="text/javascript" async=true>\n  (function() {\n    var host = \'weather-forecast.com\';\n    var element = document.createElement(\'script\');\n    var firstScript = document.getElementsByTagName(\'script\')[0];\n    var url = \'https://cmp.inmobi.com\'\n      .concat(\'/choice/\', \'ZUS0dMZYEZF3f\', \'/\', host, \'/choice.js?tag_version=V3\');\n    var uspTries = 0;\n    var uspTriesLimit = 3;\n    element.async = true;\n    element.type = \'text/javascript\';\n    element.src = url;\n\n    firstScript.parentNode.insertBefore(element, firstScript);\n\n    function makeStub() {\n      var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n      var queue = [];\n      var win = window;\n      var cmpFrame;\n\n      function addFrame() {\n        var doc = win.document;\n        var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\n        if (!otherCMP) {\n          if (doc.body) {\n            var iframe = doc.createElement(\'iframe\');\n\n            iframe.style.cssText = \'display:none\';\n            iframe.name = TCF_LOCATOR_NAME;\n            doc.body.appendChild(iframe);\n          } else {\n            setTimeout(addFrame, 5);\n          }\n        }\n        return !otherCMP;\n      }\n\n      function tcfAPIHandler() {\n        var gdprApplies;\n        var args = arguments;\n\n        if (!args.length) {\n          return queue;\n        } else if (args[0] === \'setGdprApplies\') {\n          if (\n            args.length > 3 &&\n            args[2] === 2 &&\n            typeof args[3] === \'boolean\'\n          ) {\n            gdprApplies = args[3];\n            if (typeof args[2] === \'function\') {\n              args[2](\'set\', true);\n            }\n          }\n        } else if (args[0] === \'ping\') {\n          var retr = {\n            gdprApplies: gdprApplies,\n            cmpLoaded: false,\n            cmpStatus: \'stub\'\n          };\n\n          if (typeof args[2] === \'function\') {\n            args[2](retr);\n          }\n        } else {\n          if(args[0] === \'init\' && typeof args[3] === \'object\') {\n            args[3] = Object.assign(args[3], { tag_version: \'V3\' });\n          }\n          queue.push(args);\n        }\n      }\n\n      function postMessageEventHandler(event) {\n        var msgIsString = typeof event.data === \'string\';\n        var json = {};\n\n        try {\n          if (msgIsString) {\n            json = JSON.parse(event.data);\n          } else {\n            json = event.data;\n          }\n        } catch (ignore) {}\n\n        var payload = json.__tcfapiCall;\n\n        if (payload) {\n          window.__tcfapi(\n            payload.command,\n            payload.version,\n            function(retValue, success ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de la previsión metereológica, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "lxml")

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer).
#
# El segundo parámetro ('lxml'), es el parser que se usa en html

# %% [markdown]
# Ahora vamos a ver el cambio

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><link crossorigin="" href="https://www.googletagmanager.com/" rel="preconnect"/><link href="https://www.googletagmanager.com/" rel="dns-prefetch"/><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><title>Vigo Weather Forecast</title><meta content="12 day Vigo Weather Forecast. Live Weather Warnings, hourly weather updates. Accurate Vigo weather today, forecast for sun, rain, wind and temperature." name="description"/><meta content="Vigo weather forecast,12 day weather forecast,Vigo weather,weather today,hourly weather,Vigo climate,weather warning,rain,snow,wind,humidity,UV index,temperature,www.weather-forecast.com" name="keywords"/><meta content="460425463983282" property="fb:app_id"/><link href="https://www.weather-forecast.com/assets/application-a82b6935c112359c4a18a49dbd42a9b13cfe22f15108cd884b58f91427ccaed1.css" media="all" rel="stylesheet"/><link href="https://www.weather-forecast.com/packs/css/application-209d4ff1.css" media="screen" rel="stylesheet"/><link href="https://www.weather-forecast.com/assets/print-e673d5458c4517ead933e17820dcf873699d55751720ce6cbfaf6036aaf48319.css" media="print" rel="stylesheet"/><!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script async="true" type="text/javascript">
#   (function() {
#     var host = 'weather-forecast.com';
#     var element = document.createElement('script');
#     var firstScript = document.getElementsByTagName('script')[0];
#     var url = 'https://cmp.inmobi.com'
#       .concat('/choice/', 'ZUS0dMZYEZF3f', '/', host, '/choice.js?tag_version=V3');
#     var uspTries = 0;
#     var uspTriesLimit = 3;
#     element.async = true;
#     element.type = 'text/javascript';
#     element.src = url;
#
#     firstScript.parentNode.insertBefore(element, firstScript);
#
#     function makeStub() {
#       var TCF_LOCATOR_NAME = '__tcfapiLocator';
#       var queue = [];
#       var win = window;
#       var cmpFrame;
#
#       function addFrame() {
#         var doc = win.document;
#         var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#         if (!otherCMP) {
#           if (doc.body) {
#             var iframe = doc.createElement('iframe');
#
#             iframe.style.cssText = 'display:none';
#             iframe.name = TCF_LOCATOR_NAME;
#             doc.body.appendChild(iframe);
#           } else {
#             setTimeout(addFrame, 5);
#           }
#         }
#         return !otherCMP;
#       }
#
#       function tcfAPIHandler() {
#         var gdprApplies;
#         var args = arguments;
#
#         if (!args.length) {
#           return queue;
#         } else if (args[0] === 'setGdprApplies') {
#           if (
#             args.length > 3 &&
#             args[2] === 2 &&
#             typeof args[3] === 'boolean'
#           ) {
#             gdprApplies = args[3];
#             if (typeof args[2] === 'function') {
#               args[2]('set', true);
#             }
#           }
#         } else if (args[0] === 'ping') {
#           var retr = {
#             gdprApplies: gdprApplies,
#             cmpLoaded: false,
#             cmpStatus: 'stub'
#           };
#
#           if (typeof args[2] === 'function') {
#             args[2](retr);
#           }
#         } else {
#           if(args[0] === 'init' && typeof args[3] === 'object') {
#             args[3] = Object.assign(args[3], { tag_version: 'V3' });
#           }
#           queue.push(args);
#         }
#       }
#
#       function postMessageEventHandler(event) {
#         var msgIsString = typeof event.data === 'string';
#         var json = {};
#
#         try {
#           if (msgIsString) {
#             json = JSON.parse(event.data);
#           } else {
#             json = event.data;
#           }
#         } catch (ignore) {}
#
#         var payload = json.__tcfapiCall;
#
#         if (payload) {
#           window.__tcfapi(
#             payload.command,
#             payload.version,
#             function(retValue, success) {
#               var returnMsg = {
#                 __tcfapiReturn: {
#                   returnValue: retValue,
#                   success: success,
#                   callId: payload.callId
#                 }
#               };
#               if (msgIsString) {
#                 returnMsg = JSON.stringify(returnMsg);
#               }
#               if (event && event.source && event.source.postMessage) {
#                 event.source.postMessage(returnMsg, '*');
#               }
#             },
#             payload.parameter
#           );
#         }
#       }
#
#       while (win) {
#         try {
#           if (win.frames[TCF_LOCATOR_NAME]) {
#             cmpFrame = win;
#             break;
#           }
#         } catch (ignore) {}
#
#         if (win === window.top) {
#           break;
#         }
#         win = win.parent;
#       }
#       if (!cmpFrame) {
#         addFrame();
#         win.__tcfapi = tcfAPIHandler;
#         win.addEventListener('message', postMessageEventHandler, false);
#       }
#     };
#
#     makeStub();
#
#     function makeGppStub() {
#       const CMP_ID = 10;
#       const SUPPORTED_APIS = [
#         '2:tcfeuv2',
#         '6:uspv1',
#         '7:usnatv1',
#         '8:usca',
#         '9:usvav1',
#         '10:uscov1',
#         '11:usutv1',
#         '12:usctv1'
#       ];
#
#       window.__gpp_addFrame = function (n) {
#         if (!window.frames[n]) {
#           if (document.body) {
#             var i = document.createElement("iframe");
#             i.style.cssText = "display:none";
#             i.name = n;
#             document.body.appendChild(i);
#           } else {
#             window.setTimeout(window.__gpp_addFrame, 10, n);
#           }
#         }
#       };
#       window.__gpp_stub = function () {
#         var b = arguments;
#         __gpp.queue = __gpp.queue || [];
#         __gpp.events = __gpp.events || [];
#
#         if (!b.length || (b.length == 1 && b[0] == "queue")) {
#           return __gpp.queue;
#         }
#
#         if (b.length == 1 && b[0] == "events") {
#           return __gpp.events;
#         }
#
#         var cmd = b[0];
#         var clb = b.length > 1 ? b[1] : null;
#         var par = b.length > 2 ? b[2] : null;
#         if (cmd === "ping") {
#           clb(
#             {
#               gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#               cmpStatus: "stub", // possible values: stub, loading, loaded, error
#               cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#               signalStatus: "not ready", // possible values: not ready, ready
#               supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#               cmpId: CMP_ID, // IAB assigned CMP ID, may be 0 during stub/loading
#               sectionList: [],
#               applicableSections: [-1],
#               gppString: "",
#               parsedSections: {},
#             },
#             true
#           );
#         } else if (cmd === "addEventListener") {
#           if (!("lastId" in __gpp)) {
#             __gpp.lastId = 0;
#           }
#           __gpp.lastId++;
#           var lnr = __gpp.lastId;
#           __gpp.events.push({
#             id: lnr,
#             callback: clb,
#             parameter: par,
#           });
#           clb(
#             {
#               eventName: "listenerRegistered",
#               listenerId: lnr, // Registered ID of the listener
#               data: true, // positive signal
#               pingData: {
#                 gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#                 cmpStatus: "stub", // possible values: stub, loading, loaded, error
#                 cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#                 signalStatus: "not ready", // possible values: not ready, ready
#                 supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#                 cmpId: CMP_ID, // list of supported APIs
#                 sectionList: [],
#                 applicableSections: [-1],
#                 gppString: "",
#                 parsedSections: {},
#               },
#             },
#             true
#           );
#         } else if (cmd === "removeEventListener") {
#           var success = false;
#           for (var i = 0; i < __gpp.events.length; i++) {
#             if (__gpp.events[i].id == par) {
#               __gpp.events.splice(i, 1);
#               success = true;
#               break;
#             }
#           }
#           clb(
#             {
#               eventName: "listenerRemoved",
#               listenerId: par, // Registered ID of the listener
#               data: success, // status info
#               pingData: {
#                 gppVersion: "1.1", // must be “Version.Subversion”, current: “1.1”
#                 cmpStatus: "stub", // possible values: stub, loading, loaded, error
#                 cmpDisplayStatus: "hidden", // possible values: hidden, visible, disabled
#                 signalStatus: "not ready", // possible values: not ready, ready
#                 supportedAPIs: SUPPORTED_APIS, // list of supported APIs
#                 cmpId: CMP_ID, // CMP ID
#                 sectionList: [],
#                 applicableSections: [-1],
#                 gppString: "",
#                 parsedSections: {},
#               },
#             },
#             true
#           );
#         } else if (cmd === "hasSection") {
#           clb(false, true);
#         } else if (cmd === "getSection" || cmd === "getField") {
#           clb(null, true);
#         }
#         //queue all other commands
#         else {
#           __gpp.queue.push([].slice.apply(b));
#         }
#       };
#       window.__gpp_msghandler = function (event) {
#         var msgIsString = typeof event.data === "string";
#         try {
#           var json = msgIsString ? JSON.parse(event.data) : event.data;
#         } catch (e) {
#           var json = null;
#         }
#         if (typeof json === "object" && json !== null && "__gppCall" in json) {
#           var i = json.__gppCall;
#           window.__gpp(
#             i.command,
#             function (retValue, success) {
#               var returnMsg = {
#                 __gppReturn: {
#                   returnValue: retValue,
#                   success: success,
#                   callId: i.callId,
#                 },
#               };
#               event.source.postMessage(msgIsString ? JSON.stringify(returnMsg) : returnMsg, "*");
#             },
#             "parameter" in i ? i.parameter : null,
#             "version" in i ? i.version : "1.1"
#           );
#         }
#       };
#       if (!("__gpp" in window) || typeof window.__gpp !== "function") {
#         window.__gpp = window.__gpp_stub;
#         window.addEventListener("message", window.__gpp_msghandler, false);
#         window.__gpp_addFrame("__gppLocator");
#       }
#     };
#
#     makeGppStub();
#
#     var uspStubFunction = function() {
#       var arg = arguments;
#       if (typeof window.__uspapi !== uspStubFunction) {
#         setTimeout(function() {
#           if (typeof window.__uspapi !== 'undefined') {
#             window.__uspapi.apply(window.__uspapi, arg);
#           }
#         }, 500);
#       }
#     };
#
#     var checkIfUspIsReady = function() {
#       uspTries++;
#       if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#         console.warn('USP is not accessible');
#       } else {
#         clearInterval(uspInterval);
#       }
#     };
#
#     if (typeof window.__uspapi === 'undefined') {
#       window.__uspapi = uspStubFunction;
#       var uspInterval = setInterval(checkIfUspIsReady, 6000);
#     }
#   })();
# </script>
# <!-- End InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script>
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push({
#         'aLayout': 'Meteo',
#     });
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KMND7ZB');</script>
# <script src="https://www.weather-forecast.com/assets/vendor/modernizr-e5e9742b5821ce505a850d937a95481d65f99c9f82713400335e024afcc4eaae.js"></script><link href="/favicon.svg" rel="shortcut icon"/><link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon.svg" rel="icon" type="image/svg+xml"/><link href="/favicon.ico" rel="shortcut icon"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><meta content="Weather-Forecast" name="apple-mobile-web-app-title"/><link href="/site.webmanifest" rel="manifest"/><link href="https://de.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="de" rel="alternate"/><link href="https://www.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="en" rel="alternate"/><link href="https://es.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="es" rel="alternate"/><link href="https://fr.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="fr" rel="alternate"/><link href="https://ja.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="ja" rel="alternate"/><link href="https://nl.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="nl" rel="alternate"/><link href="https://zh.weather-forecast.com/locations/Vigo/forecasts/latest" hreflang="zh" rel="alternate"/><link href="https://www.weather-forecast.com/locations/Vigo/forecasts/latest" rel="canonical"/><script data-pagespeed-no-defer="">
#   Array.from||(Array.from=function(){var r=Object.prototype.toString,n=function(n){return"function"==typeof n||"[object Function]"===r.call(n)},t=Math.pow(2,53)-1,e=function(r){var n=function(r){var n=Number(r);return isNaN(n)?0:0!==n&&isFinite(n)?(n>0?1:-1)*Math.floor(Math.abs(n)):n}(r);return Math.min(Math.max(n,0),t)};return function(r){var t=Object(r);if(null==r)throw new TypeError("Array.from requires an array-like object - not null or undefined");var o,a=arguments.length>1?arguments[1]:void 0;if(void 0!==a){if(!n(a))throw new TypeError("Array.from: when provided, the second argument must be a function");arguments.length>2&&(o=arguments[2])}for(var i,u=e(t.length),f=n(this)?Object(new this(u)):new Array(u),c=0;c<u;)i=t[c],f[c]=a?void 0===o?a(i,c):a.call(o,i,c):i,c+=1;return f.length=u,f}}());
#   var uj_funcs = [];
#   (function() {
#     window.FCLAYOUT = {};
#     var fclayout = (window.FCLAYOUT || (window.FCLAYOUT = {}));
#     if (window.matchMedia) {
#       fclayout.small = !window.matchMedia('(min-width: 640px)').matches;
#       fclayout.portrait = window.matchMedia("(orientation: portrait)").matches;
#     } else {
#       fclayout.small = (window.innerWidth <= 640);
#     }
#   }).call(this);
# </script><script>(function() {
#   var fclayout = (window.FCLAYOUT || (window.FCLAYOUT = {}));
#   if (window.matchMedia) {
#     fclayout.largeUp = window.matchMedia('(min-width: 1024px)').matches;
#     fclayout.xLargeUp = window.matchMedia('(min-width: 1310px)').matches;
#   }
# }).call(this);</script> <script>
#       window.AdBridg = window.AdBridg || { cmd: [] };
#       window.googletag = window.googletag || { cmd: [] };
#       window.AdBridg.cmd.push({
#           action: "spa_pv_initialize",
#           config: {
#               ad_unit_section: "forecast",
#               contextual_data: {"iab_categories":[653,390,659],"keywords":["weather","travel","Vigo","Spain"]},
#               sticky_footer: true,
#               targeting: {}
#           }
#       });
#   </script>
# <script async="" src="https://prod.adspsp.com/adb.4578379.min.js" type="text/javascript"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script>
# <script async="" src="https://c.amazon-adsystem.com/aax2/apstag.js" type="text/javascript"></script>
# <style type="text/css">.img_over_cont {
#   cursor: pointer;
# }</style><script>var my = (window.FCLOCATIONS || (window.FCLOCATIONS = {}));
# my.locationFilename = "Vigo";
# my.forecastMode = "normal";
#
# var fclayout = (window.FCLAYOUT || (window.FCLAYOUT = {}));
# fclayout.userAgentIpad = false;</script> <style type="text/css">
#       @media only screen and (min-width: 0px) and (min-height: 0px) {
#           .bn-placeholder-0, .bn-placeholder-0.bn-placeholder-vcentered {
#               display: none;
#           }
#           .bn-placeholder-visual.bn-placeholder-0:after, .bn-placeholder-visual.bn-placeholder-0.bn-placeholder-vcentered:after {
#               display: none;
#           }
#       }
#       @media only screen and (min-width: 1000px) and (min-height: 200px) {
#           .bn-placeholder-0, .bn-placeholder-0.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 160px);
#               min-height: 600px;
#           }
#           .bn-placeholder-visual.bn-placeholder-0:after, .bn-placeholder-visual.bn-placeholder-0.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 160px);
#               margin-left: max(-80px, -50%);
#           }
#       }
#       @media only screen and (min-width: 1300px) and (min-height: 200px) {
#           .bn-placeholder-0, .bn-placeholder-0.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 300px);
#               min-height: 600px;
#           }
#           .bn-placeholder-visual.bn-placeholder-0:after, .bn-placeholder-visual.bn-placeholder-0.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 300px);
#               margin-left: max(-150px, -50%);
#           }
#       }
#     </style>
# <style type="text/css">
#       @media only screen and (min-width: 0px) and (min-height: 0px) {
#           .bn-placeholder-1, .bn-placeholder-1.bn-placeholder-vcentered {
#               display: flex;
#               min-width: 100%;
#               min-height: 83.333vw;
#           }
#           .bn-placeholder-visual.bn-placeholder-1:after, .bn-placeholder-visual.bn-placeholder-1.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: 100%;
#               margin-left: -50%;
#           }
#       }
#       @media only screen and (min-width: 758px) and (min-height: 200px) {
#           .bn-placeholder-1, .bn-placeholder-1.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 728px);
#               min-height: 90px;
#           }
#           .bn-placeholder-visual.bn-placeholder-1:after, .bn-placeholder-visual.bn-placeholder-1.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 728px);
#               margin-left: max(-364px, -50%);
#           }
#       }
#       @media only screen and (min-width: 1000px) and (min-height: 200px) {
#           .bn-placeholder-1, .bn-placeholder-1.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 728px);
#               min-height: 90px;
#           }
#           .bn-placeholder-visual.bn-placeholder-1:after, .bn-placeholder-visual.bn-placeholder-1.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 728px);
#               margin-left: max(-364px, -50%);
#           }
#       }
#     </style>
# <script data-pagespeed-no-defer="" type="text/javascript">
#   var FCMAPS = (window.FCMAPS || (window.FCMAPS = {}));
#   FCMAPS.anim_frames = 100;
#   FCMAPS.hr_step = 3;
# </script> <style type="text/css">
#       @media only screen and (min-width: 0px) and (min-height: 0px) {
#           .bn-placeholder-2, .bn-placeholder-2.bn-placeholder-vcentered {
#               display: flex;
#               min-width: 100%;
#               min-height: 83.333vw;
#           }
#           .bn-placeholder-visual.bn-placeholder-2:after, .bn-placeholder-visual.bn-placeholder-2.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: 100%;
#               margin-left: -50%;
#           }
#       }
#       @media only screen and (min-width: 641px) and (min-height: 200px) {
#           .bn-placeholder-2, .bn-placeholder-2.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 468px);
#               min-height: 60px;
#           }
#           .bn-placeholder-visual.bn-placeholder-2:after, .bn-placeholder-visual.bn-placeholder-2.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 468px);
#               margin-left: max(-234px, -50%);
#           }
#       }
#       @media only screen and (min-width: 758px) and (min-height: 200px) {
#           .bn-placeholder-2, .bn-placeholder-2.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 728px);
#               min-height: 90px;
#           }
#           .bn-placeholder-visual.bn-placeholder-2:after, .bn-placeholder-visual.bn-placeholder-2.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 728px);
#               margin-left: max(-364px, -50%);
#           }
#       }
#       @media only screen and (min-width: 1000px) and (min-height: 200px) {
#           .bn-placeholder-2, .bn-placeholder-2.bn-placeholder-vcentered {
#               display: flex;
#               min-width: min(100%, 970px);
#               min-height: 250px;
#           }
#           .bn-placeholder-visual.bn-placeholder-2:after, .bn-placeholder-visual.bn-placeholder-2.bn-placeholder-vcentered:after {
#               display: flex;
#               min-width: min(100%, 970px);
#               margin-left: max(-485px, -50%);
#           }
#       }
#     </style>
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "28221962" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <!-- End comScore Tag -->
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="Byg0g9AI8w13Adkm8NVp6Y9adWrLqJDSMqJ8coSfC3q4YUZPhgBs+bD6WFgtPMCQRZkuZYmAI94WIbfYNTTC3g==" name="csrf-token"/><script type="text/javascript">!(function(d,_name){d[_name]=d[_name]||function z(){(z.q=z.q||[]).push(arguments)},d[_name].v=d[_name].v||2,d[_name].s="1";})(window,decodeURI(decodeURI('%25%361%64%6d%256%39%72%25%36%31%256%63')));!(function(d,z,M,c){M=d.createElement(z),d=d.getElementsByTagName(z)[0],M.async=1,M.src="https://feelwarmth.com/kgwej9uk4r5w.js",(c=0)&&c(M),d.parentNode.insertBefore(M,d)})(document,"script");;</script>
# <script type="text/javascript">!(function(d,z,M,c,I){function O(c,I){try{O=d.localStorage,(c=JSON.parse(O[decodeURI(decodeURI('%2567e%25%37%34%254%39%257%34%65%25%36%64'))](M)).lgk||[])&&(I=d[z].pubads())&&c.forEach((function(d){d&&d[0]&&I.setTargeting(d[0],d[1]||"")}))}catch(g){}var O}try{(I=d[z]=d[z]||{}).cmd=I.cmd||[],typeof I.pubads===c?O():typeof I.cmd.unshift===c?I.cmd.unshift(O):I.cmd.push(O)}catch(g){}})(window,decodeURI(decodeURI('%67%6f%6f%25%367%256%63%2565%74a%67')),"_a"+decodeURI(decodeURI("%255%31S%253%30%2532N%44%2556F%25%34e%25%37%61%25%34a%25%346%25%35%32%54M%35%25%34%64%255%34%254e%44%25%35%32%45%5aF%4d%257%61%256%37%2577%52%54%25%346%2544N%255%35%45%25%374%25%34%64w")),"function");;</script>
# <script type="text/javascript">;</script>
# </head><body class="wider" data-c-domain=".weather-forecast.com"><!-- Begin comScore Tag -->
# <noscript>
# <img alt="" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28221962&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KMND7ZB" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="not_in_print" id="header_cont"><div id="head_bg"><div id="bg_right"></div></div><div id="tcont_head"><div id="logo_cont"><a href="/"><img alt="Weather Forecast" height="104" src="https://www.weather-forecast.com/img/weather-forecast__logo.svg" width="244"/></a></div><div id="header_sky"><div id="flags"><div class="show-for-medium-up"><div class="language-flags"><a href="https://www.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="gb" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/gb.svg"/></a><a href="https://fr.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="fr" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/fr.svg"/></a><a href="https://de.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="de" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/de.svg"/></a><a href="https://es.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="es" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/es.svg"/></a><a href="https://nl.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="nl" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/nl.svg"/></a><a href="https://ja.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="jp" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/jp.svg"/></a><a href="https://zh.weather-forecast.com/locations/Vigo/forecasts/latest"><img alt="cn" class="language-flags__flag" src="https://www.weather-forecast.com/images/flags/cn.svg"/></a></div></div><div class="show-for-small"><a aria-controls="flags-drop" aria-expanded="false" class="flags-drop-link flag-sprites" data-dropdown="flags-drop" href=""><img alt="gb" class="flag-large flag-gb" src="https://www.weather-forecast.com/images/blank.gif"/></a>
# <ul aria-hidden="true" class="flags-drop-list flag-sprites" data-dropdown-content="" id="flags-drop" tabindex="-1">
# <li><a href="https://www.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-gb"></div> English</a></li>
# <li><a href="https://fr.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-fr"></div> Français</a></li>
# <li><a href="https://de.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-de"></div> Deutch</a></li>
# <li><a href="https://es.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-es"></div> Español</a></li>
# <li><a href="https://nl.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-nl"></div> Nederlands</a></li>
# <li><a href="https://ja.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-jp"></div> 日本語</a></li>
# <li><a href="https://zh.weather-forecast.com/locations/Vigo/forecasts/latest"><div class="flag flag-cn"></div> 中文</a></li>
# </ul>
# </div></div><form action="/locations/catch" class="top-search-box" id="search-box" method="post">
# <input autocomplete="off" class="textinput" id="location" maxlength="255" name="query" onfocus="this.value='';" size="26" tabindex="1" type="text" value="ENTER A CITY OR COUNTRY:"/>
# <input id="location_loc_id" name="loc_id" type="hidden"/>
# <input class="searchbtn" id="searchbtn" type="submit" value="Search"/> <input name="action" type="hidden" value="save"/>
# </form>
# </div></div></div><div style="clear:both;"></div><div class="contain-to-grid cont-for-menu sticky"><nav class="top-bar" data-topbar="" role="navigation"><ul class="title-area"><li class="toggle-topbar menu-icon"><a href="#"><span></span></a></li><li class="show-for-small"><form action="/locations/catch" id="menu-search-box" method="post"><input autocomplete="off" class="search-small search-in-menu" id="search-in-menu" name="query" placeholder="ENTER A CITY OR COUNTRY:"/><input id="search-in-menu-loc-id" name="loc_id" type="hidden"/></form></li></ul><section class="top-bar-section"><ul class="left"><li><a class="active" href="/">Home</a></li><li><a href="/countries">Weather Forecasts</a></li><li><a href="/maps">Weather maps</a></li><li><a href="/photos">Photo Gallery</a></li></ul><ul class="right"><li><a href="/sign_in">Login</a></li><li><a href="/sign_up">Sign up</a></li></ul></section></nav></div><div id="upper-content"><div id="flash">
# </div></div><div style="text-align: center; padding: 10px 0 5px;">
# <div class="bn-placeholder bn-placeholder-visual bn-placeholder-vcentered bn-placeholder-2" data-adbridg-ad-class="adb-wt-top" id="cont_bn_unit_h">
# </div>
# </div><main class="combined-container"><section class="main-title"><div class="row"><div class="main-title__container column"><a class="main-title__flag" href="/countries/Spain"><img alt="Spain WEATHER" class="header_flag" src="https://www.weather-forecast.com/flags/SP.gif"/></a><h1 class="main-title__header"><span class="show-for-medium-up">Vigo Weather Forecast</span><span class="show-for-small-only">Vigo Weather Forecast</span></h1><div class="main-title__weather-icon show-for-medium-up"><div class="weather-wrapper"><img alt="Vigo Weather Forecast" src="https://www.weather-forecast.com/assets/wxvicons/dayclear-894dab60a9a23c3c4a197e71f47a5394e100502b19da44699a16735ef8fe3e39.svg"/></div></div></div></div><div class="row"><div class="main-title__container column"><div class="main-title__issued show-for-medium-up">Vigo (Galicia, Spain) forecast issued: <time datetime="2026-03-15T17:00:00Z">6 pm Sun 15 Mar 2026</time> local time <section class="next-update-countdown"><span data-countdown=""><span class="time-estimate countdown-hidden"><div><span class="countdown-delimiter">|</span> Updates in: <span class="hours-part"><span class="hours"></span>hr </span><span class="minutes"></span>min <span class="seconds"></span>s </div></span><span class="update-imminent countdown-hidden"><span class="countdown-delimiter">|</span> (Update imminent)</span> </span></section></div><div class="main-title__issued show-for-small-only"><div>Issued: <time datetime="2026-03-15T17:00:00Z">6 pm Sun 15 Mar 2026</time> local time <section class="next-update-countdown"><span data-countdown=""><span class="time-estimate countdown-hidden"><div><span class="countdown-delimiter">|</span> Updates in: <span class="hours-part"><span class="hours"></span>hr </span><span class="minutes"></span>min <span class="seconds"></span>s </div></span><span class="update-imminent countdown-hidden"><span class="countdown-delimiter">|</span> (Update imminent)</span> </span></section></div></div></div></div></section><section class="description"><div class="row"><div class="description__container description__container--pd0 columns large-1 collapse"><div class="description__map-thumb show-for-large-up"><a href="" onclick='$("html, body").animate({scrollTop: ($("#location-map-on-combined").offset().top)},500);return false;'><img alt="Vigo Local Map" class="descr-topo-thumb" src="https://www.weather-forecast.com/t_locationmaps/t_Vigo.10.gif"/></a></div></div><div class="description__container columns large-11"><div class="description__breadcrumbs"><ol class="breadcrumb-links show-for-medium-up"><li><a href="/countries/Spain"><span>Spain</span></a></li> <li class="current"><a href="/locations/Vigo/forecasts/latest"><span>Vigo</span></a></li> </ol></div><div class="description__text"><div class="show-for-small-only"><div class="description__weather-icon"><div class="weather-wrapper"><img alt="Vigo Weather Forecast" src="https://www.weather-forecast.com/assets/wxvicons/dayclear-894dab60a9a23c3c4a197e71f47a5394e100502b19da44699a16735ef8fe3e39.svg"/></div></div></div>Vigo Weather Forecast. Providing a local hourly Vigo weather forecast of rain, sun, wind, humidity and temperature. <div class="read-more-small"><div class="read-more-content">The Long-range 12 day forecast also includes detail for Vigo weather today. Live weather reports from Vigo weather stations and weather warnings that include risk of thunder, high UV index and forecast gales. See the links below the 12-day Vigo weather forecast table for other cities and towns nearby along with weather conditions for local outdoor activities.<p class="large-loc"><b>Vigo</b> is  <span class="height">47</span> <span class="heightu">m</span>  above sea level and located at <span class="geo"><span class="latitude" title="42.22">42.22° N</span> <span class="longitude" title="-8.73">8.73° W</span></span>. Vigo has a population of 297332. Local time in Vigo is <span class="current-local-time"></span> CET.</p></div><a class="read-more-labe ...
# <div class="bn-placeholder bn-placeholder-visual bn-placeholder-vcentered bn-placeholder-0" data-adbridg-ad-class="adb-wt-lhs" id="cont_bn_by_forecast">
# </div>
# </div><div class="b-forecast__overflow" data-scroll=""><button class="scroll-button is-left is-hidden not_in_print" data-scroll-button="left" style="left: 50px;">Scroll to left<img alt="left" class="scroll-button__arrow" height="32" src="https://www.weather-forecast.com/assets/base/icon-chevron-circle-left-f87a8f940dc4d0991d5a7eccd9f7b028460a4e09851a6eec440d913dee3d8b4c.svg" width="32"/></button><div class="b-forecast__wrapper b-forecast__wrapper--js" data-scroll-container=""><table class="b-forecast__table js-forecast-table"><thead><tr class="b-forecast__table-description b-forecast__hide-for-small days-summaries js-day-summary"><th></th><td class="b-forecast__table-description-cell--js" colspan="9"><div class="b-forecast__table-description-title"><h2>Vigo Weather Today</h2> (1–3 days)</div><p class="b-forecast__table-description-content"><span class="phrase">Some drizzle, heaviest during Wed morning. Very mild (max 19°C on Tue morning, min 8°C on Sun night). Wind will be generally light.</span></p></td><td class="b-forecast__table-description-cell--js" colspan="9"><div class="b-forecast__table-description-title"><h2>Vigo Weather (4–7 days)</h2></div><p class="b-forecast__table-description-content"><span class="phrase">Moderate rain (total 17mm), heaviest on Thu night. Very mild (max 18°C on Thu morning, min 11°C on Thu night). Wind will be generally light.</span></p></td><td class="b-forecast__table-description-cell--js" colspan="9"><div class="b-forecast__table-description-title"><h2>10 Day Vigo Weather</h2> (7–10 days)</div><p class="b-forecast__table-description-content"><span class="phrase">Light rain (total 3.2mm), mostly falling on Sat afternoon. Very mild (max 16°C on Sun morning, min 9°C on Sun night). Wind will be generally light.</span></p></td><td class="b-forecast__table-description-cell--js" colspan="9"><div class="b-forecast__table-description-title"><h2>Vigo Weather Next Week</h2> (10–12 days)</div><p class="b-forecast__table-description-content"><span class="phrase">Light rain (total 2.7mm), mostly falling on Fri morning. Very mild (max 14°C on Thu afternoon, min 9°C on Wed night). Wind will be generally light.</span></p></td><td class="b-forecast__table-description-cell--js" colspan="9"><div class="b-forecast__table-description-title"><h2>Vigo Weather Next Week</h2> (13–16 days)</div><p class="b-forecast__table-description-content"><span class="phrase">Light rain (total 2.1mm), mostly falling on Sat afternoon. Very mild (max 17°C on Tue morning, min 7°C on Fri night). Wind will be generally light.</span></p></td></tr><tr class="b-forecast__table-days js-forecast-header js-daynames"><th class="b-forecast__table-units"><div class="b-forecast__table-units-container"><button class="b-forecast__table-units-button b-forecast__table-float b-forecast__table-units-button--active" data-units="Metric"><span class="b-forecast__table-units-button-wrapper">°C</span></button></div></th><td class="b-forecast__table-days-item b-forecast__table-day-end b-forecast__table-day-odd js-day-header" colspan="2" data-column-name="Sun_15" data-d-period="0" data-first-h-period="0" data-first-p-period="0" data-first-t-period="0" data-last-h-period="9" data-last-p-period="1" data-last-t-period="2"><button class="b-forecast__table-days-toggle" data-period="p"><i aria-hidden="true" class="fa fa-expand not_in_print"></i></button><div class="b-forecast__table-days-content"><div class="b-forecast__table-days-name">Sun</div><div class="b-forecast__table-days-date">15</div></div></td><td class="b-forecast__table-days-item b-forecast__table-day-end js-day-header" colspan="3" data-column-name="Mon_16" data-d-period="1" data-first-h-period="10" data-first-p-period="2" data-first-t-period="3" data-last-h-period="33" data-last-p-period="4" data-last-t-period="10"><button class="b-forecast__table-days-toggle" data-period="p"><i aria-hidden="true" class="fa fa-expand not_in_print"></i></button><div class="b-forecast__table-days-content"><div class="b- ...
# <div class="bn-placeholder bn-placeholder-visual bn-placeholder-vcentered bn-placeholder-1" data-adbridg-ad-class="adb-wt-bottom" id="cont_bn_under_forecast">
# </div>
# </div><section class="row"><div class="column"><div class="hr"></div></div></section><section class="row"><div class="large-8 columns"><section class="b-metar"><div class="row"><h2 class="b-metar__title columns">Live weather stations near Vigo</h2><div class="b-metar__subtitle columns"><div class="show-for-large-up">Vigo Live Weather Today: Recent reports from weather stations near Vigo</div></div><div class="b-metar__table-container columns"><table class="b-metar-table"><thead class="b-metar-table__header"><tr class="b-metar-table__row"><th>Weather Station</th><th>Temp.</th><th>Weather</th><th>Wind</th><th>Gusts</th><th><div><div class="hide-for-large-up">Cloud</div><div class="hide-for-large-up">Visibility</div><div class="show-for-large-up">Cloud / Visibility</div></div></th></tr></thead><tbody class="b-metar-table__body"><tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Comesana-weather-station">Comesaña wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">3</span> <span class="distu">km</span> <span class="dir">SSW</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">36</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">18.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Calm</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="0.0">0</span> <span class="windu">km/h</span> at SE°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="3.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">5</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr><tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Vigo-Peinador-Airport">Vigo/Peinador Airport</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">9</span> <span class="distu">km</span> <span class="dir">E</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">712</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div ...
#   <style type="text/css">
#     .half-map-cont .wxicon {
#       background-image: url(https://www.weather-forecast.com/assets/smallweathericons/sprite-067-d65b9ab4f8c780defab470d0d9102f925a600897fa9d0b6e0422b0adc75d5888.png);
#     }
#   </style>
# <![endif]-->
# <h2 class="list-side__header">Spain Weather Map</h2>
# <div class="basic"><div id="scrollBox"><div class="rtn" id="mapcontainer"><div class="zoom-control"><a class="plus" href="" onclick="$('.also-see-detailed').show(); return false;">+</a><a class="minus zoom" href="/maps/Spain">-</a></div><div class="also-see-detailed"><a class="cross" href="" onclick="$('.also-see-detailed').hide(); return false;">✖</a><h3>Please pick from the following detailed weather maps:</h3><table><tr><td><a class="zoom" href="/topographic-maps/andalucia">Andalucía</a></td><td><a class="zoom" href="/topographic-maps/cataluna">Catalunya</a></td><td><a class="zoom" href="/topographic-maps/la-rioja">La Rioja</a></td></tr><tr><td><a class="zoom" href="/topographic-maps/aragon">Aragón</a></td><td><a class="zoom" href="/topographic-maps/ceuta">Ceuta</a></td><td><a class="zoom" href="/topographic-maps/melilla">Melilla</a></td></tr><tr><td><a class="zoom" href="/topographic-maps/principado-de-asturias">Asturias</a></td><td><a class="zoom" href="/topographic-maps/comunidad-de-madrid">Comunidad de Madrid</a></td><td><a class="zoom" href="/topographic-maps/comunidad-foral-de-navarra">Navarra</a></td></tr><tr><td><a class="zoom" href="/topographic-maps/islas-canarias">Canarias</a></td><td><a class="zoom" href="/topographic-maps/islas-baleares">Comunitat Autònoma de les Illes Balears</a></td><td><a class="zoom" href="/topographic-maps/pais-vasco">Pais Vasco</a></td></tr><tr><td><a class="zoom" href="/topographic-maps/cantabria">Cantabria</a></td><td><a class="zoom" href="/topographic-maps/comunidad-valenciana">Comunitat Valenciana</a></td><td><a class="zoom" href="/topographic-maps/region-de-murcia">Región de Murcia</a></td></tr><tr><td><a class="zoom" href="/topographic-maps/castilla-y-leon">Castilla y León</a></td><td><a class="zoom" href="/topographic-maps/extremadura">Extremadura</a></td></tr><tr><td><a class="zoom" href="/topographic-maps/castilla-la-mancha">Castilla-La Mancha</a></td><td><a class="zoom" href="/topographic-maps/galicia">Galicia</a></td></tr></table></div><div class="play-control"><div class="frame-back inactive"><div class="bar"></div><div class="triangle triangle-left"></div></div><div class="frame-forward"><div class="triangle triangle-right"></div><div class="bar"></div></div><div style="clear: both;"></div></div><img alt="" id="mapimg" src="/images/blank.gif"/><table class="map-table-like-container not_in_print" id="loaderContainer" onclick="return false;"><tr><td class="map-table-cell-middle"><table class="map-table-like-container" id="progressTable" style="border-spacing: 2px;"><tr><td colspan="28" style="font-size:16px;font-weight:bold;">Preloading...</td></tr><tr><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progressBlank"></td><td class="progres ...
# </div><div class="large-8 columns photos-on-combined"><h2>Vigo Weather Photos</h2><div class="photos like-row">View <a href="/regions/Galicia/photos">all photos from <b>Galicia</b> (6)</a> | <a href="/countries/Spain/photos">photos from <b>Spain</b> (381)</a> | <a href="/photos">Photo gallery home</a><p><img alt="Upload symbol" border="0" class="pre-icon" height="16" src="https://www.weather-forecast.com/assets/up-symbol-99c8800e8a98b93ff6ee0332669c70c8ac12d84670a5f63ff3d74df4ccbe8430.png" width="16"/>Upload a <a href="/photos/new"><b>Vigo</b> Weather Image</a> | <a href="/photos/new">Upload for another city</a></p><div class="gallery photos short"><ul class="small-block-grid-2 medium-block-grid-3 large-block-grid-4"><li class="img"><a href="/locations/Vigo/photos/547"><img alt="Vigo" class="gallery" src="https://www.weather-forecast.com/system/images/547/thumb_gallery_rtn/Vigo.jpg"/></a><br/><div class="stars"><div class="star_bar"><div style="width: 44px;"></div></div></div><p class="ph-name">Vigo.</p></li></ul></div></div></div></section><section class="row"><div class="column"><div class="hr"></div></div></section><section class="row"><div class="static-location-map small-12 large-4 columns"><img alt="Vigo Location Map" class="static-location-map__main" id="placeholder" src="https://www.weather-forecast.com/locationmaps/Vigo.10.gif"/><div class="static-location-map__links" id="locationmap_links"><a href="https://www.weather-forecast.com/locationmaps/Vigo.8.gif" onclick="return showPic(this)"><img alt="Vigo Regional Map" src="https://www.weather-forecast.com/t_locationmaps/t_Vigo.8.gif"/></a><a class="current" href="https://www.weather-forecast.com/locationmaps/Vigo.10.gif" onclick="return showPic(this)"><img alt="Vigo Local Map" src="https://www.weather-forecast.com/t_locationmaps/t_Vigo.10.gif"/></a><a href="https://www.weather-forecast.com/locationmaps/Vigo.12.gif" onclick="return showPic(this)"><img alt="Vigo Street Map" src="https://www.weather-forecast.com/t_locationmaps/t_Vigo.12.gif"/></a></div></div><div class="small-12 columns large-8">
# <h3 class="nearest-other-header">
#     Weather forecast for places near Vigo:
# </h3>
# <div class="has-overflow-x-auto">
# <table cellspacing="0" class="other_places guide">
# <tr>
# <th><b>Place Name</b></th>
# <th><b>1–3 Day Summary</b></th>
# <th><b>4–6 Day Summary</b></th>
# <th><b>7–9 Day Summary</b></th>
# <th><b>10–12 Day Summary</b></th>
# </tr>
# <tr>
# <td bgcolor="#99CC99" height="25"><a href="/locations/Cangas/forecasts/latest">
# <b>Cangas do Morrazo</b></a>
# <br/>
# <span class="dist">
#                 7
#             </span>
# <span class="distu">km</span>
# </td>
# <td bgcolor="#99CC99" height="25"><span class="phrase">Mostly dry.</span></td>
# <td bgcolor="#99CC99" height="25"><span class="phrase">Moderate rain (total 15mm), heaviest on Thu night.</span></td>
# <td bgcolor="#99CC99" height="25"><span class="phrase">Light rain (total 2.7mm), mostly falling on Sat morning.</span></td>
# <td bgcolor="#99CC99" height="25"><span class="phrase">Mostly dry.</span></td>
# </tr>
# <tr>
# <td bgcolor="#CCCCCC" height="25"><a href="/locations/Redondela/forecasts/latest">
# <b>Redondela</b></a>
# <br/>
# <span class="dist">
#                 13
#             </span>
# <span class="distu">km</span>
# </td>
# <td bgcolor="#CCCCCC" height="25"><span class="phrase">Mostly dry.</span></td>
# ...
# <ul>
# <li><a href="https://www.facebook.com/wxforecast"><img alt="facebook" src="/images/fb.png"/><span>Like us</span></a></li>
# <li><a href="https://twitter.com/meteo365"><img alt="twitter" src="/images/t.png"/><span>Follow us</span></a></li>
# </ul>
# </div>
# <div class="footer-logo-links show-for-large-up">
# <ul>
# <li>
# <img alt="Surf Forecast" height="41" src="https://www.weather-forecast.com/images/surf.png" width="130"/>
# </li>
# <li>
# <img alt="Snow Forecast" height="37" src="https://www.weather-forecast.com/images/snow.png" width="130"/>
# </li>
# <li>
# <img alt="Mountain Forecast" height="37" src="https://www.weather-forecast.com/images/mountain.png" width="130"/>
# </li>
# <li>
# <img alt="Tide Forecast" height="37" src="https://www.weather-forecast.com/images/tide.png" width="130"/>
# </li>
# </ul>
# </div>
# <div class="footer-links">
# <div class="row">
# <div class="medium-4 columns">
# <h5>Company</h5>
# <ul>
# <li><a href="/pages/contact" rel="nofollow">Contact us</a></li>
# <li><a href="/pages/terms" rel="nofollow">Terms</a></li>
# <li><a href="/pages/privacy" rel="nofollow">Privacy</a></li>
# <li><a href="/pages/cookie_policy" rel="nofollow">Cookie Policy</a></li>
# <li><a class="change-consent page-footer__link" id="gdpr_link" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );" style="display: none; cursor: pointer;">Privacy Settings</a></li>
# <li><a class="page-footer__link" id="ccpa_link" onclick="window.__uspapi('displayUspUi')" style="display: none; cursor: pointer;">Do Not Sell My Personal Information</a></li>
# <script type="text/javascript">
#     if (typeof window.__uspapi === 'function') {
#         window.__uspapi('uspPing', 1, function(obj, status) {
#             if (status && obj.mode.includes('USP') && obj.jurisdiction.includes(obj.location.toUpperCase())) {
#                 document.getElementById("ccpa_link").style.display = "block";
#             }
#         });
#     }
#
#     window.__tcfapi('getTCData',2,function(data,success){
#         console.log("data.gdprApplies: "  + data.gdprApplies);
#         if(data.gdprApplies){
#             document.getElementById("gdpr_link").style.display = "block";
#         }
#     });
# </script>
# </ul>
# </div>
# <div class="medium-4 columns">
# <h5>Weather Photos</h5>
# <ul>
# <li><a href="/albums/5/photos">Cloud Formations</a></li>
# <li><a href="/albums/18/photos">Autumn Colours</a></li>
# <li><a href="/albums/3/photos">Lightning</a></li>
# <li><a href="/albums/12/photos">Rainbows &amp; Reflections</a></li>
# <li><a href="/albums/1/photos">Snow, Ice &amp; Frost</a></li>
# <li><a href="/albums/2/photos">Sunrises &amp; Sunsets</a></li>
# <li><a href="/albums/6/photos">Rain &amp; Floods</a></li>
# </ul>
# </div>
# <div class="medium-4 columns show-for-medium-up">
# <h5 class="show-for-medium-up">Share</h5>
# <ul>
# <li><a href="https://www.facebook.com/wxforecast"><img alt="facebook" src="/images/fb.png"/><span>Like us</span></a></li>
# <li><a href="https://twitter.com/meteo365"><img alt="twitter" src="/images/t.png"/><span>Follow us</span></a></li>
# </ul>
# </div>
# </div>
# <div style="width:100%; text-align:center; clear: both;">
# <p>
#         © 2026 Meteo365.com
#
#       </p>
# </div>
# </div>
# </div>
# <script>
# //<![CDATA[
# window.FCGON = {"forecast_update_ts":1773622467,"server_time":1773600899,"maps":[{"topoUrl":"https://snowmap.fast-sfc.com/base_snow_map/{z}/{x}/{y}.png","metarReports":[{"name":"Comesaña wx","filename":"Comesana-weather-station","lat":42.2,"lon":-8.75,"wind_icon":"\u003cdiv class=\"wind-icon\" data-precision=\"5\" data-speed=\"0.0\"\u003e\u003csvg class=\"wind-icon__svg\" fill=\"rgb(0, 0, 0)\" viewBox=\"-19 -19 38 38\" xmlns=\"http://www.w3.org/2000/svg\"\u003e\u003ccircle cx=\"0\" cy=\"0\" r=\"10.5\"\u003e\u003c/circle\u003e\u003cg class=\"wind-icon__arrow\" transform=\"rotate(315)\"\u003e\u003cpolygon points=\"-7 -13.5 0 -19.5 7 -13.5\"\u003e\u003c/polygon\u003e\u003crect height=\"4\" width=\"4\" x=\"-2\" y=\"-13.5\"\u003e\u003c/rect\u003e\u003c/g\u003e\u003ctext class=\"wind-icon__val\" fill=\"rgb(255, 255, 255)\" text-anchor=\"middle\" x=\"0\" y=\"5\"\u003e0\u003c/text\u003e\u003c/svg\u003e\u003c/div\u003e","temp":18,"temp_css_class":"temp-color5","weather":"dry","weather_icon":"","gusts_icon":"\u003cdiv class=\"wind-icon\" data-precision=\"5\" data-speed=\"3.0\"\u003e\u003csvg class=\"wind-icon__svg\" fill=\"rgb(0, 0, 0)\" viewBox=\"-19 -19 38 38\" xmlns=\"http://www.w3.org/2000/svg\"\u003e\u003ccircle cx=\"0\" cy=\"0\" r=\"10.5\"\u003e\u003c/circle\u003e\u003cg class=\"wind-icon__arrow\" transform=\"rotate(315)\"\u003e\u003cpolygon points=\"-7 -13.5 0 -19.5 7 -13.5\"\u003e\u003c/polygon\u003e\u003crect height=\"4\" width=\"4\" x=\"-2\" y=\"-13.5\"\u003e\u003c/rect\u003e\u003c/g\u003e\u003ctext class=\"wind-icon__val\" fill=\"rgb(255, 255, 255)\" text-anchor=\"middle\" x=\"0\" y=\"5\"\u003e5\u003c/text\u003e\u003c/svg\u003e\u003c/div\u003e"},{"name":"Vigo/Peinador Airport","filename":"Vigo-Peinador-Airport","lat":42.217,"lon":-8.617000000000019,"wind_icon":"\u003cdiv class=\"wind-icon\" data-precision=\"5\" data-speed=\"15.0\"\u003e\u003csvg class=\"wind-icon__svg\" fill=\"rgb(0, 0, 0)\" viewBox=\"-19 -19 38 38\" xmlns=\"http://www.w3.org/2000/svg\"\u003e\u003ccircle cx=\"0\" cy=\"0\" r=\"10.5\"\u003e\u003c/circle\u003e\u003cg class=\"wind-icon__arrow\" transform=\"rotate(160)\"\u003e\u003cpolygon points=\"-7 -13.5 0 -19.5 7 -13.5\"\u003e\u003c/polygon\u003e\u003crect height=\"4\" width=\"4\" x=\"-2\" y=\"-13.5\"\u003e\u003c/rect\u003e\u003c/g\u003e\u003ctext class=\"wind-icon__val\" fill=\"rgb(255, 255, 255)\" text-anchor=\"middle\" x=\"0\" y=\"5\"\u003e15\u003c/text\u003e\u003c/svg\u003e\u003c/div\u003e","temp":null,"temp_css_class":null,"weather":"-","weather_icon":"\u003cimg alt=\"clear\" class=\"weather-icon\" src=\"https://www.weather-forecast.com/packs/media/components/weather-icon/static/dayclear-af30c218df7d56904a79f3bd51b3c055.svg\" /\u003e","gusts_icon":null},{"name":"VigoPeinador","filename":null,"lat":42.238611,"lon":-8.62388900000002,"wind_icon":"\u003cdiv class=\"wind-icon\" data-precision=\"5\" data-speed=\"17.0\"\u003e\u003csvg class=\"wind-icon__svg\" fill=\"rgb(0, 0, 0)\" viewBox=\"-19 -19 38 38\" xmlns=\"http://www.w3.org/2000/svg\"\u003e\u003ccircle cx=\"0\" cy=\"0\" r=\"10.5\"\u003e\u003c/circle\u003e\u003cg class=\"wind-icon__arrow\" transform=\"rotate(160)\"\u003e\u003cpolygon points=\"-7 -13.5 0 -19.5 7 -13.5\"\u003e\u003c/polygon\u003e\u003crect height=\"4\" width=\"4\" x=\"-2\" y=\"-13.5\"\u003e\u003c/rect\u003e\u003c/g\u003e\u003ctext class=\"wind-icon__val\" fill=\"rgb(255, 255, 255)\" text-anchor=\"middle\" x=\"0\" y=\"5\"\u003e15\u003c/text\u003e\u003c/svg\u003e\u003c/div\u003e","temp":15,"temp_css_class":"temp-color5","weather":"-","weather_icon":"","gusts_icon":null},{"name":"Guimarey wx","filename":"Guimarey-weather-station","lat":42.68133,"lon":-8.461169999999981,"wind_icon":"\u003cdiv class=\"wind-icon\" data-precision=\"5\" data-speed=\"0.0\"\u003e\u003csvg class=\"wind-icon__svg\" fill=\"rgb(0, 0, 0)\" viewBox=\"-19 -19 38 38\" xmlns=\"http://www.w3.org/2000/svg\"\u003e\u003ccircle cx=\"0\" cy=\"0\" r=\"10.5\"\u003e\u003c/circle\u003e\u003cg class=\"wind-icon__arrow\" transform=\"rota ...
# //]]>
# </script><script src="https://www.weather-forecast.com/packs/js/application-5687239e32a48899c204.js"></script><script src="https://www.weather-forecast.com/assets/application-200f3ab5206ed73d1be68c383adbaa26151c6690789a95799761d801ab861a0f.js"></script><script>var server_time = 1773600899;
# var now = new Date();
# var time_correction = server_time - now.getTime() / 1000;
# var secdiff = 3600;
# updateLocalTime();</script><script async="" src="/javascripts/forecast-table.umd.js"></script><script>$(".img_over_cont").click(function() {
#   window.location.href = "/topographic-maps/Spain";
# });</script><script>$(".zoom-control a.zoom, .also-see-detailed a.zoom").click(function() {
#   if (this.href) {
#     window.location.href=FCMAPS.mapPathPreservingMode(this.href);
#   }
#   return false;
# });</script><script>$(".play-control .frame-back").click(function() {
#   FCMAPS.advanceByFrames(-1);
# });
# $(".play-control .frame-forward").click(function() {
#   FCMAPS.advanceByFrames(1);
# });</script><script>window.fcmaps_cmd = window.fcmaps_cmd || [];
# fcmaps_cmd.push(function() {
#   window.filenames = [];
# });</script><script type="text/javascript">
#
#   window.fcmaps_cmd = window.fcmaps_cmd || [];
#   fcmaps_cmd.push(function() {
#
#     window.params = {};
#     window.filename = "Spain";
#     window.main_filename = "Spain";
#     window.guests_code=".cc23";
#     window.members_code="";
#     window.map_hosts=['https://assets.weather-forecast.com'];
#     window.static_map_hosts=['https://assets.weather-forecast.com'];
#     window.symbol_path = "/maps/topographic/";
#     window.map_path = "/maps/topographic/";
#     window.default_type_for_anim = "prec";
#     window.max_guest_hours = 300;
#     window.last_hr = 300;
#
#     window.units = 'metric';
#     window.noClick = false;
#
#     $(document).ready(function () {
#       $(".basic_controls .dyn_thumb_controls .mode a").click(function() {
#         // var a_element = $("a", $(this).parents("td")[0])[0];
#         FCMAPS.setMapModeFromUrl(this.href);
#         if (history && history.replaceState) {
#           history.replaceState(null, "", this.href);
#         }
#         $(".dyn_thumb_controls .selected").removeClass("selected").addClass("not_selected");
#
#         var currentCont = $(".not_selected", $(this).parentsUntil(".btncontblock, .dyn_thumb_controls", "tr"))[0];
#         $(currentCont).addClass("selected").removeClass("not_selected");
#
#         $(this).parents("li.not_selected").addClass("selected").removeClass("not_selected");
#         return false;
#       });
#       $(".advanced_controls .dyn_thumb_controls .mode a").click(function() {
#         FCMAPS.setMapModeFromUrl(this.href, false);
#         var controls_group = $(this).parents(".dyn_thumb_controls");
#         controls_group.find(".selected").removeClass("selected").addClass("not_selected");
#         $($(".not_selected", $(this).parents("tr"))[0]).addClass("selected").removeClass("not_selected");
#         return false;
#       });
#       window.params.map_mode = {"default":{"type":"marine","over":"none","symbols":"cities.forecast.weather","hr":"6"},"current":{"type":"marine","over":"none","symbols":"cities.forecast.weather","hr":"6"}};
#       window.params.basic = true;
#       FCMAPS.detailed = true;
#       FCMAPS.scale = 0.67;
#       FCMAPS.width = 601;
#       FCMAPS.height = 492;
#       FCMAPS.thumb_filename = "Spain";
#       FCMAPS.titles_for_symbols = {
#         "cities.forecast.weather": " ",
#         "cities.forecast.wind": "Wind Forecast",
#         "cities.forecast.temp": "Temperature Forecast",
#         "snow.forecast.weather.top": "Weather Forecast (Top Lift at Resorts)",
#         "snow.forecast.weather.mid": "Weather Forecast (Mid Mountain)",
#         "snow.forecast.weather.bot": "Weather Forecast (Bottom Lift at Resorts)",
#         "isgoodpiste": "Resorts with Good Piste Conditions Reported",
#         "ispowder": "Resorts with Powder Reported",
#         "isnewsnow": "Resorts with New Snow Reported",
#         "isnewsnow": "Resorts with New Snow Reported",
#         "summary.upper_depth": "Snow Depths at the Resort Top Lift",
#         "summary.lower_depth": "Snow Depths at the Resort Bottom Lift",
#         "summary.fresh_snow_depth": "Resorts with Fresh Snow Reported",
#         "summary.lastsnowed": "Number of Days Since Last Snow",
#         "livecams": "Resort Webcams",
#         "isfullyopen": "Resorts that are Fully Open",
#         "runstoresort": "Runs to Resort Open",
#         "liveweather": "Weather Now",
#         "livetemp": "Temperature Now",
#         "livewind": "Wind Now",
#         "livecitycams": "City Webcams",
#         "livesurfcams": "Beach Webcams",
#         "liveswell": "Wave Buoys"
#       }
#       FCMAPS.time_descriptions = ['Sunday 15 Mar 10am', 'Sunday 15 Mar 1pm', 'Sunday 15 Mar 4pm', 'Sunday 15 Mar 7pm', 'Sunday 15 Mar 10pm', 'Monday 16 Mar 1am', 'Monday 16 Mar 4am', 'Monday 16 Mar 7am', 'Monday 16 Mar 10am', 'Monday 16 Mar 1pm', 'Monday 16 Mar 4pm', 'Monday 16 Mar 7pm', 'Monday 16 Mar 10pm', 'Tuesday 17 Mar 1am', 'Tuesday 17 Mar 4am', 'Tuesday 17 Mar 7am', 'Tuesday 17 Mar 10am', 'Tuesday 17 Mar 1pm', 'Tuesday 17 Mar 4pm', 'Tuesday 17 Mar 7pm', 'Tuesday 17 Mar 10pm', 'Wednesday 18 Mar 1am', 'Wednesday 18 Mar 4am', 'Wednesday 18 Mar 7am', 'Wednesday 18 Mar 10am', 'Wednesday 18 Mar 1pm', 'Wednesday 18 Mar 4pm', 'Wednesday 18 Mar 7pm', 'Wednesday 18 Mar 10pm', 'Thursday 19 Mar 1am', 'Thursday 19 Mar 4am', 'Thursday 19 Mar 7am', 'Thursday 19 Mar 10am', 'Thursday 19 Mar 1pm', 'Thursday 19 Mar 4pm', 'Thursday 19 Mar 7pm', 'Thursday 19 Mar 10pm', 'Friday 20 Mar 1am', 'Friday 20 Mar 4am', 'Friday 20 Mar 7am', 'Friday 20 Mar 10am', 'Friday 20 Mar 1pm', 'Friday 20 Mar 4pm', 'Friday 20 Mar 7pm', 'Friday 20 Mar 10pm', 'Saturday 21 Mar 1am', 'Saturday 21 Mar 4am', 'Saturday 21 Mar 7am', 'Saturday 21 Mar 10am', 'Saturday 21 Mar 1pm', 'Saturday 21 Mar 4pm', 'Saturday 21 Mar 7pm', 'Saturday 21 Mar 10pm', 'Sunday 22 Mar 1am', 'Sunday 22 Mar 4am', 'Sunday 22 Mar 7am', 'Sunday 22 Mar 10am', 'Sunday 22 Mar 1pm', 'Sunday 22 Mar 4pm', 'Sunday 22 Mar 7pm', 'Sunday 22 Mar 10pm', 'Monday 23 Mar 1am', 'Monday 23 Mar 4am', 'Monday 23 Mar 7am', 'Monday 23 Mar 10am', 'Monday 23 Mar 1pm', 'Monday 23 Mar 4pm', 'Monday 23 Mar 7pm', 'Monday 23 Mar 10pm', 'Tuesday 24 Mar 1am', 'Tuesday 24 Mar 4am', 'Tuesday 24 Mar 7am', 'Tuesday 24 Mar 10am', 'Tuesday 24 Mar 1pm', 'Tuesday 24 Mar 4pm', 'Tuesday 24 Mar 7pm', 'Tuesday 24 Mar 10pm', 'Wednesday 25 Mar 1am', 'Wednesday 25 Mar 4am', 'Wednesday 25 Mar 7am', 'Wednesday 25 Mar 10am', 'Wednesday 25 Mar 1pm', 'Wednesday 25 Mar 4pm', 'Wednesday 25 Mar 7pm', 'Wednesday 25 Mar 10pm', 'Thursday 26 Mar 1am', 'Thursday 26 Mar 4am', 'Thursday 26 Mar 7am', 'Thursday 26 Mar 10am', 'Thursday 26 Mar 1pm', 'Thursday 26 Mar 4pm', 'Thursday 26 Mar 7pm', 'Thursday 26 Mar 10pm', 'Friday 27 Mar 1am', 'Friday 27 Mar 4am', 'Friday 27 Mar 7am', 'Friday 27 Mar 10am', 'Friday 27 Mar 1pm', 'Friday 27 Mar 4pm', 'Friday 27 Mar 7pm'];
#       FCMAPS.timezone_descr = 'CET';
#       FCMAPS.thumbs_to_preload = [ "lapse", "cloud", "weather_pressure", "wind", "prec" ];
#       FCMAPS.initMap1();
#       FCMAPS.initialSwitch();
#
#
#
#
#
#       $('#map-loc-namebox').auto_complete_loc({
#         url: '/topographic-maps/Spain/ac_location_name?query=__VALUE__',
#         immediate_submit: false,
#         loc_id: 'map_loc_id',
#         default_text: 'Vigo',
#         use_first_entry: true,
#         callback_on_choice: function (input, result) {
#           eval("FCMAPS.putCross("+result+")");
#         },
#         matchesUseJSON: false
#       });
#       $("input[name='airports']").click(function() {
#         if ($(this).attr('data-class') == 'rtn') {
#           $('#mapcontainer').addClass('rtn');
#         } else {
#           $('#mapcontainer').removeClass('rtn');
#         }
#         FCMAPS.setAirports(this.value);
#       });
#     });
#
#
#   });
# </script> <script>
#         (function() {
#
#             window.googletag = window.googletag || { cmd: [] };
#             googletag.cmd.push(function() {
#                 googletag.pubads().addEventListener('slotRenderEnded', event => {
#                     if (!event.isEmpty) {
#                         var slotId = event.slot.getSlotElementId();
#                         var el = document.getElementById(slotId);
#                         el.classList.remove('bn-placeholder-visual');
#                     }
#                 });
#             });
#         })();
#     </script>
# <script>
#     $(document).ready(function () {
#       var url_str = '/locations/ac_location_name?query=__VALUE__';
#       var default_text_str = 'ENTER A CITY OR COUNTRY:';
#       $('#location').auto_complete_loc({url: url_str, default_text: default_text_str, loc_id: 'location_loc_id', prevent_empty_submit: true, matchesUseJSON: true});
#     });
#   </script>
# <script>if (typeof init_uj == "function") {
#   init_uj();
# }</script><!-- Generated 2026-03-15 18:54:59 UTC --></body></html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup

# %% [markdown]
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.

# %% [markdown]
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>Vigo Weather Forecast</title>

# %%
soup.h1
# Out:
# <h1 class="main-title__header"><span class="show-for-medium-up">Vigo Weather Forecast</span><span class="show-for-small-only">Vigo Weather Forecast</span></h1>

# %% [markdown]
# Eliminamos las etiquetas

# %%
soup.h1.get_text()
# Out:
# 'Vigo Weather ForecastVigo Weather\xa0Forecast'

# %% [markdown]
# Buscamos los datos que nos interesan: en este caso, etiquetas ```td``` y ```p```.

# %%
w_desc=[]

# td es una celda de datos dentro de una tabla
# p es un párrafo
for weather in soup.find_all('td', class_='b-forecast__table-description-cell--js'):
    desc = weather.find('p', class_='b-forecast__table-description-content').text
    w_desc.append(desc)

# %%
w_desc
# Out:
# ['Some drizzle, heaviest during Wed morning. Very mild (max 19°C on Tue morning, min 8°C on Sun night). Wind will be generally light.',
#  'Moderate rain (total 17mm), heaviest on Thu night. Very mild (max 18°C on Thu morning, min 11°C on Thu night). Wind will be generally light.',
#  'Light rain (total 3.2mm), mostly falling on Sat afternoon. Very mild (max 16°C on Sun morning, min 9°C on Sun night). Wind will be generally light.',
#  'Light rain (total 2.7mm), mostly falling on Fri morning. Very mild (max 14°C on Thu afternoon, min 9°C on Wed night). Wind will be generally light.',
#  'Light rain (total 2.1mm), mostly falling on Sat afternoon. Very mild (max 17°C on Tue morning, min 7°C on Fri night). Wind will be generally light.']

# %% [markdown]
# Buscamos ahora datos dentro de la etiqueta ```tbody``` cuya ```class```es la indicada en el ejercicio.

# %%
alist=[]
for i in soup.find_all('tbody', class_="b-metar-table__body")[0]: # Los vientos
    print(i) # i son los tr, que a su vez contienen etiquetas td
    alist.append((i).encode('utf-8'))
# Out:
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Comesana-weather-station">Comesaña wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">3</span> <span class="distu">km</span> <span class="dir">SSW</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">36</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">18.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Calm</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="0.0">0</span> <span class="windu">km/h</span> at SE°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="3.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">5</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Vigo-Peinador-Airport">Vigo/Peinador Airport</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">9</span> <span class="distu">km</span> <span class="dir">E</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">712</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value"><span class="temp"></span>-</div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"><div class="weather-wrapper"><img alt="clear" src="https://www.weather-forecast.com/assets/wxvicons/dayclear-894dab60a9a23c3c4a197e71f47a5394e100502b19da44699a16735ef8fe3e39.svg"/></div></div><span class="b-metar-table__weather-text">-</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="15.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(160)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">15</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Light winds from the NNW.(Wind varies from 300 to 010 degs)</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="15.0">15</span> <span class="windu">km/h</span> at NNW°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"><div class="vis"><span class="phrase">0.0 km</span></div></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name">VigoPeinador</strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">9</span> <span class="distu">km</span> <span class="dir">ENE</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">258</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">2 hours ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">15.3</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">-</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="17.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(160)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">15</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Light winds from the NNW</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="17.0">17</span> <span class="windu">km/h</span> at NNW°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Guimarey-weather-station">Guimarey wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">56</span> <span class="distu">km</span> <span class="dir">NNE</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">216</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">38 minutes ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color6"><span class="temp">14.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(351)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Calm</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="0.0">0</span> <span class="windu">km/h</span> at S°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="2.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(351)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Ortono-weather-station">Ortoño wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">70</span> <span class="distu">km</span> <span class="dir">N</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">30</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">16.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(180)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Calm</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="0.0">0</span> <span class="windu">km/h</span> at N°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(180)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Orense">Orense</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">73</span> <span class="distu">km</span> <span class="dir">E</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">127</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">2 hours ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">17.8</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">-</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="7.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(190)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">5</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Light winds from the N</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="7.0">7</span> <span class="windu">km/h</span> at N°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"><div class="vis"><span class="phrase">36 km</span></div></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Santiago-de-Compostela-Airport-Lavacolla">Santiago de Compostela Airport - Lavacolla</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">78</span> <span class="distu">km</span> <span class="dir">NNE</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">714</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">2 hours ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color6"><span class="temp">13.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"><div class="weather-wrapper"><img alt="partially cloudy" src="https://www.weather-forecast.com/assets/wxvicons/daypartcloud-3a3c6410aba10f6a3b8eeef4c10b11cd935d9ae298098be0e5078a828e49a38c.svg"/></div></div><span class="b-metar-table__weather-text">Dry and partly cloudy.</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="9.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(210)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">10</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Light winds from the NNE.(Wind varies from 350 to 060 degs)</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="9.0">9</span> <span class="windu">km/h</span> at NNE°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"><div class="vis"><span class="phrase">10.0 km</span></div><div class="low">Low: broken</div></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Mesao-Frio-weather-station">Mesão Frio wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">94</span> <span class="distu">km</span> <span class="dir">SSE</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">281</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">46 minutes ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">16.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="6.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(48)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">5</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Light winds from the SW</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="6.0">6</span> <span class="windu">km/h</span> at SW°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="13.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(48)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">15</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Mesao-Frio-weather-station-1">Mesão Frio wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">94</span> <span class="distu">km</span> <span class="dir">SSE</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">281</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">3 hours ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">18.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="14.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(103)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">15</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Light winds from the WNW</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="14.0">14</span> <span class="windu">km/h</span> at WNW°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="26.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(103)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(0, 255, 0)" text-anchor="middle" x="0" y="5">25</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>
# <tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Porto-Pedras-Rubras-Airport">Porto/Pedras Rubras Airport</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">112</span> <span class="distu">km</span> <span class="dir">S</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">218</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value"><span class="temp"></span>-</div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"><div class="weather-wrapper"><img alt="clear" src="https://www.weather-forecast.com/assets/wxvicons/dayclear-894dab60a9a23c3c4a197e71f47a5394e100502b19da44699a16735ef8fe3e39.svg"/></div></div><span class="b-metar-table__weather-text">-</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="28.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(160)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(0, 255, 0)" text-anchor="middle" x="0" y="5">30</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Moderate winds from the NNW</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="28.0">28</span> <span class="windu">km/h</span> at NNW°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"><div class="vis"><span class="phrase">0.0 km</span></div></div></td></tr>

# %%
alist[0]
# Out:
# b'<tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Comesana-weather-station">Comesa\xc3\xb1a wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">3</span> <span class="distu">km</span> <span class="dir">SSW</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">36</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">18.0</span>\xc2\xb0\xe2\x80\x89<span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Calm</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="0.0">0</span> <span class="windu">km/h</span> at SE\xc2\xb0).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="3.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">5</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr>'

# %%
city_weather_info=alist[0] # vamos al primer tr
soup1 = bs(city_weather_info,'lxml')

# %%
soup1
# Out:
# <html><body><tr class="b-metar-table__row"><td class="b-metar-table__weather-station"><div><strong class="b-metar-table__weather-station-name"><a href="/weather-stations/Comesana-weather-station">Comesaña wx</a></strong> </div><div class="b-metar-table__weather-station-detail"><span class="dist">3</span> <span class="distu">km</span> <span class="dir">SSW</span></div><div class="b-metar-table__weather-station-elevation"><span><span class="height">36</span><span class="heightu">m</span> alt.</span></div><div class="b-metar-table__weather-station-time">1 hour ago</div></td><td class="b-metar-table__temperature"><div class="b-metar-table__temperature-value temp-color5"><span class="temp">18.0</span>° <span class="tempu">C</span></div></td><td class="b-metar-table__weather"><div class="b-metar-table__weather-container"><div class="b-metar-table__weather-icon"></div><span class="b-metar-table__weather-text">Dry</span></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon"><div class="wind-icon" data-precision="5" data-speed="0.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">0</text></svg></div></div><div class="b-metar-table__wind-text-units"><span class="windu">km/h</span></div><div class="b-metar-table__wind-text"><div>Calm</div> <div class="b-metar-table__wind-detail">(<span class="windp" data-precise="0.0">0</span> <span class="windu">km/h</span> at SE°).</div></div></div></td><td class="b-metar-table__wind"><div class="b-metar-table__wind-container"><div class="b-metar-table__wind-icon b-metar-table__wind-icon__gusts"><div class="wind-icon" data-precision="5" data-speed="3.0"><svg class="wind-icon__svg" fill="rgb(0, 0, 0)" viewbox="-19 -19 38 38" xmlns="http://www.w3.org/2000/svg"><circle cx="0" cy="0" r="10.5"></circle><g class="wind-icon__arrow" transform="rotate(315)"><polygon points="-7 -13.5 0 -19.5 7 -13.5"></polygon><rect height="4" width="4" x="-2" y="-13.5"></rect></g><text class="wind-icon__val" fill="rgb(255, 255, 255)" text-anchor="middle" x="0" y="5">5</text></svg></div></div></div></td><td class="b-metar-table__additionally"><div class="b-metar-table__additionally-container"></div></td></tr></body></html>

# %% [markdown]
# Obtenemos los datos contenidos en la fila

# %%
station=soup1.find('td', class_="b-metar-table__weather-station")
print("estación", station.text)

temp=soup1.find('span', class_="temp")
tem=temp.text
tem=tem + ' C'

wind=soup1.find('div', class_="b-metar-table__wind-text")
print("viento", wind.text)

cloud_visi=soup1.find('div', class_="b-metar-table__additionally-container")
print("nubosidad", cloud_visi.text)
# Out:
# estación Comesaña wx 3 km SSW36m alt.1 hour ago
# viento Calm (0 km/h at SE°).
# nubosidad

# %% [markdown]
# Vamos ahora a almacenar los datos.

# %%
import csv

with open(f"Weather_Forecast_{city}.csv", "a", newline='') as file: # a es de append para añadir
    # columnas
    field_names = ['Weather Today days', 'Weather days', '10 Day Weather days', 'Weather_Station_Info', 'Temperature', 'Wind', 'Cloud_Visibility']
    writer = csv.DictWriter(file, fieldnames=field_names)
    writer.writeheader()

    # escribimos toda la información en una fila
    writer.writerow(
        {
            'Weather Today days': w_desc[0],
            'Weather days': w_desc[1],
            '10 Day Weather days': w_desc[2],
            'Weather_Station_Info': station.text,
            'Temperature': tem,
            'Wind': wind.text,
            'Cloud_Visibility': cloud_visi.text
        }
    )
