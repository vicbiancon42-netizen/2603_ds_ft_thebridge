# %% [markdown]
# ![imagen](img/python.jpg)

# %% [markdown]
# ## ¡A practicar! :-)

# %% [markdown]
# ## Ejercicio 1
#
# ### Nota: **NO** es necesario obtener una clave API
# #### No es necesario tener una cuenta de Spotify. Solo hay que consultar la documentación pública.
#
# Utiliza la API de Spotify para ver cómo puedes...
#
# a) Crear una lista de reproducción.
# Por favor, especifica la **consulta**, el **endpoint**, los **parámetros** que existen, **de qué tipo** son y si son **obligatorios**.
#
# b) ¿Qué solicitud de API utilizarías si quisieras saber en qué países está disponible Spotify?

# %% [markdown]
# ## Ejercicio 2
#
# Utiliza un SDK para interactuar con la API de The Movie Database. Crea un proyecto con UV, crea un entorno virtual, instala un paquete de Python para interactuar con The Movie Database y también un paquete de Python para interactuar con .env
#
# Sugerencia: instala tmdbv3api
#
# Documentación: https://github.com/AnthonyBloomer/tmdbv3api
#
# Obtén datos sobre recomendaciones (de películas similares) y datos de películas populares

# %%
# Mira que tengas una API  key para el servicio
# Nota: themoviedatabase puede trabajar tanto con Bearer tokens (version 3 y version 4) or API Keys (version 3)

# https://www.themoviedb.org/settings/api

# %% [markdown]
# ## Ejercicio 3
#
# Para agilizar el proceso, puedes escribir el código directamente en una celda de este cuaderno de Jupyter (no es necesario crear un proyecto con uv)
#
# Utilizando requests, obtén las primeras 100 páginas con películas cuyo año de estreno (el primer año en que se estrenaron) sea 2026. Ordénalas por popularidad en orden descendente.

# %%
# Out:
# year: 2026
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/6yeVcxFR0j08vlv2OlL6zbewm4D.jpg',
#               'genre_ids': [28, 878, 53],
#               'id': 1265609,
#               'original_language': 'en',
#               'original_title': 'War Machine',
#               'overview': 'On one last grueling mission during Army Ranger '
#                           'training, a combat engineer must lead his unit in a '
#                           'fight against a giant otherworldly killing machine.',
#               'popularity': 361.6614,
#               'poster_path': '/tlPgDzwIE7VYYIIAGCTUOnN4wI1.jpg',
#               'release_date': '2026-02-12',
#               'title': 'War Machine',
#               'video': False,
#               'vote_average': 7.253,
#               'vote_count': 1008},
#              {'adult': False,
#               'backdrop_path': '/wsQPh8gz0sK3C3mAyaXcPSSOWUZ.jpg',
#               'genre_ids': [28, 80, 53],
#               'id': 1290821,
#               'original_language': 'en',
#               'original_title': 'Shelter',
#               'overview': 'A man living in self-imposed exile on a remote '
#                           'island rescues a young girl from a violent storm, '
#                           'setting off a chain of events that forces him out '
#                           'of seclusion to protect her from enemies tied to '
#                           'his past.',
#               'popularity': 296.3502,
#               'poster_path': '/buPFnHZ3xQy6vZEHxbHgL1Pc6CR.jpg',
#               'release_date': '2026-01-28',
#               'title': 'Shelter',
#               'video': False,
#               'vote_average': 6.564,
#               'vote_count': 330},
#              {'adult': False,
#               'backdrop_path': '/hz7TdCrpLLt2Dz7S3PS2HG9rpAO.jpg',
#               'genre_ids': [27, 9648, 80],
#               'id': 1159559,
#               'original_language': 'en',
#               'original_title': 'Scream 7',
#               'overview': 'When a new Ghostface killer emerges in the quiet '
#                           'town where Sidney Prescott has built a new life, '
#                           'her darkest fears are realized as her daughter '
#                           'becomes the next target. Determined to protect her '
#                           'family, Sidney must face the horrors of her past to '
#                           'put an end to the bloodshed once and for all.',
#               'popularity': 231.1484,
#               'poster_path': '/jjyuk0edLiW8vOSnlfwWCCLpbh5.jpg',
#               'release_date': '2026-02-25',
#               'title': 'Scream 7',
#               'video': False,
#               'vote_average': 5.885,
#               'vote_count': 383},
#              {'adult': False,
#               'backdrop_path': '/1fkuBPid72KGS6WmtkEXMftZtkE.jpg',
#               'genre_ids': [80, 18],
#               'id': 875828,
#               'original_language': 'en',
#               'original_title': 'Peaky Blinders: The Immortal Man',
#               'overview': 'After his estranged son gets embroiled in a Nazi '
#                           'plot, self-exiled gangster Tommy Shelby must return '
#                           'to Birmingham to save his family — and his nation.',
#               'popularity': 225.5177,
#               'poster_path': '/gRMalasZEzsZi4w2VFuYusfSfqf.jpg',
#               'release_date': '2026-03-05',
#               'title': 'Peaky Blinders: The Immortal Man',
#               'video': False,
#               'vote_average': 7.116,
#               'vote_count': 108},
#              {'adult': False,
#               'backdrop_path': '/8Tfys3mDZVp4tNoH2ktm06a0Tau.jpg',
#               'genre_ids': [878, 12, 9648],
#               'id': 687163,
#               'original_language': 'en',
#               'original_title': 'Project Hail Mary',
#               'overview': 'Science teacher Ryland Grace wakes up on a '
#                           'spaceship light years from home with no '
#                           'recollection of who he is or how he got there. As '
#                           'his memory returns, he begins to uncover his '
#                           'mission: solve the riddle of the mysterious '
#                           'substance causing the sun to die out. He must call '
#                           'on his scientific knowledge and unorthodox ideas to '
#                           'save everything on Earth from extinction… but an '
#                           'unexpected friendship means he may not have to do '
#                           'it alone.',
#               'popularity': 210.0281,
#               'poster_path': '/huVzcVrlK8aiLd240ienleODvWl.jpg',
#               'release_date': '2026-03-15',
#               'title': 'Project Hail Mary',
#               'video': False,
#               'vote_average': 8.247,
#               'vote_count': 164},
#              {'adult': False,
#               'backdrop_path': '/1x9e0qWonw634NhIsRdvnneeqvN.jpg',
#               'genre_ids': [10749, 18],
#               'id': 1523145,
#               'original_language': 'ru',
#               'original_title': 'Твое сердце будет разбито',
#               'overview': 'High school student Polina is saved from bullying '
#                           'at her new school and makes a deal with the main '
#                           'bully Bars: he must pretend to be her boyfriend and '
#                           'protect her, and she must do everything he says. '
#                           'During this game, the couple develops real '
#                           'feelings, but her family and classmates have '
#                           'reasons to separate the lovers.',
#               'popularity': 198.372,
#               'poster_path': '/iGpMm603GUKH2SiXB2S5m4sZ17t.jpg',
#               'release_date': '2026-03-26',
#               'title': 'Your Heart Will Be Broken',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/52AkwEfQiJl2HuTPMZ2yC5Bdr9I.jpg',
#               'genre_ids': [80, 53],
#               'id': 1171145,
#               'original_language': 'en',
#               'original_title': 'Crime 101',
#               'overview': 'When an elusive thief whose high-stakes heists '
#                           'unfold along the iconic 101 freeway in Los Angeles '
#                           'eyes the score of a lifetime, with hopes of this '
#                           'being his final job, his path collides with a '
#                           'disillusioned insurance broker who is facing her '
#                           'own crossroads. Determined to crack the case, a '
#                           'relentless detective closes in on the operation, '
#                           'raising the stakes even higher.',
#               'popularity': 196.2929,
#               'poster_path': '/heMdO64ys1hR896YE2jvTv8JlBX.jpg',
#               'release_date': '2026-02-11',
#               'title': 'Crime 101',
#               'video': False,
#               'vote_average': 7.0,
#               'vote_count': 189},
#              {'adult': False,
#               'backdrop_path': '/u9jE0R1nvkmdWu3bt7Op8joPywa.jpg',
#               'genre_ids': [12, 53, 878],
#               'id': 840464,
#               'original_language': 'en',
#               'original_title': 'Greenland 2: Migration',
#               'overview': 'Having found the safety of the Greenland bunker '
#                           'after the comet Clarke decimated the Earth, the '
#                           'Garrity family must now risk everything to embark '
#                           'on a perilous journey across the wasteland of '
#                           'Europe to find a new home.',
#               'popularity': 159.0856,
#               'poster_path': '/z2tqCJLsw6uEJ8nJV8BsQXGa3dr.jpg',
#               'release_date': '2026-01-07',
#               'title': 'Greenland 2: Migration',
#               'video': False,
#               'vote_average': 6.387,
#               'vote_count': 639},
#              {'adult': False,
#               'backdrop_path': '/2RrLuIfIzGWWIH8IAEo6o0IYHmx.jpg',
#               'genre_ids': [16, 10751, 878, 35],
#               'id': 1327819,
#               'original_language': 'en',
#               'original_title': 'Hoppers',
#               'overview': "Scientists have discovered how to 'hop' human "
#                           'consciousness into lifelike robotic animals, '
#                           'allowing people to communicate with animals as '
#                           'animals. Animal lover Mabel seizes an opportunity '
#                           'to use the technology, uncovering mysteries within '
#                           'the animal world beyond anything she could have '
#                           'imagined.',
#               'popularity': 134.1029,
#               'poster_path': '/xjtWQ2CL1mpmMNwuU5HeS4Iuwuu.jpg',
#               'release_date': '2026-03-04',
#               'title': 'Hoppers',
#               'video': False,
#               'vote_average': 7.694,
#               'vote_count': 232},
#              {'adult': False,
#               'backdrop_path': '/7HKpc11uQfxnw0Y8tRUYn1fsKqE.jpg',
#               'genre_ids': [878, 28, 53],
#               'id': 1236153,
#               'original_language': 'en',
#               'original_title': 'Mercy',
#               'overview': 'In the near future, a detective stands on trial '
#                           'accused of murdering his wife. He has ninety '
#                           'minutes to prove his innocence to the advanced AI '
#                           'Judge he once championed, before it determines his '
#                           'fate.',
#               'popularity': 116.9637,
#               'poster_path': '/91gH7E7Jqc2QSuKbp8OWQxbyh1Q.jpg',
#               'release_date': '2026-01-20',
#               'title': 'Mercy',
#               'video': False,
#               'vote_average': 7.09,
#               'vote_count': 765},
#              {'adult': False,
#               'backdrop_path': '/yJi6g0CnsqANLNuVaRX28tZxeHX.jpg',
#               'genre_ids': [27, 9648],
#               'id': 1193501,
#               'original_language': 'en',
#               'original_title': 'Whistle',
#               'overview': 'A misfit group of unwitting high school students '
#                           'stumble upon a cursed object, an ancient Aztec '
#                           'Death Whistle. They discover that blowing the '
#                           'whistle and the terrifying sound it emits will '
#                           'summon their future deaths to hunt them down.',
#               'popularity': 118.0037,
#               'poster_path': '/eGxPyseSnEZBMJaopGfRUO9HSYx.jpg',
#               'release_date': '2026-01-20',
#               'title': 'Whistle',
#               'video': False,
#               'vote_average': 6.098,
#               'vote_count': 164},
#              {'adult': False,
#               'backdrop_path': '/vSQSYd2zZTqc0zmHImwWEGGluMI.jpg',
#               'genre_ids': [10749, 18],
#               'id': 1316092,
#               'original_language': 'en',
#               'original_title': '"Wuthering Heights"',
#               'overview': 'Tragedy strikes when Heathcliff falls in love with '
#                           'Catherine Earnshaw, a woman from a wealthy family '
#                           'in 18th-century England.',
#               'popularity': 121.4815,
#               'poster_path': '/3YBce6dTh1D5oCMITXk2S5QhPt.jpg',
#               'release_date': '2026-02-11',
#               'title': '"Wuthering Heights"',
#               'video': False,
#               'vote_average': 6.352,
#               'vote_count': 533},
#              {'adult': False,
#               'backdrop_path': '/nTbO6UF944b0VZrgypMK5rFYRSW.jpg',
#               'genre_ids': [9648, 18, 27],
#               'id': 680493,
#               'original_language': 'en',
#               'original_title': 'Return to Silent Hill',
#               'overview': 'When James receives a mysterious letter from his '
#                           'lost love Mary, he is drawn to Silent Hill—a '
#                           'once-familiar town now consumed by darkness. As he '
#                           'searches for her, James faces monstrous creatures '
#                           'and unravels a terrifying truth that will push him '
#                           'to the edge of his sanity.',
#               'popularity': 111.9551,
#               'poster_path': '/fqAGFN2K2kDL0EHxvJaXzaMUkkt.jpg',
#               'release_date': '2026-01-21',
#               'title': 'Return to Silent Hill',
#               'video': False,
#               'vote_average': 5.022,
#               'vote_count': 276},
#              {'adult': False,
#               'backdrop_path': '/1gLFGrxHqQebqLWpISmoFR6XWtJ.jpg',
#               'genre_ids': [28, 53],
#               'id': 1088434,
#               'original_language': 'en',
#               'original_title': 'Hellfire',
#               'overview': 'A drifter with a mysterious past arrives in a small '
#                           'town and finds the residents in the grip of a '
#                           'ruthless crime boss and realizes he has to help '
#                           'them.',
#               'popularity': 105.8982,
#               'poster_path': '/tQti9QTf13MfzNpXguijgNh7ojE.jpg',
#               'release_date': '2026-02-05',
#               'title': 'Hellfire',
#               'video': False,
#               'vote_average': 6.941,
#               'vote_count': 59},
#              {'adult': False,
#               'backdrop_path': '/cz4vLJrmaV1zJlRYbxqtvLzeLWB.jpg',
#               'genre_ids': [28, 35, 80, 9648],
#               'id': 1168190,
#               'original_language': 'en',
#               'original_title': 'The Wrecking Crew',
#               'overview': 'Estranged half-brothers Jonny and James reunite '
#                           "after their father's mysterious death. As they "
#                           'search for the truth, buried secrets reveal a '
#                           'conspiracy threatening to tear their family apart.',
#               'popularity': 105.6919,
#               'poster_path': '/gbVwHl4YPSq6BcC92TQpe7qUTh6.jpg',
#               'release_date': '2026-01-28',
#               'title': 'The Wrecking Crew',
#               'video': False,
#               'vote_average': 6.872,
#               'vote_count': 800},
#              {'adult': False,
#               'backdrop_path': '/owQeDouUZ6wI6f1aTOYEFd511zn.jpg',
#               'genre_ids': [28, 80, 53],
#               'id': 1582770,
#               'original_language': 'hi',
#               'original_title': 'धुरंधर: द रिवेंज',
#               'overview': 'As rival gangs, corrupt officials and a ruthless '
#                           "Major Iqbal close in, Hamza's mission for his "
#                           'country spirals into a bloody personal war where '
#                           'the line between patriot and monster disappears in '
#                           'the streets of Lyari.',
#               'popularity': 90.7023,
#               'poster_path': '/ov8vrRLZGoXHpYjSY9Vpv1tHJX7.jpg',
#               'release_date': '2026-03-18',
#               'title': 'Dhurandhar: The Revenge',
#               'video': False,
#               'vote_average': 7.5,
#               'vote_count': 10},
#              {'adult': False,
#               'backdrop_path': '/lmns2jlRmATs8OGWKcCkgrbHLM4.jpg',
#               'genre_ids': [28, 18],
#               'id': 1634301,
#               'original_language': 'te',
#               'original_title': 'Vanaveera',
#               'overview': 'A descendant of the Vanara clan is pushed into '
#                           'conflict when a modern-day Ravana seizes his only '
#                           'bike for an election rally. What starts as a petty '
#                           'injustice soon erupts into a fierce fight for '
#                           'self-respect and dignity.',
#               'popularity': 94.7946,
#               'poster_path': '/oBYExKI8E3bTzQjPkofhpV2EJon.jpg',
#               'release_date': '2026-02-13',
#               'title': 'Vanaveera',
#               'video': False,
#               'vote_average': 7.0,
#               'vote_count': 3},
#              {'adult': False,
#               'backdrop_path': '/jenQoCLJ4FEfFGZS13op91jlxjy.jpg',
#               'genre_ids': [878, 28, 12],
#               'id': 969681,
#               'original_language': 'en',
#               'original_title': 'Spider-Man: Brand New Day',
#               'overview': 'Four years have passed since the events of No Way '
#                           'Home, and Peter is now an adult living entirely '
#                           'alone, having voluntarily erased himself from the '
#                           'lives and memories of those he loves. '
#                           'Crime-fighting in a New York that no longer knows '
#                           "his name, he's devoted himself entirely to "
#                           'protecting his city — a full-time Spider-Man — but '
#                           'as the demands on him intensify, the pressure '
#                           'sparks a surprising physical evolution that '
#                           'threatens his existence, even as a strange new '
#                           'pattern of crimes gives rise to one of the most '
#                           'powerful threats he has ever faced.',
#               'popularity': 75.5399,
#               'poster_path': '/ucQ0QBXXQPSxeUmWfh4YQenIuB9.jpg',
#               'release_date': '2026-07-29',
#               'title': 'Spider-Man: Brand New Day',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/drRxbu2OHG0DEENptZ8wI5f0uEU.jpg',
#               'genre_ids': [878, 28, 35],
#               'id': 1119449,
#               'original_language': 'en',
#               'original_title': "Good Luck, Have Fun, Don't Die",
#               'overview': "A 'Man from the Future' arrives at an LA diner "
#                           'where he must recruit the precise combination of '
#                           'disgruntled patrons to join him on a one-night '
#                           'quest to save the world from the terminal threat of '
#                           'a rogue artificial intelligence.',
#               'popularity': 56.9099,
#               'poster_path': '/rWcfOdY7TU6lTdazWj0ebDZnAfO.jpg',
#               'release_date': '2026-02-13',
#               'title': "Good Luck, Have Fun, Don't Die",
#               'video': False,
#               'vote_average': 6.878,
#               'vote_count': 200},
#              {'adult': False,
#               'backdrop_path': '/3F2EXWF1thX0BdrVaKvnm6mAhqh.jpg',
#               'genre_ids': [28, 53, 80],
#               'id': 1306368,
#               'original_language': 'en',
#               'original_title': 'The Rip',
#               'overview': 'Trust frays when a team of Miami cops discovers '
#                           'millions in cash inside a run-down stash house, '
#                           'calling everyone — and everything — into question.',
#               'popularity': 59.0903,
#               'poster_path': '/eZo31Dhl5BQ6GfbMNf3oU0tUvPZ.jpg',
#               'release_date': '2026-01-13',
#               'title': 'The Rip',
#               'video': False,
#               'vote_average': 7.07,
#               'vote_count': 1397}],
#  'total_pages': 519,
#  'total_results': 10370}
# {'page': 2,
#  'results': [{'adult': False,
#               'backdrop_path': '/y1Vj3R6puWZebFH8OQirt6hMtwj.jpg',
#               'genre_ids': [35],
#               'id': 1217584,
#               'original_language': 'es',
#               'original_title': 'Torrente Presidente',
#               'overview': 'Years have passed since his last adventure, but '
#                           'José Luis Torrente, the most politically incorrect '
#                           'former cop in Spain, still sees himself as a '
#                           'national hero.',
#               'popularity': 56.3669,
#               'poster_path': '/yrDKwAdZRJjoQ9RZwzRGPpMC7U1.jpg',
#               'release_date': '2026-03-13',
#               'title': 'Torrente for President',
#               'video': False,
#               'vote_average': 6.5,
#               'vote_count': 11},
#              {'adult': False,
#               'backdrop_path': '/hHDNOlATHhre4eZ7aYz5cdyJLik.jpg',
#               'genre_ids': [27, 53, 878],
#               'id': 1272837,
#               'original_language': 'en',
#               'original_title': '28 Years Later: The Bone Temple',
#               'overview': 'Dr. Kelson finds himself in a shocking new '
#                           'relationship - with consequences that could change '
#                           "the world as they know it - and Spike's encounter "
#                           "with Jimmy Crystal becomes a nightmare he can't "
#                           'escape.',
#               'popularity': 56.0637,
#               'poster_path': '/kK1BGkG3KAvWB0WMV1DfOx9yTMZ.jpg',
#               'release_date': '2026-01-14',
#               'title': '28 Years Later: The Bone Temple',
#               'video': False,
#               'vote_average': 7.2,
#               'vote_count': 850},
#              {'adult': False,
#               'backdrop_path': '/ptcyGmBonW6mDQmrPhXbt6Rjrlp.jpg',
#               'genre_ids': [18, 53],
#               'id': 1314786,
#               'original_language': 'es',
#               'original_title': 'Zeta',
#               'overview': 'Four Spanish ex-intelligence officers are '
#                           'assassinated simultaneously worldwide. The CNI '
#                           'discovers all participated in the covert "Operation '
#                           'Ciénaga" decades ago in Colombia. Zeta, the CNI\'s '
#                           'best operative, must hunt and protect the sole '
#                           'survivor, facing his deadliest global mission yet. '
#                           'Top Colombian agent Alfa will join Zeta, seemingly '
#                           'knowing more about "Ciénaga"\'s secrets than him.',
#               'popularity': 55.6535,
#               'poster_path': '/1cKLG9KMoCjsgFB8Nw1EuglteVi.jpg',
#               'release_date': '2026-03-20',
#               'title': 'Agent Zeta',
#               'video': False,
#               'vote_average': 6.5,
#               'vote_count': 10},
#              {'adult': False,
#               'backdrop_path': '/eUERZRVjCTNdgnESlQxyaOJ2d4K.jpg',
#               'genre_ids': [28],
#               'id': 1584215,
#               'original_language': 'en',
#               'original_title': 'The Internship',
#               'overview': 'A CIA-trained assassin recruits other graduates '
#                           'from her secret childhood program, The Internship, '
#                           'to violently destroy the organization. The CIA '
#                           'fights back with deadly force.',
#               'popularity': 55.5703,
#               'poster_path': '/fYqSOkix4rbDiZW0ACNnvZCpT6X.jpg',
#               'release_date': '2026-01-13',
#               'title': 'The Internship',
#               'video': False,
#               'vote_average': 6.142,
#               'vote_count': 60},
#              {'adult': False,
#               'backdrop_path': '/yHlVD4zBJ2MMevQo2uVb8m8LWOm.jpg',
#               'genre_ids': [27, 878, 35],
#               'id': 696393,
#               'original_language': 'en',
#               'original_title': 'Cold Storage',
#               'overview': 'When a mutating, highly contagious fungus escapes a '
#                           'sealed facility, two employees – joined by a '
#                           'grizzled bioterror operative – must survive the '
#                           'wildest night shift ever to save humanity from '
#                           'extinction.',
#               'popularity': 54.2167,
#               'poster_path': '/pfqkETJ2A3zXZJuNcufZbAJNnKA.jpg',
#               'release_date': '2026-01-22',
#               'title': 'Cold Storage',
#               'video': False,
#               'vote_average': 6.7,
#               'vote_count': 220},
#              {'adult': False,
#               'backdrop_path': '/d3hiSKKyIjvB3Lv577vHh0TxbFM.jpg',
#               'genre_ids': [10749],
#               'id': 1650558,
#               'original_language': 'tl',
#               'original_title': 'Abot Langit',
#               'overview': 'The relationship of a couple is tested when the '
#                           'girl’s first official flight pairs her with a '
#                           'confident senior pilot, jealousy and power dynamics '
#                           'surface in the training ground. The girl is now '
#                           'torn between her present relationship and new '
#                           'temptation she can’t resist.',
#               'popularity': 50.2202,
#               'poster_path': '/5lVYe4aSimWdxJINKwq9s68TZ2G.jpg',
#               'release_date': '2026-03-13',
#               'title': 'Abot Langit',
#               'video': False,
#               'vote_average': 5.0,
#               'vote_count': 1},
#              {'adult': False,
#               'backdrop_path': '/6D6M5z4reppUxo2cnBEKI02Csp1.jpg',
#               'genre_ids': [28, 80, 53, 37],
#               'id': 1601243,
#               'original_language': 'en',
#               'original_title': 'Oscar Shaw',
#               'overview': 'After retiring from the police force, a relentless '
#                           'detective haunted by the tragic loss of his closest '
#                           'friend sets out on a perilous quest for vengeance, '
#                           'seeking redemption and fighting to restore justice '
#                           'to the streets he once swore to protect.',
#               'popularity': 48.6379,
#               'poster_path': '/tsE3nySukwrfUjouz8vzvKTcXNC.jpg',
#               'release_date': '2026-01-09',
#               'title': 'Oscar Shaw',
#               'video': False,
#               'vote_average': 6.741,
#               'vote_count': 27},
#              {'adult': False,
#               'backdrop_path': '/1Xdsq7U7bvJJd2X7Jg4qNaKVkYO.jpg',
#               'genre_ids': [28, 53, 80, 18],
#               'id': 1426964,
#               'original_language': 'pt',
#               'original_title': 'Salve Geral: Irmandade',
#               'overview': 'As São Paulo erupts in an unprecedented wave of '
#                           'violence, a lawyer with underworld ties must strike '
#                           'a deal with the police to rescue her kidnapped '
#                           'niece.',
#               'popularity': 52.9326,
#               'poster_path': '/3Eaqedg8MAlnP51GYY8MCSIdTnV.jpg',
#               'release_date': '2026-02-10',
#               'title': 'State of Fear',
#               'video': False,
#               'vote_average': 5.424,
#               'vote_count': 59},
#              {'adult': False,
#               'backdrop_path': '/5rxEnsgriw8z065q51lrvPKYmCL.jpg',
#               'genre_ids': [10749, 18],
#               'id': 1367642,
#               'original_language': 'en',
#               'original_title': 'Reminders of Him',
#               'overview': "When Diem's custodial grandparents adamantly refuse "
#                           "Kenna's attempts to see her daughter, Kenna "
#                           'discovers unexpected compassion, and then something '
#                           'truer and deeper, with former NFL player and local '
#                           'bar owner Ledger. As their secret romance develops, '
#                           'so do the dangers for both of them, leading Kenna '
#                           'toward heartbreak and, ultimately, the hope for a '
#                           'second chance.',
#               'popularity': 46.7346,
#               'poster_path': '/7L6rceYgzQ0NeHD7PRDNrRoQ291.jpg',
#               'release_date': '2026-03-11',
#               'title': 'Reminders of Him',
#               'video': False,
#               'vote_average': 7.0,
#               'vote_count': 52},
#              {'adult': False,
#               'backdrop_path': '/waUDWpsm3oCrzU9P4XnsBAh2cso.jpg',
#               'genre_ids': [27, 35],
#               'id': 1266127,
#               'original_language': 'en',
#               'original_title': 'Ready or Not: Here I Come',
#               'overview': 'Moments after surviving an all-out attack from the '
#                           'Le Domas family, Grace discovers she’s reached the '
#                           'next level of the nightmarish game — and this time '
#                           'with her estranged sister Faith at her side. Grace '
#                           'has one chance to survive, keep her sister alive, '
#                           'and claim the High Seat of the Council that '
#                           'controls the world. Four rival families are hunting '
#                           'her for the throne, and whoever wins rules it all.',
#               'popularity': 41.9981,
#               'poster_path': '/13ZcJzSGEqVgDSqsS9U5EkQwPkV.jpg',
#               'release_date': '2026-03-19',
#               'title': 'Ready or Not: Here I Come',
#               'video': False,
#               'vote_average': 7.5,
#               'vote_count': 14},
#              {'adult': False,
#               'backdrop_path': '/bnJ5nWc7ymPfsovOxgM0LD6Yg8T.jpg',
#               'genre_ids': [12, 878],
#               'id': 1170608,
#               'original_language': 'en',
#               'original_title': 'Dune: Part Three',
#               'overview': 'As Emperor, Paul Atreides grapples with the '
#                           'consequences of his rise to power as political '
#                           'conspiracies and a galaxy-spanning holy war '
#                           'threaten the future he alone can foresee.',
#               'popularity': 41.7436,
#               'poster_path': '/b4wekkUaxExzOeGe7hKXzhnyXHt.jpg',
#               'release_date': '2026-12-16',
#               'title': 'Dune: Part Three',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/6xVAbjvUWKJlPSVYduQgkRzEQNy.jpg',
#               'genre_ids': [18, 53],
#               'id': 1424965,
#               'original_language': 'en',
#               'original_title': 'Ice Skater',
#               'overview': 'A survival drama about an ice skater stranded on an '
#                           'ice floe at the Arctic Sea. When the ice floe '
#                           'starts to float towards south and melt, the ice '
#                           'skater must use all means necessary to survive.',
#               'popularity': 36.1324,
#               'poster_path': '/m93BKabB7Je8WQACed58BXeHNNR.jpg',
#               'release_date': '2026-02-24',
#               'title': 'Ice Skater',
#               'video': False,
#               'vote_average': 5.7,
#               'vote_count': 10},
#              {'adult': False,
#               'backdrop_path': '/1qwhYqg7YEZajh3Q4biqbuQoDq8.jpg',
#               'genre_ids': [16, 35, 10751],
#               'id': 1297842,
#               'original_language': 'en',
#               'original_title': 'GOAT',
#               'overview': 'A small goat with big dreams gets a '
#                           'once-in-a-lifetime shot to join the pros and play '
#                           'roarball, a high-intensity, co-ed, full-contact '
#                           'sport dominated by the fastest, fiercest animals in '
#                           'the world.',
#               'popularity': 42.9783,
#               'poster_path': '/wfuqMlaExcoYiUEvKfVpUTt1v4u.jpg',
#               'release_date': '2026-02-11',
#               'title': 'GOAT',
#               'video': False,
#               'vote_average': 7.5,
#               'vote_count': 114},
#              {'adult': False,
#               'backdrop_path': '/xcBlMEvzuaHoWANKYn5PGvcW4OC.jpg',
#               'genre_ids': [27, 28, 53],
#               'id': 1110034,
#               'original_language': 'no',
#               'original_title': 'Kraken',
#               'overview': 'Marine biologist Johanne is doing research on a '
#                           'fish farm in Vangsnes, a rural community located by '
#                           'the fjord, when she encounters several strange '
#                           'occurrences. Along with the brutal deaths of two '
#                           'local teenagers, all signs point to the deep fjord; '
#                           'can there be more to the depths than the eye can '
#                           'see? At the bottom of the deepest fjord rests a '
#                           'mythical monster as large as a mountain, with a '
#                           'myriad of arms ready to crush and devour anything '
#                           'they can grab.',
#               'popularity': 38.9036,
#               'poster_path': '/jVsflOu9WpMqUJ3WwVX2mITi86S.jpg',
#               'release_date': '2026-02-06',
#               'title': 'Kraken',
#               'video': False,
#               'vote_average': 6.2,
#               'vote_count': 8},
#              {'adult': False,
#               'backdrop_path': '/3eOINbgRs8WiWfQfViXeuZ3enrs.jpg',
#               'genre_ids': [878, 28, 12],
#               'id': 1003596,
#               'original_language': 'en',
#               'original_title': 'Avengers: Doomsday',
#               'overview': 'The Avengers, Wakandans, Fantastic Four, '
#                           'Thunderbolts, and X-Men all fight against Doctor '
#                           'Doom. Plot TBA.',
#               'popularity': 79.126,
#               'poster_path': '/s2Fkuq0tj7mjAHEdbfQkFkdbeRI.jpg',
#               'release_date': '2026-12-16',
#               'title': 'Avengers: Doomsday',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/9Z2uDYXqJrlmePznQQJhL6d92Rq.jpg',
#               'genre_ids': [10751, 14, 35, 12, 16],
#               'id': 1226863,
#               'original_language': 'en',
#               'original_title': 'The Super Mario Galaxy Movie',
#               'overview': "Having thwarted Bowser's previous plot to marry "
#                           'Princess Peach, Mario and Luigi now face a fresh '
#                           'threat in Bowser Jr., who is determined to liberate '
#                           'his father from captivity and restore the family '
#                           'legacy. Alongside companions new and old, the '
#                           'brothers travel across the stars to stop the young '
#                           "heir's crusade.",
#               'popularity': 35.6763,
#               'poster_path': '/eJGWx219ZcEMVQJhAgMiqo8tYY.jpg',
#               'release_date': '2026-04-01',
#               'title': 'The Super Mario Galaxy Movie',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/fTG8itSb1a4O2BgUMjXdwO64qTz.jpg',
#               'genre_ids': [10749, 35],
#               'id': 1291335,
#               'original_language': 'en',
#               'original_title': 'Solo Mio',
#               'overview': "After Matt's dreams of a picturesque Italian "
#                           'wedding are shattered when his fiancée leaves him '
#                           'at the altar, he embarks on his planned honeymoon '
#                           'across Italy alone, immersing himself in the '
#                           "country's vibrant culture, food, and beauty, "
#                           'meeting Gia along the way.',
#               'popularity': 34.3194,
#               'poster_path': '/efSsZJaddeq0LOABZqpCXdMxv9P.jpg',
#               'release_date': '2026-02-05',
#               'title': 'Solo Mio',
#               'video': False,
#               'vote_average': 6.993,
#               'vote_count': 76},
#              {'adult': False,
#               'backdrop_path': '/6AYl4PU29o2WXUPZzAo56GVQs5r.jpg',
#               'genre_ids': [53, 18, 9648],
#               'id': 1381027,
#               'original_language': 'en',
#               'original_title': 'The Good Boy',
#               'overview': 'Tommy, a volatile 19-year-old, revels in drugs, '
#                           'parties and violence. After getting separated from '
#                           'his friends on a drunken bender, he is abducted by '
#                           'a shadowy figure. He wakes to find himself '
#                           'imprisoned in the basement of a remote Yorkshire '
#                           'house, inhabited by a very strange family. But what '
#                           'unfolds is not what he could possibly expect.',
#               'popularity': 35.1648,
#               'poster_path': '/cEXT4bXOrM0pqrK714NP3M69cWW.jpg',
#               'release_date': '2026-03-06',
#               'title': 'The Good Boy',
#               'video': False,
#               'vote_average': 7.797,
#               'vote_count': 37},
#              {'adult': False,
#               'backdrop_path': '/5hH7QiEPOiz7aGa4eJce74kZkO1.jpg',
#               'genre_ids': [878, 27, 14],
#               'id': 1159831,
#               'original_language': 'en',
#               'original_title': 'The Bride!',
#               'overview': 'A lonely Frankenstein travels to 1930s Chicago to '
#                           'ask groundbreaking scientist Dr. Euphronious to '
#                           'create a companion for him. The two revive a '
#                           'murdered young woman and The Bride is born. But '
#                           'what ensues is beyond what either of them imagined.',
#               'popularity': 31.0234,
#               'poster_path': '/lV8YHwGkYZsm6EfIqnhaSz2avKt.jpg',
#               'release_date': '2026-03-04',
#               'title': 'The Bride!',
#               'video': False,
#               'vote_average': 6.305,
#               'vote_count': 177},
#              {'adult': False,
#               'backdrop_path': '/cYyNJzwhaj7aC4uTlUctrfaERbf.jpg',
#               'genre_ids': [28, 18, 36],
#               'id': 1305781,
#               'original_language': 'zh',
#               'original_title': '镖人：风起大漠',
#               'overview': 'Dao Ma, the "second most wanted fugitive," is '
#                           'entrusted by his benefactor, the chief of Mo family '
#                           'clan, to take on a mysterious escort '
#                           'mission-escorting the "most wanted fugitive" to '
#                           "Chang'an.",
#               'popularity': 28.4155,
#               'poster_path': '/AbunjMKX4P1sDNlKfhYrWkIoRD9.jpg',
#               'release_date': '2026-02-17',
#               'title': 'Blades of the Guardians: Wind Rises in the Desert',
#               'video': False,
#               'vote_average': 7.094,
#               'vote_count': 32}],
#  'total_pages': 519,
#  'total_results': 10363}
# {'page': 3,
#  'results': [{'adult': False,
#               'backdrop_path': '/cYyNJzwhaj7aC4uTlUctrfaERbf.jpg',
#               'genre_ids': [28, 18, 36],
#               'id': 1305781,
#               'original_language': 'zh',
#               'original_title': '镖人：风起大漠',
#               'overview': 'Dao Ma, the "second most wanted fugitive," is '
#                           'entrusted by his benefactor, the chief of Mo family '
#                           'clan, to take on a mysterious escort '
#                           'mission-escorting the "most wanted fugitive" to '
#                           "Chang'an.",
#               'popularity': 28.4155,
#               'poster_path': '/AbunjMKX4P1sDNlKfhYrWkIoRD9.jpg',
#               'release_date': '2026-02-17',
#               'title': 'Blades of the Guardians: Wind Rises in the Desert',
#               'video': False,
#               'vote_average': 7.094,
#               'vote_count': 32},
#              {'adult': False,
#               'backdrop_path': '/bAFnjhweXxHUWjmFzMTuX12Ud3b.jpg',
#               'genre_ids': [53],
#               'id': 1199193,
#               'original_language': 'en',
#               'original_title': 'Pose',
#               'overview': 'Isolated in a grand country manor, a reclusive '
#                           'artist spends a passionate and paranoid weekend '
#                           'with his ex-lover, an obsessive fan, and a '
#                           'potential muse. Hoping to spark a new wave of '
#                           'artistic brilliance over the course of a few '
#                           'tumultuous days, filled with chaos and revelation '
#                           'not all of them will make it out alive.',
#               'popularity': 27.9195,
#               'poster_path': '/qhyyyWrHUbl6QG4udAJj17CBa5.jpg',
#               'release_date': '2026-02-25',
#               'title': 'Pose',
#               'video': False,
#               'vote_average': 6.52,
#               'vote_count': 25},
#              {'adult': False,
#               'backdrop_path': '/9uakM2woks0JV8HKIc4oatIVS88.jpg',
#               'genre_ids': [27, 53],
#               'id': 1315303,
#               'original_language': 'en',
#               'original_title': 'Primate',
#               'overview': 'Lucy, a college student, along with her friends, '
#                           "spend their vacation at her family's home in "
#                           'Hawaii, which includes her pet chimpanzee, Ben. '
#                           'However, when Ben contracts rabies after being '
#                           'bitten by a rabid animal, the group must fight for '
#                           'their lives in order to avoid the now-violent '
#                           'chimp.',
#               'popularity': 26.7112,
#               'poster_path': '/z97hrgI5wbGbZvSVkBfAeBnFKAg.jpg',
#               'release_date': '2026-01-01',
#               'title': 'Primate',
#               'video': False,
#               'vote_average': 6.531,
#               'vote_count': 487},
#              {'adult': False,
#               'backdrop_path': '/bpp58yHuQmpt6xwggI63mVRw7po.jpg',
#               'genre_ids': [27, 53, 35],
#               'id': 1198994,
#               'original_language': 'en',
#               'original_title': 'Send Help',
#               'overview': 'Two colleagues become stranded on a deserted '
#                           'island, the only survivors of a plane crash. On the '
#                           'island, they must overcome past grievances and work '
#                           "together to survive, but ultimately, it's a battle "
#                           'of wills and wits to make it out alive.',
#               'popularity': 26.5492,
#               'poster_path': '/mjkS2iAgWj3ik1DTjvI15nHZ7yl.jpg',
#               'release_date': '2026-01-22',
#               'title': 'Send Help',
#               'video': False,
#               'vote_average': 7.063,
#               'vote_count': 367},
#              {'adult': False,
#               'backdrop_path': '/ohUhHOqW8cM59Ay5UjqplLzJbH3.jpg',
#               'genre_ids': [10749, 18],
#               'id': 1317672,
#               'original_language': 'en',
#               'original_title': 'Love Me Love Me',
#               'overview': "After her brother's death, June moves to Milan for "
#                           'a fresh start, finding comfort in Will, the perfect '
#                           'honor student at her new international school. But '
#                           'when his troubled best friend James—hiding a '
#                           'dangerous life in clandestine MMA fights—sparks a '
#                           'rivalry that quickly turns into irresistible '
#                           'attraction, June must choose between safety and a '
#                           'love that upends everything she thought she wanted.',
#               'popularity': 25.7466,
#               'poster_path': '/4QWAPETLYZosiwXQCTMu1KerXxI.jpg',
#               'release_date': '2026-02-12',
#               'title': 'Love Me Love Me',
#               'video': False,
#               'vote_average': 5.572,
#               'vote_count': 180},
#              {'adult': False,
#               'backdrop_path': '/vSMz2G3Dx5l6rkGxdw3zEAl1oiq.jpg',
#               'genre_ids': [35],
#               'id': 1440049,
#               'original_language': 'en',
#               'original_title': 'Preschool',
#               'overview': 'Two determined fathers engage in a comical battle '
#                           'to enroll their kids in an elite preschool, '
#                           'escalating into an absurd competition with '
#                           'unexpected results.',
#               'popularity': 25.3326,
#               'poster_path': '/o6JYj1sZDdLgKb6GW39AfGfrGhw.jpg',
#               'release_date': '2026-03-17',
#               'title': 'Preschool',
#               'video': False,
#               'vote_average': 5.5,
#               'vote_count': 2},
#              {'adult': False,
#               'backdrop_path': '/1jdPUUSy37Wzw3xuc8otI86X2gv.jpg',
#               'genre_ids': [16, 14, 10402, 878],
#               'id': 1575337,
#               'original_language': 'ja',
#               'original_title': '超かぐや姫！',
#               'overview': "Iroha's life gets knocked off its orbit when "
#                           'Kaguya, a carefree runaway from the Moon, moves in '
#                           'and convinces her to perform in a virtual world '
#                           'together.',
#               'popularity': 25.1761,
#               'poster_path': '/9I9cM38gecZcwJ0C6r0cwfvtPJP.jpg',
#               'release_date': '2026-01-22',
#               'title': 'Cosmic Princess Kaguya!',
#               'video': False,
#               'vote_average': 8.3,
#               'vote_count': 56},
#              {'adult': False,
#               'backdrop_path': '/aOZlZ5ceIpUVjJaFBl0vQjGTieI.jpg',
#               'genre_ids': [18],
#               'id': 1561687,
#               'original_language': 'ta',
#               'original_title': 'மேட் இன் கொரியா',
#               'overview': 'A woman from a small town in Tamil Nadu moves to '
#                           'South Korea — a place she always dreamed of — but '
#                           'struggles to find her footing in a foreign land.',
#               'popularity': 23.468,
#               'poster_path': '/foEObhyAMM3dxYeBEr242EdQDB7.jpg',
#               'release_date': '2026-03-12',
#               'title': 'Made in Korea',
#               'video': False,
#               'vote_average': 6.526,
#               'vote_count': 19},
#              {'adult': False,
#               'backdrop_path': '/i275mAQP4KhPtYUpMUgBGMmK4WN.jpg',
#               'genre_ids': [27, 53, 18],
#               'id': 1249508,
#               'original_language': 'en',
#               'original_title': 'Grizzly Night',
#               'overview': "On August 12, 1967, in Montana's Glacier National "
#                           'Park, the unthinkable happened: that same night, '
#                           'nine miles apart, there were not one—but two—fatal '
#                           'grizzly bear attacks.',
#               'popularity': 21.903,
#               'poster_path': '/d3UMQAw5EGRsLEnMfpxorHvbzHg.jpg',
#               'release_date': '2026-07-02',
#               'title': 'Grizzly Night',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/wHdpSwLr0wUKRyG1CGzGjPSkyrK.jpg',
#               'genre_ids': [35, 10749, 18],
#               'id': 1611398,
#               'original_language': 'es',
#               'original_title': 'Un Hombre por Semana',
#               'overview': 'A divorced woman reconstructs her life and opens '
#                           'herself to love. Her search for dating apps takes '
#                           'her through fun and unpredictable moments to '
#                           'discover self-love.',
#               'popularity': 21.3836,
#               'poster_path': '/rHwOvosfDFRsjBihdh9dIHnMgbO.jpg',
#               'release_date': '2026-01-08',
#               'title': 'Un Hombre por Semana',
#               'video': False,
#               'vote_average': 6.143,
#               'vote_count': 7},
#              {'adult': False,
#               'backdrop_path': '/1U12SjJjlfUpcutFLXpBNEmRHQB.jpg',
#               'genre_ids': [27],
#               'id': 999136,
#               'original_language': 'en',
#               'original_title': 'Do Not Enter',
#               'overview': 'A group of young explorers investigates an old '
# ...
#               'title': 'Les femmes savantes',
#               'video': False,
#               'vote_average': 8.0,
#               'vote_count': 1},
#              {'adult': False,
#               'backdrop_path': '/czsmonGUESXBXvkeClze93GuYqE.jpg',
#               'genre_ids': [35],
#               'id': 1652144,
#               'original_language': 'id',
#               'original_title': 'Pulkam',
#               'overview': 'Rispo, a single parent living in a small rented '
#                           'house with his child, struggles through life with '
#                           'many limitations. Every day, he simply tries to '
#                           'survive.  When life feels increasingly difficult, '
#                           'bad news comes from his hometown: his mother has '
#                           'fallen seriously ill and hopes Rispo can return '
#                           'before it’s too late. Rispo then does everything he '
#                           'can to make it back home.  Will Rispo succeed in '
#                           'returning home and meeting his mother?',
#               'popularity': 0.3624,
#               'poster_path': '/lHHxzn09IUKEM5SXGw3iCSNgUo6.jpg',
#               'release_date': '2026-03-21',
#               'title': 'Pulkam',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/9burYB54QVi4Rn2eYCnWGEo4WHb.jpg',
#               'genre_ids': [53],
#               'id': 1449056,
#               'original_language': 'en',
#               'original_title': 'Snapshot',
#               'overview': 'An amateur photographer’s interview with an '
#                           'industry legend spirals into a tense unravelling of '
#                           'his darkest secrets, revealing the disturbing truth '
#                           'behind their meeting.',
#               'popularity': 0.2089,
#               'poster_path': '/cjek01BkcKlTQuUbZHPZlLXS22W.jpg',
#               'release_date': '2026-02-01',
#               'title': 'Snapshot',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [18, 35, 53],
#               'id': 1628034,
#               'original_language': 'en',
#               'original_title': 'A Date with Death',
#               'overview': 'Mori Bund is in over her head when she is selected '
#                           'as a contestant on a game show with a deadly twist',
#               'popularity': 0.2345,
#               'poster_path': '/2gTaEHTeoteAz9JX7umKpPMq5Jr.jpg',
#               'release_date': '2026-01-29',
#               'title': 'A Date with Death',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [27, 18],
#               'id': 1619294,
#               'original_language': 'en',
#               'original_title': 'The Fallen',
#               'overview': 'a secluded Airbnb near cursed woods, a young man '
#                           'battling grief and addiction is lured by a demonic '
#                           'force that feeds on despair. As his faith unravels, '
#                           'only his girlfriend’s devotion to God stands '
#                           'between them and eternal darkness.',
#               'popularity': 0.3012,
#               'poster_path': None,
#               'release_date': '2026-01-17',
#               'title': 'The Fallen',
#               'video': False,
#               'vote_average': 7.0,
#               'vote_count': 1},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [],
#               'id': 1617239,
#               'original_language': 'en',
#               'original_title': 'The Last Critic',
#               'overview': 'Sixty years & a million records ago, Robert '
#                           'Christgau invented Rock music criticism. Anyone who '
#                           'has ever read or written a Pop music review has '
#                           'been influenced by Christgau, who canonized legends '
#                           'from The Ramones to Public Enemy & infuriated icons '
#                           'from Lou Reed to Billy Joel. Now in his eighties, '
#                           'Bob is still at it—amazingly with the same vigor, '
#                           'wit, concision and craft that has defined his '
#                           'expansive career. But in a world where albums are '
#                           'irrelevant, where print is dead & where algorithms '
#                           'have eclipsed critics we are forced to ask: What '
#                           'happens next—for Bob, but also for all music '
#                           'criticism? Is this the end of something? Is Robert '
#                           'Christgau the last critic?',
#               'popularity': 0.3833,
#               'poster_path': '/wXM9rd4GDhzesyyxCrNIdPYI0Na.jpg',
#               'release_date': '2026-03-14',
#               'title': 'The Last Critic',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [99],
#               'id': 1629059,
#               'original_language': 'en',
#               'original_title': 'We Are The Shaggs',
#               'overview': 'We Are The Shaggs is a music documentary about The '
#                           'Shaggs, an all-girl band that created some of the '
#                           'most provocative and polarizing music in '
#                           'rock-and-roll history.',
#               'popularity': 0.2775,
#               'poster_path': None,
#               'release_date': '2026-03-13',
#               'title': 'We Are The Shaggs',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/fA9yiBV7CukVGxOSH85JhqSBkd2.jpg',
#               'genre_ids': [18],
#               'id': 1644713,
#               'original_language': 'sl',
#               'original_title': 'Exodus 1945: Naša kri',
#               'overview': 'May 1945, Ljubljana. Following the end of World War '
#                           'II and the communist seizure of power, many '
#                           'opponents of communism flee Yugoslavia, retreating '
#                           'to Austrian Carinthia toward the British Allies. On '
#                           'a medical train from Ljubljana, alongside wounded '
#                           'members of the Home Guard, travel two physicians: '
#                           'Dr. Janez Janež and Dr. Valentin Meršol with his '
#                           'family. Their principles and consciences are put to '
#                           'the test as they face the brutal truth that they '
#                           'cannot save everyone - the survival of some will '
#                           'mean the death of others.',
#               'popularity': 0.3553,
#               'poster_path': '/j2B4ewVBu6qdQlMkF4tiyEVMSZQ.jpg',
#               'release_date': '2026-02-20',
#               'title': 'Exodus 1945: Our Blood',
#               'video': False,
#               'vote_average': 9.0,
#               'vote_count': 1},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [35],
#               'id': 1455679,
#               'original_language': 'ru',
#               'original_title': 'Новая тёща',
#               'overview': '',
#               'popularity': 0.4643,
#               'poster_path': '/n5r6TgPl2G18nbiDc3BToweILcH.jpg',
#               'release_date': '2026-03-05',
#               'title': 'New Mother-in-law',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/tiTRz3pBlM51qVciPUJ0h3OAOTK.jpg',
#               'genre_ids': [10402, 99],
#               'id': 1616936,
#               'original_language': 'en',
#               'original_title': 'AURORA: What Happened to the Earth? Live From '
#                                 'Mexico City',
#               'overview': 'Norwegian alt-pop artist AURORA plays her biggest '
#                           'ever headline performance at Mexico City’s Palacio '
#                           'de los Deportes as part of her What Happened to the '
#                           'Earth? Tour. Filmed live on Dia De Los Muertos (Day '
#                           'of the Dead), the arena is transformed into a space '
#                           'of spellbinding sound and light, and filled with '
#                           'fans in festive dress. AURORA’s ethereal voice is '
#                           'ever-captivating as she sings haunting ballads '
#                           "including 'Dreams' and 'Exist for Love' as well as "
#                           "fan-favourites 'Runaway', 'The Seed' and "
#                           "'Churchyard'. Known for blending electronic pop "
#                           'with folk and vivid storytelling, AURORA’s '
#                           'performances are always immersive and emotional, '
#                           'and this concert – celebrating nature and the human '
#                           'experience – solidifies her as a beacon of '
#                           'originality and inspiration.',
#               'popularity': 0.3555,
#               'poster_path': '/fYShYKxsa8ZiMkPkbjiVoKnD9jV.jpg',
#               'release_date': '2026-03-04',
#               'title': 'AURORA: What Happened to the Earth? Live From Mexico '
#                        'City',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/sFFO0F5ZPnsNJhxFu24kdzdfTec.jpg',
#               'genre_ids': [35],
#               'id': 1509802,
#               'original_language': 'zh',
#               'original_title': 'NO GOOD！歐吉桑',
#               'overview': '',
#               'popularity': 0.4328,
#               'poster_path': '/aUDcTCDOSOucqFwmJFMCpoCnmRa.jpg',
#               'release_date': '2026-04-10',
#               'title': 'Uncle Odyssey',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [18],
#               'id': 1514056,
#               'original_language': 'en',
#               'original_title': 'Nika & Madison',
#               'overview': "Fearing they won't be believed, two young "
#                           "Indigenous women go on the run after one's defense "
#                           'of the other results in a violent attack against a '
#                           'police officer.',
#               'popularity': 0.6971,
#               'poster_path': '/j3x9UqLLhAESI75TCjOszArBHFW.jpg',
#               'release_date': '2026-03-20',
#               'title': 'Nika & Madison',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/qJ2fqrKPBmiFH1wGt6DKHkgD6zB.jpg',
#               'genre_ids': [18],
#               'id': 1647277,
#               'original_language': 'en',
#               'original_title': 'The Gardener',
#               'overview': 'Cosmetics heiress Sabena Weathers, battling a '
#                           'hostile takeover of her company, finds solace and '
#                           'renewal at a remote mountain cottage, where she '
#                           'connects with a mysterious gardener.',
#               'popularity': 0.2925,
#               'poster_path': '/3v2vttsSVOAaJEmYmnHLik05790.jpg',
#               'release_date': '2026-04-17',
#               'title': 'The Gardener',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': None,
#               'genre_ids': [],
#               'id': 1621816,
#               'original_language': 'et',
#               'original_title': 'Head niidid',
#               'overview': 'Three sisters notice a strange car while cleaning '
#                           'the apartment of their recently deceased '
#                           'grandmother.',
#               'popularity': 0.2393,
#               'poster_path': None,
#               'release_date': '2026-03-11',
#               'title': 'Good Threads',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/hUU8uhkL4ecmM4XEL6IijjyThM7.jpg',
#               'genre_ids': [16, 35, 18],
#               'id': 1363285,
#               'original_language': 'en',
#               'original_title': 'Brimstone Terrace',
#               'overview': 'When a depressed public defender ends his own life, '
#                           'he is sentenced to an eternity in Hell. However, '
#                           'after Satan takes notice of his skills, he is '
#                           'offered an afterlife-changing deal that may not '
#                           'fall in line with his own values.',
#               'popularity': 0.2928,
#               'poster_path': '/3lrAUJxKOqgkdm9797at9Aqyv6z.jpg',
#               'release_date': '2026-05-01',
#               'title': 'Brimstone Terrace',
#               'video': False,
#               'vote_average': 0.0,
#               'vote_count': 0},
#              {'adult': False,
#               'backdrop_path': '/tEs6S6MOQNWT2Kosne1pO2Pehqk.jpg',
#               'genre_ids': [35, 10749],
#               'id': 1617129,
#               'original_language': 'fr',
#               'original_title': 'Mur mure',
#               'overview': 'Machin, a zany inventor and self-confessed '
#                           'misanthrope, needs only one thing: absolute '
#                           'silence. Thanks to his inventions, which are as '
#                           'ingenious as they are bizarre, he has always '
#                           'managed to scare away his neighbors. Until the day '
#                           'a pianist, Machine, moves in for the first time in '
#                           'her life... into the apartment next door! Recorded '
#                           "at the Théâtre de la Michodière in Paris's 2nd "
#                           'arrondissement.',
#               'popularity': 0.3577,
#               'poster_path': '/4HevJ3d3rzfTjgaZRx1fiYIRri8.jpg',
#               'release_date': '2026-01-18',
#               'title': 'Mur mure',
#               'video': False,
#               'vote_average': 6.333,
#               'vote_count': 3},
#              {'adult': False,
#               'backdrop_path': '/dTm8WXB5wOJiUeUCh2PQeNgTPRd.jpg',
#               'genre_ids': [53],
#               'id': 1465685,
#               'original_language': 'es',
#               'original_title': 'Caminando con el diablo',
#               'overview': 'Spain, 1980s. Philippe is a ten-year-old French boy '
#                           'traveling with his very pregnant mother, Marie, and '
#                           'his father, Tomas, whose plan is to take them home '
#                           'to the village where he grew up and introduce the '
#                           'boy to his Spanish roots. But an unfortunate '
#                           'breakdown leads the family to a scrapyard on the '
#                           'outskirts of a deserted inland town, where they '
#                           'come upon its owners, Alicia and Miguel.',
#               'popularity': 0.7458,
#               'poster_path': '/5PwuCJhCSDqpg1LxlfFxdiZiyjv.jpg',
#               'release_date': '2026-03-06',
#               'title': 'The Devil Within',
#               'video': False,
#               'vote_average': 5.0,
#               'vote_count': 2}],
#  'total_pages': 518,
#  'total_results': 10349}

# %%
df_movies_id
# Out:
#            id        date                             title  popularity  page
# 0     1265609  2026-02-12                       War Machine    361.6614     1
# 1     1290821  2026-01-28                           Shelter    296.3502     1
# 2     1159559  2026-02-25                          Scream 7    231.1484     1
# 3      875828  2026-03-05  Peaky Blinders: The Immortal Man    225.5177     1
# 4      687163  2026-03-15                 Project Hail Mary    210.0281     1
# ...       ...         ...                               ...         ...   ...
# 1995  1647277  2026-04-17                      The Gardener      0.2925   100
# 1996  1621816  2026-03-11                      Good Threads      0.2393   100
# 1997  1363285  2026-05-01                 Brimstone Terrace      0.2928   100
# 1998  1617129  2026-01-18                          Mur mure      0.3577   100
# 1999  1465685  2026-03-06                  The Devil Within      0.7458   100
#
# [2000 rows x 5 columns]

# %% [markdown]
# ## Ejercicio 4
# ### Búsqueda de aparcamientos
# Para este caso práctico, imagina que vas a viajar a Madrid y estás buscando posibles aparcamientos donde dejar tu coche. Crea un DataFrame con todos los aparcamientos (de OpenStreetMap) de la ciudad de Madrid. Para ello, define una cuadrícula con dos coordenadas sobre Madrid.
#
# Representa los resultados en un mapa.

# %%
df_parking
# Out:
# <Response [200]>
#      amenity        lat       lon               name         address
# 0    parking  40.426712 -3.714370        Princesa 25  NO STREET 9999
# 1    parking  40.414469 -3.703549  Parking Benavente  NO STREET 9999
# 2    parking  40.406444 -3.708171            NO NAME  NO STREET 9999
# 3    parking  40.447447 -3.627856            NO NAME  NO STREET 9999
# 4    parking  40.476365 -3.643011            NO NAME  NO STREET 9999
# ..       ...        ...       ...                ...             ...
# 275  parking  40.436061 -3.692951           Señorial  NO STREET 9999
# 276  parking  40.433930 -3.692634     Garaje Collado  NO STREET 9999
# 277  parking  40.440933 -3.652483            NO NAME  NO STREET 9999
# 278  parking  40.400168 -3.722415  Garaje Manzanares  NO STREET 9999
# 279  parking  40.400462 -3.722441            NO NAME  NO STREET 9999
#
# [280 rows x 5 columns]

# %%
plot_my_map(df_parking)

# %% [markdown]
# ## Ejercicio 5
# ### Mudanza
# Imagina que quieres mudarte a El Berrueco, en la Comunidad de Madrid. Averigua si hay gasolineras y/o colegios en la zona. Al igual que en el caso anterior, define un rectángulo utilizando dos coordenadas. Busca la forma de realizar una única solicitud a la API.
#
# A continuación, representa los colegios y las gasolineras en un mapa utilizando colores diferentes.

# %%
df_moving_house
# Out:
# <Response [200]>
#   amenity        lat       lon  \
# 0    fuel  40.905376 -3.607588
# 1    fuel  40.906677 -3.610172
# 2    fuel  40.856872 -3.612894
# 3    fuel  40.875833 -3.602389
# 4  school  40.864566 -3.614058
# 5  school  40.872395 -3.608802
# 6  school  40.863864 -3.615523
# 7  school  40.872395 -3.608802
#
#                                                 name  \
# 0                                             Repsol
# 1                                              Shell
# 2                                              Shell
# 3                                              Shell
# 4  Equipo de Orientación Educativa y Psicopedagóg...
# 5                               C.A.P. De La Cabrera
# 6  Equipo de Orientación Educativa y Psicopedagóg...
# 7                               C.A.P. De La Cabrera
#
#                       address
# 0              NO STREET 9999
# 1    CTRA. N-I KM 64.650 9999
# 2    Avenida de La Cabrera 12
# 3  Avenida de La Cabrera 9999
# 4      Calle de Carlos Ruiz 8
# 5       Calle los Colegios 28
# 6      Calle de Carlos Ruiz 2
# 7       Calle los Colegios 28

# %%
df_moving_house
# Out:
# <Response [200]>
#         amenity        lat       lon  \
# 0  music_school  40.872876 -3.606421
# 1        school  40.864566 -3.614058
# 2        school  40.872395 -3.608802
# 3        school  40.863864 -3.615523
# 4          fuel  40.905376 -3.607588
# 5          fuel  40.906677 -3.610172
# 6          fuel  40.856872 -3.612894
# 7          fuel  40.875833 -3.602389
# 8        school  40.872395 -3.608802
#
#                                                 name  \
# 0     Escuela Municipal de Música y Danza La Cabrera
# 1  Equipo de Orientación Educativa y Psicopedagóg...
# 2                               C.A.P. De La Cabrera
# 3  Equipo de Orientación Educativa y Psicopedagóg...
# 4                                             Repsol
# 5                                              Shell
# 6                                              Shell
# 7                                              Shell
# 8                               C.A.P. De La Cabrera
#
#                       address
# 0    Avenida de La Cabrera 96
# 1      Calle de Carlos Ruiz 8
# 2       Calle los Colegios 28
# 3      Calle de Carlos Ruiz 2
# 4              NO STREET 9999
# 5    CTRA. N-I KM 64.650 9999
# 6    Avenida de La Cabrera 12
# 7  Avenida de La Cabrera 9999
# 8       Calle los Colegios 28

# %%
plot_my_map(df_moving_house)

# %% [markdown]
# ## Ejercicio 6
#
# Imagina que trabajas para tu ayuntamiento y que, debido a una emergencia, necesitas identificar:
# 1. Todos los espacios abiertos de uso público (zonas de barbacoa, fuentes y parques infantiles) para poder cerrarlos.
# 2. Todos los hospitales y clínicas de la zona.
#
# Como no sabes exactamente dónde se encuentran estos lugares, utilizas la API de OpenStreetMap. Esta muestra toda la información en un único mapa.

# %%
df
# Out:
# <Response [200]>
#             amenity        lat       lon  \
# 0    drinking_water  40.413707 -3.695723
# 1    drinking_water  40.412415 -3.691375
# 2    drinking_water  40.413810 -3.709083
# 3    drinking_water  40.444679 -3.708382
# 4    drinking_water  40.439450 -3.691385
# ..              ...        ...       ...
# 274    kindergarten  40.447935 -3.704028
# 275    kindergarten  40.434118 -3.709672
# 276    kindergarten  40.424438 -3.706078
# 277    kindergarten  40.433793 -3.695049
# 278    kindergarten  40.439107 -3.694977
#
#                                                 name  \
# 0                                            NO NAME
# 1                                            NO NAME
# 2                                            NO NAME
# 3                                            NO NAME
# 4                                            NO NAME
# ..                                               ...
# 274                         Chiquitín Cuatro Caminos
# 275  Escuela infantil municipal Fernando el Católico
# 276                                      Family Moon
# 277                              St. Alice's nursery
# 278                                              TEO
#
#                                address
# 0                       NO STREET 9999
# 1                       NO STREET 9999
# 2                       NO STREET 9999
# 3                       NO STREET 9999
# 4                       NO STREET 9999
# ..                                 ...
# 274                     NO STREET 9999
# 275  Calle de Fernando el Católico 16B
# 276                   Calle de Minas 6
# 277    Calle de Fernández de la Hoz 21
# 278                     NO STREET 9999
#
# [279 rows x 5 columns]

# %%
plot_my_map(df)

# %% [markdown]
# ## Ejercicio 7
#
# ### API de YouTube
#
# Inicia un proyecto de Python con uv. Crea un entorno virtual. Añade google-api-python-client desde PyPi.
#
# ![image.png](attachment:image.png)
#
# Cambia el intérprete de Python de los cuadernos de Jupyter por el que necesites.
#
# `Control + Mayús + P`
#
# `Python: Seleccionar intérprete`
#
# `Introducir ruta del intérprete`
#
# `Buscar`
#
# Busca tu python.exe
#
# ![image-2.png](attachment:image-2.png)

# %%
from googleapiclient.discovery import build

# %% [markdown]
# El ID del vídeo se encuentra en la URL de la página del vídeo, justo después del parámetro v=.
#
# En este caso, la URL del vídeo es: https://www.youtube.com/watch?v=fn3KWM1kuAw. Por lo tanto, el ID del vídeo es fn3KWM1kuAw

# %%
#   https://cloud.google.com/console to create the project and activate the API key of youtube v3
#   https://console.cloud.google.com/projectselector2/apis/credentials --> create a project

# Create credentials --> get the API key

# Now link the API key to the services it can use!
# APIs and services library

# https://developers.google.com/youtube/v3/quickstart/python --> API key
# Ensure that you have enabled the YouTube Data API for your project.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#api_key_y = "your api key"

youtube = build("youtube", "v3", developerKey=api_key_y)


request = youtube.channels().list(
    part="statistics",
    id = "fn3KWM1kuAw"
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'RuuXzTIr0OoDqI4S0RU6n4FqKEM',
#  'pageInfo': {'totalResults': 0, 'resultsPerPage': 5}}

# %% [markdown]
# ### ¡Puedes hacer búsquedas como si estuvieras en la barra de búsqueda de Youtube!

# %%
search_response = youtube.search().list(
    q="Dancing robots",
    part="snippet",
    order="viewCount",
    type="video",
    maxResults=50
).execute()

# %%
search_response["items"][0]["snippet"]
# Out:
# {'publishedAt': '2021-05-20T06:40:06Z',
#  'channelId': 'UCi3onjs7UU2Z64i3RrVci-Q',
#  'title': 'Robot Doctor | D Billions Kids Songs',
#  'description': 'Funny robot song #DBillions Copyright AWA LLC 2021. All Rights Reserved.',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNX0uTBp7_U/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/ZNX0uTBp7_U/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/ZNX0uTBp7_U/hqdefault.jpg',
#    'width': 480,
#    'height': 360}},
#  'channelTitle': 'D Billions',
#  'liveBroadcastContent': 'none',
#  'publishTime': '2021-05-20T06:40:06Z'}

# %%
# código
df_video_y
# Out:
#              id                                 channelTitle  \
# 0   ZNX0uTBp7_U                                   D Billions
# 1   DzgwbVZr_VU                                    Danny Go!
# 2   _QNbbE5hb5U                                   D Billions
# 3   nEUTY8n2iZo                                    Danny Go!
# 4   ufnagMewn4E                                    Danny Go!
# 5   XwfG9FdhAc0                                 charles agha
# 6   cn-NsWRtaSY                         America's Got Talent
# 7   yw5-GMjuzo8                                      Mr. Han
# 8   c6nf0ursWZs                                       stance
# 9   DMqQtylat3U                                       stance
# 10  fIKbwzlYjdk                                  Likes video
# 11  iH58C67wEQw                                  Teehee Town
# 12  jLePoipMxDk                                 Ryan's World
# 13  ZM7rrXHNNPI   Robot Vall | Валерий Робот Вэлл Черновский
# 14  2cukB4_hDCI                                SoKrispyMedia
# 15  60d2E6lVgiM  Baby Shark - Pinkfong Kids’ Songs & Stories
# 16  mKgl1CiA9Qk                                    Danny Go!
# 17  VVp_Yzg5VQs                                  Evolayersen
# 18  RTxYve-GwzM                                    Danny Go!
# 19  XDJHcUkkjHA                                    Danny Go!
# 20  q-6g_viAcIk                                    Danny Go!
# 21  009J06pXasM                                    Danny Go!
# 22  jyJfC1C3jJI                                      TechBro
# 23  5CvwgC-WQlo                      Official World of Dance
# 24  T8Df3VZCKUc                                    Danny Go!
# 25  nXUQxgQHX8E                                    Danny Go!
# 26  CP-1cPeFM_c                                  Evolayersen
# 27  IjY7QFIOlkI                                  Magic Dance
# 28  sikpxhmgDj8                                    Danny Go!
# 29  gZeO2SCt9ws                                    Danny Go!
# 30  YrRs4acFOv0                         America's Got Talent
# 31  qSkVgH-4PKw                                    Danny Go!
# 32  jvFr_gpaI8g   Robot Vall | Валерий Робот Вэлл Черновский
# 33  Is9DbPAnlaQ                            Mother Goose Club
# 34  fn3KWM1kuAw                              Boston Dynamics
# 35  i9QAVURLtJo                                    Danny Go!
# 36  1LaWTpokO8s                            Taylor_thatdancer
# 37  FG5JnmwM7ow                                Merrick Hanna
# 38  CfTLDRHKpuk                                  Teehee Town
# 39  aQJ35RhvHF0                                    Danny Go!
# 40  rR0RtYdl3Ao                                    Danny Go!
# 41  oK7kq4q40mk                   Lingokids Official Channel
# 42  pDBHzi3CKfg                                       stance
# 43  fwuSL4I975c                               junior cordova
# 44  diBeYXb4wLM                           Battle Of The Year
# 45  3a0Py4OQ9_M                                    Danny Go!
# 46  udStWRlOGrs                                    Danny Go!
# 47  xzyeTeYWsrQ                                         ELLO
# 48  aFC3UPE1Ukg                               ARPO The Robot
# 49  SzFSFz5tBv8                                    Danny Go!
#
#                  publish                                        description  \
# 0   2021-05-20T06:40:06Z  Funny robot song #DBillions Copyright AWA LLC ...
# 1   2023-09-04T12:00:16Z  Are you ready for a Danny Go DANCE ADVENTURE? ...
# 2   2023-02-09T08:52:01Z  https://band.link/DBillions Lyrics: Robo, robo...
# 3   2022-10-03T11:00:34Z  It's time to play the floor is LAVA! Dance alo...
# 4   2024-09-09T12:01:05Z  Are you ready for a spooky adventure? Bearhead...
# 5   2020-11-04T01:18:54Z  Dance video created to the awesome theme song ...
# 6   2013-06-19T01:17:24Z  You've never seen dancing done like this! From...
# 7   2025-08-18T11:04:25Z
# 8   2022-08-31T14:00:30Z
# 9   2023-07-12T16:03:31Z
# 10  2022-11-18T02:57:27Z  Robo boy sambalpuria robo boy Robot boys Robot...
# 11  2024-01-12T00:00:20Z  Skeleton Robot Finger Family is here to make u...
# 12  2018-08-15T12:00:03Z  Let's Build A Robot Kids Song | Body Parts Exe...
# 13  2021-07-13T18:18:36Z  Freestyle, i didn't know this track. Back To T...
# 14  2023-12-01T12:00:03Z  An on-site look at the intelligence helping bu...
# 15  2022-09-09T12:00:07Z  [NEW CHANNEL] Subscribe Bebefinn - Nursery Rhy...
# 16  2025-08-25T12:01:24Z  Are you ready to use your superpowers? ⚡  ‍♂️ ...
# 17  2022-08-08T10:24:20Z  Wubbox is a Supernatural Monsters available on...
# 18  2024-08-19T12:00:24Z  Join Danny Go and friends on an exciting adven...
# 19  2022-08-09T12:00:20Z  You're invited to a DANCE PARTY!! ⚡️ Do you ha...
# 20  2023-03-13T12:00:38Z  Time to DANCE like your favorite colors!! In t...
# 21  2024-04-01T12:00:00Z  Are you ready to transform into a ROBOT? Charg...
# 22  2023-09-01T11:09:22Z
# 23  2015-04-26T17:57:25Z  Check out our latest SPLASH MOB Video! https:/...
# 24  2022-11-07T12:00:26Z  Are you ready to dance like a ROBOT? Get your ...
# 25  2024-05-13T12:00:47Z  Are you ready to pound the ground like a goril...
# 26  2023-01-27T11:32:52Z  Wubbox is a Supernatural Monster available on ...
# 27  2024-05-21T10:02:20Z  Coffin Dance ⭐️ Who BEST DANCER? TUZELITY SHUF...
# 28  2024-04-15T12:01:00Z  You're invited to a Danny Go DANCE PARTY! ⚡️ J...
# 29  2023-08-28T12:00:25Z  Are you ready to DRIVE some vehicles? Dance al...
# 30  2019-06-19T00:59:00Z  Adem Show will leave you with your jaw on the ...
# 31  2022-05-24T11:00:33Z  Get ready to swing your tail & stomp the groun...
# 32  2022-02-11T06:15:02Z  shorts Booking show, workshops, judging, chore...
# 33  2013-08-21T15:17:12Z  Hey parents and teachers! Looking for activity...
# 34  2020-12-29T18:51:48Z  Our whole crew got together to celebrate the s...
# 35  2024-07-22T13:02:20Z  You're invited to a Danny Go DANCE PARTY! ⚡️ J...
# 36  2023-02-06T21:34:58Z
# 37  2023-04-11T19:26:39Z                   gottalent #agt #moonwalk #dance.
# 38  2023-01-03T12:28:41Z  Het Kids, Have you heard about the Five Skelet...
# 39  2025-11-06T13:00:02Z  Delivery! Are you ready to pop open some packa...
# 40  2023-12-18T13:00:44Z  You're invited to a Danny Go DANCE PARTY! ⚡️ H...
# 41  2021-01-29T16:00:09Z  DON'T STOP BABY BOT DANCE | More Lingokids Eng...
# 42  2024-01-05T06:18:36Z
# 43  2016-02-14T20:02:42Z  Un pequeño mix que hice por diversión. Mis mús...
# 44  2014-07-04T12:00:03Z  ROBOT DANCE - BOTY 2006 - SALAH (FRANCE) - SHO...
# 45  2022-12-05T13:00:02Z  You're invited to a DANCE PARTY!! ⚡️ Do you ha...
# 46  2025-09-30T12:01:46Z  Are you ready to get batty? Fly into the spook...
# 47  2024-02-29T17:00:46Z  Unleash the Magic of Movement! Dive into "Danc...
# 48  2023-02-07T12:00:00Z  ARPO the Robot and Blippi meet each other for ...
# 49  2025-12-17T13:01:00Z  Get ready to push, pull, and stick together in...
#
#                                           title_video
# 0                Robot Doctor | D Billions Kids Songs
# 1   Quicksand, Lava, Sharks + more!  🌋🦈 🐍 | Dance ...
# 2   Robot Cha-Cha, Robot Chicky, Robot Boom-Boom &...
# 3   &quot;The Floor is Lava Dance!&quot; 🌋 /// Dan...
# 4   &quot;Spooky Spiders Everywhere!&quot; 🕷🎃 Hall...
# 5      AMONG US Dance Video - Moondai EDM Remix (DTB)
# 6   Kenichi Ebina Performs an Epic Matrix- Style M...
# 7          The boy dances with the robot #dance #cute
# 8                  Robots are getting more lifelike 🤯
# 9                         Chibi the real life robot 🤖
# 10  Robo boy // Sambalpuria robo boy // robot boy ...
# 11  Skeleton Robot Finger Family - Midnight Lab St...
# 12  Let&#39;s Build A Robot Kids Song | Body Parts...
# 13                     Best Robot Dance by Robot Vall
# 14         Robots testing the Bulletproof #cybertruck
# 15                     Poppin&#39; Robot 🤖 Baby Shark
# 16  Ka-Pow! 2: Attack of the Gravity Goldfish! 💥 S...
# 17  All Wubbox - Sound and Animation (My Singing M...
# 18  &quot;Don&#39;t Stop Digging!&quot; 💎⛏️ Gemsto...
# 19  Wiggle, Freeze, Spin + more! | Dance Along | D...
# 20  “The Color Dance Game!” 🌈 /// Would You Rather...
# 21  “Robot Energy!” Toy Factory Adventure 🤖⚡️ Robo...
# 22  300 ₹ vs 30000 ₹ Smart A.I Robot 🤖 #tech #tech...
# 23  Dytto | FRONTROW | World of Dance Bay Area 201...
# 24  &quot;The Robot Dance!&quot; 🤖 /// Danny Go! B...
# 25  &quot;Gorilla Smash!&quot; Drum-Along Dance 🦍🥁...
# 26          All Wubbox - Power UP/DOWN (Animation) 4k
# 27  Coffin Dance 😎⭐️ Who BEST DANCER? 🤔🔥 TUZELITY ...
# 28  Glow Sticks, Animals, Bugs + more! ⚡️🐒🐛 | Danc...
# 29  &quot;Drive Drive!&quot; Vehicle Dance Song 🚒 ...
# 30  WOW! EPIC Dance Crew Delivers Mortal Kombat x ...
# 31  &quot;The Dinosaur Dance!&quot; 🦖 /// Danny Go...
# 32                          Robot walk (dance battle)
# 33  Rockin&#39; Robot - Mother Goose Club Phonics ...
# 34                                    Do You Love Me?
# 35  Lava, Sharks, Race Cars + more! 🚘🔥🦈 | 1-Hour D...
# 36      Sleep Paralysis Dancers @jxnmyles @BluPrint01
# 37      LONELYBOT Merrick &amp; Lonely Robot  #shorts
# 38  Haunted Five Skeletons Halloween Song | Spooky...
# 39  “Package POP!” 📦💥 Mystery Box Surprise Dance |...
# 40  Superheroes, Vehicles, Farm Animals + more! 🦸‍...
# 41  DON&#39;T STOP BABY BOT DANCE 🤖🎶🕺| Dance Song ...
# 42  Reliving this unreal moment 2023 chibi the AI ...
# 43           Barbie Girl - Permanent - Chain Hang Low
# 44  ROBOT DANCE - SALAH (FRANCE) BOTY 2006 SHOWCAS...
# 45  Lava, Robots, Twist + more! 🌋🤖 /// Danny Go! D...
# 46  “The Bat Wing BEAT!” 🦇 Spooky Drum-Along Dance...
# 47  Robot or real girl? #dance #ello #pop #dancer ...
# 48  Blippi and ARPO Can&#39;t Stop Dancing!! | ARP...
# 49  “Magnet MANIA!” 🧲⚡️STEM Brain Break | Danny Go...

# %% [markdown]
# ### Escribe un programa que le pida a Youtube "¿cómo hacer pan?", 50 resultados, obtén los snippets y guarda los siguientes datos:
#
# * id_video
# * channelTitle
# * publish_time
# * description
# * title_video
# * duration
# * definition
# * closed_caption
# * license_content
# * madeforkids
# * view_count
# * like_count
# * favorite_count
# * comment_count
# * license

# %%
# Your code:



df_youtube.head()
# Out:
#       id_video               Channel  \
# 0  G-jCXT_jt34         Milagro Reyes
# 1  ebTI4nm2cg8    By Tahiana Fandiño
# 2  zqQcSAXy1VY       Quiero Cupcakes
# 3  F7PnS0IBu5I  Las Recetas de Simón
# 4  0W9lXaHcXL4            Allrecipes
#
#                                                title  \
# 0                Los Panaderos Hacen esto en Secreto
# 1  PAN SIN HARINA, en la descripción te dejo los ...
# 2  BIZCOCHO EXTRA ESPONJOSO CON 3 INGREDIENTES | ...
# 3  TE SOBRÓ PAN O MEDIALUNAS DEL FINDE? Hacete es...
# 4  How to Make Banana Banana Bread | Get Cookin&#...
#
#                                          description          publish_time  \
# 0                                                     2023-10-02T13:14:34Z
# 1  PAN DE CREMA DE MANI ( pan sin harina) Ingredi...  2024-08-31T03:20:04Z
# 2  ACCEDE A MIS CURSOS DE REPOSTERÍA➜ https://www...  2019-10-25T15:00:10Z
# 3  Para mi en el top 3 de postres de restaurant s...  2022-09-18T22:00:05Z
# 4  See how to make the best banana bread. Month a...  2012-05-10T14:50:08Z
#
#   duration definiton closed_caption  license_content  madeforkids  license  \
# 0   PT1M1S        hd          false             True        False  youtube
# 1   PT1M1S        hd          false             True         True  youtube
# 2   PT8M6S        hd          false             True        False  youtube
# 3    PT59S        hd          false             True        False  youtube
# 4  PT3M31S        hd           true             True        False  youtube
#
#   view_count favorite_count comment_count
# 0   55343452              0         17552
# 1   48541679              0          None
# 2   25321139              0          8500
# 3   24494275              0          4276
# 4   12955634              0          4347

# %%
df_youtube
# Out:
#        id_video                          Channel  \
# 0   G-jCXT_jt34                    Milagro Reyes
# 1   ebTI4nm2cg8               By Tahiana Fandiño
# 2   zqQcSAXy1VY                  Quiero Cupcakes
# 3   F7PnS0IBu5I             Las Recetas de Simón
# 4   0W9lXaHcXL4                       Allrecipes
# 5   sTUSMZK38do                Rezepte von Julia
# 6   0X7QE0XmVEQ                 Przepisy od Olgi
# 7   Bc7KNDrheaQ              Anna recetasfaciles
# 8   YTFxV98w1JY              La pasamos comiendo
# 9   P7LUKvvPGB8                      Ailu Tokman
# 10  8efWPwnDJLY              Anna recetasfaciles
# 11  tijBUdAKV0o               Temperos e Sabores
# 12  H8X22pf1MS8               VICKY RECETA FACIL
# 13  boCKxCTzbnQ           Jennifer Salas Postres
# 14  yCDTVzRQnD0                          Cuk-it!
# 15  Qz551QovGJU  Recetas Tradicionales de Cocina
# 16  KcKe8z6ZjX0                   Paulina Cocina
# 17  KhDs1756qCw               VICKY RECETA FACIL
# 18  6snDDoeV3W0              Dulce Hogar Recetas
# 19  gm5wSHC6KpE            Jauja Cocina Mexicana
# 20  I_8RlzV7qsA            Gluten Morgen Español
# 21  xmWPoBn7ZD4                       Oye Kenedy
# 22  x3tAkLlP3HA                    Super Gustoso
# 23  1vJH_2hUIHo               VICKY RECETA FACIL
# 24  jZ0ByEyxELw                 Recetas y Más TV
# 25  v8F6yJt1ULo                Cocina Para Todos
# 26  mI6K-4_JPrM              Anna recetasfaciles
# 27  tjF6KfDBbfc              La pasamos comiendo
# 28  0rtFCQuewe8           La Cocina de la Abuela
# 29  WXyQvok6zfA            Jauja Cocina Mexicana
# 30  W-3CoY4NoVI         MAMBRUNENSE Edgardo Rios
# 31  VKsScVmPtTE                 Przepisy od Olgi
# 32  Nzj6cfxeknY            Jauja Cocina Mexicana
# 33  XdtL0VGiQFE          Comida Mexicana Con Ali
# 34  FXU7vNwP7Z8               VICKY RECETA FACIL
# 35  47YFAQZk5G8             Katastrofa La Cocina
# 36  xl6LqdmEbCQ   Eugenio Monesma - Documentales
# 37  k3BOBKzZsoQ            Gluten Morgen Español
# 38  L0-DLs3QoMo            Jauja Cocina Mexicana
# 39  Ifuz64p_9pA                Por amor al horno
# 40  5LcKilYc5pY              La Cocina de Denise
# 41  B0w_N5tu8PU               VICKY RECETA FACIL
# 42  bLh6-RpZRgU                      CHEFSCHWARZ
# 43  GRwfWx4167E            Gluten Morgen Español
# 44  LTpJqibpcaY                   Recetas TikTok
# 45  64ev7GkaDwg              Anna recetasfaciles
# 46  6E8RyaMsxhc         MAMBRUNENSE Edgardo Rios
# 47  vVyQ_a9m1gU                        A cocinar
# 48  aAn1E1b-pmQ         MAMBRUNENSE Edgardo Rios
# 49  SgvaeW3EeRY               Anna recetas y más
#
#                                                 title  \
# 0                 Los Panaderos Hacen esto en Secreto
# 1   PAN SIN HARINA, en la descripción te dejo los ...
# 2   BIZCOCHO EXTRA ESPONJOSO CON 3 INGREDIENTES | ...
# 3   TE SOBRÓ PAN O MEDIALUNAS DEL FINDE? Hacete es...
# 4   How to Make Banana Banana Bread | Get Cookin&#...
# 5   Ich kaufe kein Brot mehr! Schnelles Brotrezept...
# 6   Jeśli masz mąkę i 2 jajka, przygotuj ten pyszn...
# 7        Pan casero fácil y rápido (con harina común)
# 8              PANCAKES FACILES | LA PASAMOS COMIENDO
# 9   SOBRÓ PAN DEL ASADO DEL DOMINGO? HAZ ESTA RECE...
# 10          Cómo hacer PAN SIN HORNO con harina común
# 11   PAN SIN HORNO HECHO EN SARTÉN, fácil y delicioso
# 12  PASTEL DE ELOTE ESPONJOSO O PAN DE ELOTE, MAÍ...
# 13  NO COMAS PAN, Prepara esta deliciosa receta mu...
# 14  Pan Casero | Corteza dorada y crocante, en el ...
# 15             Cómo hacer pan casero de forma fácil
# 16  CÓMO HACER BUDÍN DE PAN: Receta fácil en 4 pasos!
# 17                 PAN DE NARANJA | #VickyRecetaFacil
# 18  DELICIOSOS BOLILLOS CASEROS con TIPS para que ...
# 19                 Cómo Hacer el Pan Francés Perfecto
# 20  Cómo hacer masa madre, la forma fácil y defini...
# 21  TE APUESTO QUE NO SABÍAS ESTO 😨‼️ la forma más...
# 22  ¡No comas pan! ¡Prepara esta deliciosa receta ...
# 23            CÓMO HACER CONCHAS | #VickyRecetaFacil
# 24    No comas pan, Haz un desayuno riquisimo y fácil
# 25  Pan Casero fácil de hacer | Corteza crujiente ...
# 26  Baguette o pan francés (barras de pan muy fáci...
# 27                  PANCITOS SIN HORNO Y SIN LEVADURA
# 28  PAN casero 🍞 SIN AMASAR, en 3 minutos 🥖 receta...
# 29                  Pan de Elote Esponjado y Facilito
# 30                                         PANQUEQUES
# 31  Jeśli macie mąkę i 2 jajka, są tak pyszne, że ...
# 32                          Pan de Muerto Tradicional
# 33  PAN DE ELOTE SIN HORNO, HECHO SOBRE LA ESTUFA....
# 34  CHOCOFLAN O PASTEL IMPOSIBLE | #VickyRecetaFac...
# 35          Cómo hacer bolillos caseros (pan frances)
# 36  HARINA Y PAN 100% artesanal en un molino cente...
# 37    ¡Encontramos la forma más fácil de hacer pan! 🔥
# 38                 Cómo Hacer Conchas Bien Suavecitas
# 39  Panecillos de leche dulces - Extra tiernos - P...
# 40  Cómo HACER PAN CASERO A MANO / PAN HECHO EN CA...
# 41                PAN DE VAINILLA | #VickyRecetaFacil
# 42  Con una Yuca puedes hacer: Pan de bono! 🇨🇴 ft....
# 43      ¿CÓMO HACER UN PAN DE MASA MADRE PASO A PASO?
# 44          COMO HACER DONAS CASERAS - Recetas TikTok
# 45  Pan casero fácil. Corteza y miga sorprendentes...
# 46                                        PAN FRANCÉS
# 47  Los panaderos no quieren que sepas este secret...
# 48                                     PANCITOS CHIPS
# 49  PAN CASERO sencillo. ¡Qué fácil es hacer TU PR...
#
#                                           description          publish_time  \
# 0                                                      2023-10-02T13:14:34Z
# 1   PAN DE CREMA DE MANI ( pan sin harina) Ingredi...  2024-08-31T03:20:04Z
# 2   ACCEDE A MIS CURSOS DE REPOSTERÍA➜ https://www...  2019-10-25T15:00:10Z
# 3   Para mi en el top 3 de postres de restaurant s...  2022-09-18T22:00:05Z
# 4   See how to make the best banana bread. Month a...  2012-05-10T14:50:08Z
# 5   Abonniere meinen Kanal   @rezeptevonjulia6650 ...  2023-03-04T12:00:39Z
# 6   Jeśli masz mąkę i 2 jajka, przygotuj ten pyszn...  2023-09-07T11:24:44Z
# 7   Compra mi libro de recetas COCINA PARA TRIUNFA...  2017-06-21T20:39:34Z
# 8   PANCAKES    fáciles,esponjosos y riquísimos. S...  2021-03-27T18:24:05Z
# 9   Sobró pan del asado del domingo? HACETE TREMEN...  2022-10-23T23:00:17Z
# 10  Compra mi libro de recetas COCINA PARA TRIUNFA...  2020-07-15T17:27:05Z
# 11  La receta original es la de los muffins ingles...  2017-05-25T00:07:07Z
# 12  Receta de CÓMO HACER PASTEL DE ELOTE ESPONJOSO...  2016-08-09T15:41:58Z
# 13                                viral #recetafacil.  2020-06-18T22:55:47Z
# 14  Hoy les compartimos una receta de Pan que para...  2018-09-06T16:05:45Z
# 15  No te pierdas esta receta fácil para elaborar ...  2015-02-06T12:38:20Z
# 16  CÓMO HACER BUDÍN DE PAN FÁCIL Y PERFECTO En es...  2017-07-12T19:37:01Z
# 17  Cómo preparar paso a paso un esponjosito y del...  2014-05-15T18:09:55Z
# 18  QuédateEnCasa #conmigo Deliciosos BOLILLOS CAS...  2020-04-24T15:15:00Z
# 19  Pan Francés. Pan Francés de Jauja Cocina Mexic...  2018-06-08T13:45:01Z
# 20  La guía definitiva para hacer masa madre fácil...  2023-08-12T16:00:11Z
# 21                                                     2025-07-07T04:39:00Z
# 22  TITULO: ¡No comas pan! ¡Prepara esta deliciosa...  2021-08-26T21:00:31Z
# 23  Receta de CÓMO HACER CONCHAS!!! :D (Los ingred...  2016-11-15T15:24:23Z
# 24  Desayunos saludables, rapidos y faciles. Desay...  2023-03-29T19:15:01Z
# 25  Aprende con este vídeo a hacer un pan casero m...  2020-03-22T15:47:33Z
# 26  Compra mi libro de recetas COCINA PARA TRIUNFA...  2020-04-23T16:27:22Z
# 27  Pancitos sin horno y sin levadura . Super fáci...  2021-05-08T21:54:47Z
# 28  La Cocina de la Abuela. Tus recetas de cocina ...  2019-09-29T17:30:12Z
# 29  Pan de Elote. Pan de Elote de Jauja Cocina Mex...  2019-02-08T14:45:01Z
# 30                                                     2023-04-27T21:25:14Z
# 31  Jeśli masz mąkę i 2 jajka, są tak pyszne, że m...  2023-12-24T11:34:58Z
# 32  Pan de Muerto. Pan de Muerto Tradicional de Ja...  2017-10-24T13:50:01Z
# 33                                                     2020-12-01T21:09:52Z
# 34  Receta de CÓMO HACER CHOCOFLAN O PASTEL IMPOSI...  2017-04-27T17:35:47Z
# 35  Bolillos - Receta fácil y económica.En este vi...  2019-09-14T12:03:56Z
# 36  HARINA Y #PAN ARTESANAL | El #molino de #Arcer...  2022-04-04T17:59:17Z
# 37  El secreto está en hacer un largo levado en fr...  2023-08-19T16:00:25Z
# 38  Conchas. Conchas de Pan Dulce de Jauja Cocina ...  2021-08-11T13:45:00Z
# 39  El día de hoy haremos unos pancitos dulces de ...  2017-06-23T08:00:01Z
# 40  Aca les comparto como hago yo el pan en mi cas...  2020-03-27T02:48:01Z
# 41  Cómo preparar pan de vainilla, delicioso y esp...  2015-02-05T21:33:04Z
# 42                                                     2025-02-15T15:20:55Z
# 43  Accedé a la Master Class de Masa Madre: https:...  2020-01-28T21:00:03Z
# 44  DONAS CASERAS• -Harina 0000✓ -Leche Líquida✓ -...  2020-12-04T01:58:48Z
# 45  Compra mi libro de recetas COCINA PARA TRIUNFA...  2018-02-21T18:35:06Z
# 46                                                     2025-04-30T16:57:37Z
# 47  Bienvenidos al canal de A cocinar, el canal do...  2023-04-10T02:20:00Z
# 48                                                     2023-07-26T23:31:07Z
# 49  Hacer pan es muy fácil. Te cuento cómo hacer u...  2020-03-11T19:26:16Z
#
#     duration definiton closed_caption  license_content  madeforkids  license  \
# 0     PT1M1S        hd          false             True        False  youtube
# 1     PT1M1S        hd          false             True         True  youtube
# 2     PT8M6S        hd          false             True        False  youtube
# 3      PT59S        hd          false             True        False  youtube
# 4    PT3M31S        hd           true             True        False  youtube
# 5    PT8M37S        hd           true             True        False  youtube
# 6     PT8M9S        hd           true             True        False  youtube
# 7     PT5M3S        hd           true             True        False  youtube
# 8      PT29S        hd          false             True        False  youtube
# 9      PT57S        hd          false             True        False  youtube
# 10   PT8M34S        hd          false             True        False  youtube
# 11  PT12M45S        hd          false             True        False  youtube
# 12   PT9M48S        hd          false             True        False  youtube
# 13   PT5M54S        hd          false             True        False  youtube
# 14   PT4M15S        hd          false             True        False  youtube
# 15   PT4M25S        hd          false             True        False  youtube
# 16   PT10M9S        hd           true             True        False  youtube
# 17  PT13M17S        sd          false             True        False  youtube
# 18  PT13M37S        hd          false             True        False  youtube
# 19   PT4M53S        hd          false             True        False  youtube
# 20      PT1M        hd          false             True        False  youtube
# 21   PT1M13S        hd          false             True        False  youtube
# 22    PT3M2S        hd           true             True        False  youtube
# 23  PT20M40S        hd          false             True        False  youtube
# 24    PT8M2S        hd          false             True        False  youtube
# 25   PT8M37S        hd           true             True        False  youtube
# 26   PT9M14S        hd          false             True        False  youtube
# 27     PT31S        hd          false             True        False  youtube
# 28  PT11M18S        hd          false             True        False  youtube
# 29   PT5M16S        hd          false             True        False  youtube
# 30      PT1M        hd          false             True        False  youtube
# 31   PT8M30S        hd           true             True        False  youtube
# 32  PT14M10S        hd          false             True        False  youtube
# 33  PT14M11S        hd          false             True        False  youtube
# 34  PT16M40S        hd          false             True        False  youtube
# 35   PT8M21S        hd           true             True        False  youtube
# 36  PT22M15S        hd           true             True        False  youtube
# 37      PT1M        hd          false             True        False  youtube
# 38  PT13M20S        hd          false             True        False  youtube
# 39   PT4M31S        hd          false             True        False  youtube
# 40  PT18M14S        sd          false             True        False  youtube
# 41  PT12M25S        hd          false             True        False  youtube
# 42   PT2M34S        hd          false             True        False  youtube
# 43  PT11M10S        hd          false             True        False  youtube
# 44      PT1M        hd          false            False        False  youtube
# 45     PT11M        hd          false             True        False  youtube
# 46      PT3M        hd          false             True        False  youtube
# 47      PT1M        hd           true             True        False  youtube
# 48      PT1M        hd          false             True        False  youtube
# 49   PT10M4S        hd          false             True        False  youtube
#
#    view_count favorite_count comment_count
# 0    55343452              0         17552
# 1    48541679              0          None
# 2    25321139              0          8500
# 3    24494275              0          4276
# 4    12955634              0          4347
# 5    12482975              0          7743
# 6    11237014              0          7634
# 7    10542078              0          6956
# 8    12117715              0          2022
# 9     9855215              0          1905
# 10    9556527              0          4542
# 11    9190675              0          5764
# 12    8759321              0          3037
# 13    8403388              0          5953
# 14    8293669              0          5443
# 15    8040176              0          2827
# 16    7900261              0          4804
# 17    7844607              0          2154
# 18    7489521              0          5328
# 19    7415650              0          3656
# 20    7887960              0          2831
# 21   11342445              0          2004
# 22    6977079              0          2752
# 23    6629420              0          3425
# 24    6625784              0          5266
# 25    5723108              0          2903
# 26    5663778              0          3568
# 27    5938221              0          1639
# 28    5598258              0          6182
# 29    5479327              0          2983
# 30    6229220              0          1342
# 31    5358803              0           512
# 32    5244613              0          7215
# 33    5224942              0          2845
# 34    5135149              0          2051
# 35    4909978              0          4713
# 36    4625292              0          5428
# 37    4549356              0          1038
# 38    4379968              0          4059
# 39    4324240              0          2434
# 40    4299625              0          2393
# 41    4227865              0          1280
# 42    4503436              0          2970
# 43    4020139              0          6289
# 44    4540177              0          1367
# 45    3967985              0          2295
# 46    8065872              0          5173
# 47    4364374              0          3896
# 48    3900823              0          1413
# 49    3457546              0          2132
