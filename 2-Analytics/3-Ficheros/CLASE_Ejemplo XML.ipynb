# %% [markdown]
# # Archivo XML
# Un XML está compuesto de tags y atributos. Es posible leer desde un archivo local o a través de una URL mediante librerías como `urllib`.

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('ejemplo.xml')
print(type(tree))
root = tree.getroot()
root
# Out:
# <class 'xml.etree.ElementTree.ElementTree'>
# <Element 'data' at 0x0000027E8395B420>

# %% [markdown]
# Dentro de root, hay n elementos, considerados como los *children* de root. Cada elemento del XML tiene un *tag* y varios atributos en formato clave-valor.

# %%
for child in root:
    print(child.tag)
    print(child.attrib)
    print(child.attrib.get('name') + '\n')
# Out:
# country
# {'name': 'Liechtenstein'}
# Liechtenstein
#
# country
# {'name': 'Singapore'}
# Singapore
#
# country
# {'name': 'Panama'}
# Panama

# %% [markdown]
# Para obtener los children de cada línea:

# %%
for node in root.iter():
    print(node.tag)
# Out:
# data
# country
# rank
# year
# gdppc
# neighbor
# neighbor
# country
# rank
# year
# gdppc
# neighbor
# country
# rank
# year
# gdppc
# neighbor
# neighbor

# %% [markdown]
# Los elementos van ordenados, por lo que podremos acceder a los mismos mediante su orden.
#
# Si queremos acceder a lo que hay dentro de los tags: `.text`. Devuelve un String, aunque estemos hablando de un número.

# %%
print(root[0][1])
print(root[0][1].text)
# Out:
# <Element 'year' at 0x0000027E8395B510>
# 2008

# %% [markdown]
# Para iterar sobre unos elementos concretos. Podría haber atributos que se llamen igual en diferentes puntos del XML, y quizá ese no es el comportamiento que deseamos. Podemos filtrar los que nos interesan usando expresiones XPath.

# %%
for neighbor in root.iter('neighbor'):
    print(type(neighbor))
    print(neighbor.attrib)
    print(neighbor.attrib['name'])
# Out:
# <class 'xml.etree.ElementTree.Element'>
# {'name': 'Austria', 'direction': 'E'}
# Austria
# <class 'xml.etree.ElementTree.Element'>
# {'name': 'Switzerland', 'direction': 'W'}
# Switzerland
# <class 'xml.etree.ElementTree.Element'>
# {'name': 'Malaysia', 'direction': 'N'}
# Malaysia
# <class 'xml.etree.ElementTree.Element'>
# {'name': 'Costa Rica', 'direction': 'W'}
# Costa Rica
# <class 'xml.etree.ElementTree.Element'>
# {'name': 'Colombia', 'direction': 'E'}
# Colombia

# %% [markdown]
# 1. `find` para buscar un tag dentro del árbol inmediato, y no de sus hijos.
# 2. `iter` para buscar un tag dentro de todo un árbol, incluidos sus hijos.
# 3. `get` para conseguir el valor de un atributo.

# %%
for country in root.findall('country'):
    rank = country.find('rank').text
    neighbor = country.find('neighbor').text
    name = country.get('name')
    
    print(name, neighbor, rank)
# Out:
# Liechtenstein None 1
# Singapore None 4
# Panama None 68

# %% [markdown]
# También podríamos modificarlo

# %%
for rank in root.iter('rank'):
    new_rank = int(rank.text) + 1
    rank.text = str(new_rank)
    rank.set('updated', 'yes')

# %%
for country in root.findall('country'):
    rank = country.find('rank').text 
    name = country.get('name') 
    print(name, rank)
# Out:
# Liechtenstein 2
# Singapore 5
# Panama 69

# %%
tree.write('output.xml')

# %% [markdown]
# O eliminar elementos

# %%
for country in root.findall('country'):
    rank = int(country.find('rank').text)
    if rank > 50:
        root.remove(country)

# %% [markdown]
# Para escribir los datos en un nuevo XML

# %%
tree.write('output.xml')

# %% [markdown]
# Cada elemento que encuentra `findall()` o `iter()` es un `Element`, sobre el que podemos acceder a sus datos gracias a atributos como como `tag` o `attrib`.
#
# Acceso mediante XPath. Ya que la estructura de los XML es un árbol de tags, podremos acceder a los elementos mediante la ruta relativa de los tags.

# %%
print(root.findall('./country/neighbor'))
# Out:
# [<Element 'neighbor' at 0x0000027E8395B5B0>, <Element 'neighbor' at 0x0000027E8395B600>, <Element 'neighbor' at 0x0000027E8395B790>]

# %% [markdown]
# # XML con RSS
# RSS es una manera que tienen las páginas web de publicar su contenido. En este caso no es un HTML, ni un CSS como se hace habitualmente, sino que será un XML, con un árbol de tags y distinta información. Páginas que utilizan esto son periódicos, foros o blogs. Permite acceder a los titulares de noticias, tanto de las generales, como de las secciones del periódico, de tal manera que puedas monitorizarlos en una aplicación. Los datos son abiertos y el formato de publicación es XML.
#
# En nuestro caso vamos a desarrollar un programa mediante el que recogeremos el RSS del periódico *El Pais* y montaremos una tabla con las principales noticias.

# %%
from urllib.request import urlopen
from xml.etree.ElementTree import parse

var_url = urlopen('https://feeds.elpais.com/mrss-s/pages/ep/site/elpais.com/section/ultimas-noticias/portada')
# var_url = urlopen('http://ep00.epimg.net/rss/tags/ultimas_noticias.xml')
xmldoc = parse(var_url)

for item in xmldoc.findall('./channel/item'):
    title = item.findtext('title')
    date = item.findtext('pubDate')
    link = item.findtext('link')
    
    
    print("título: ", title, "\nfecha:", date, "\nenlace:", link, "\n")
# Out:
# título:  Del “estoy dispuesto a hablar” al “no habrá acuerdo sin rendición incondicional”: los bandazos de Trump sobre el fin de la guerra en Irán
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/internacional/2026-03-07/del-estoy-dispuesto-a-hablar-al-no-habra-acuerdo-sin-rendicion-incondicional-los-bandazos-de-trump-sobre-el-fin-de-la-guerra-en-iran.html
#
# título:  El Departamento de Justicia publica una docena de documentos pendientes con las acusaciones contra Trump en el caso Epstein
# fecha: Fri, 06 Mar 2026 23:55:11 GMT
# enlace: https://elpais.com/internacional/2026-03-06/el-departamento-de-justicia-publica-una-docena-de-documentos-pendientes-con-las-acusaciones-contra-trump-en-el-caso-epstein.html
#
# título:  Un “muchacho de Malasaña” para sacar a la Policía de su peor bache
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/espana/2026-03-07/un-muchacho-de-malasana-para-sacar-a-la-policia-de-su-peor-bache.html
#
# título:  El viejo debate que divide a las tenistas: jugar o no a cinco sets visibilizaría la igualdad, pero también daría más peso al físico
# fecha: Sat, 07 Mar 2026 15:11:49 GMT
# enlace: https://elpais.com/deportes/tenis/2026-03-07/el-viejo-debate-que-divide-a-las-tenistas-jugar-o-no-a-cinco-sets-visibilizaria-la-igualdad-pero-tambien-daria-mas-peso-al-fisico.html
#
# título:  Inapelable ‘pole’ de Russell en un GP de Australia que confirma el tremendo impacto del nuevo reglamento
# fecha: Sat, 07 Mar 2026 07:53:06 GMT
# enlace: https://elpais.com/deportes/formula-1/2026-03-07/inapelable-pole-de-russell-en-un-gp-de-australia-que-confirma-el-tremendo-impacto-del-nuevo-reglamento.html
#
# título:  Las 10 pensadoras feministas más influyentes
# fecha: Sat, 07 Mar 2026 05:24:47 GMT
# enlace: https://elpais.com/ideas/2026-03-08/las-10-pensadoras-feministas-mas-influyentes.html
#
# título:  La reina Urraca, pionera del empoderamiento femenino, murió de parto el 8M de hace 900 años
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/espana

# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/ciencia/2026-03-07/diana-walsh-pasulka-especialista-en-religiones-la-fe-en-los-ovnis-es-muy-parecida-a-la-comunidad-cristiana-primitiva.html
#
# título:  El movimiento feminista llega al 8M con una mirada global “frente al clima belicista”
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/sociedad/dia-de-la-mujer/2026-03-07/el-movimiento-feminista-llega-al-8m-con-una-mirada-global-frente-al-clima-belicista.html
#
# título:  Los ocho libros de la semana
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/babelia/2026-03-07/los-ocho-libros-de-la-semana.html
#
# título:  El camino vivido Avui-El País
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/espana/catalunya/2026-03-07/el-camino-vivido-avui-el-pais.html
#
# título:  La IA y un futuro de (des)igualdad de género
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/opinion/2026-03-07/la-ia-y-un-futuro-de-desigualdad-de-genero.html
#
# título:  ‘La Antídoto’, érase una vez en la misteriosa tierra de Uz
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/babelia/2026-03-07/la-antidoto-erase-una-vez-en-la-misteriosa-tierra-de-uz.html
#
# título:  El ataque a Irán aviva el riesgo de una crisis energética que impacte en la economía
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/economia/2026-03-07/el-ataque-a-iran-aviva-el-riesgo-de-una-crisis-energetica-que-impacte-en-la-economia.html
#
# título:  Bàrbara Mestanza, cineasta: “A quienes exigen a las mujeres que denuncien les digo: ‘Que les jodan”
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/cultura/cine/2026-03-07/barbara-mestanza-cineasta-a-quienes-exigen-a-las-mujeres-que-denuncien-les-digo-que-les-jodan.html
#
# título:  Matteo Renzi: “La antipatía hacia Trump no me impide querer liberar a las mujeres iraníes”
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/internacional/2026-03-07/matteo-renzi-la-antipatia-hacia-trump-no-me-impide-querer-liberar-a-las-mujeres-iranies.html
#
# título:  Una pasarela y el particular Ventorro de Santander
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/opinion/2026-03-07/una-pasarela-y-el-particular-ventorro-de-santander.html
#
# título:  Demolición en el Reina Sofía
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/babelia/2026-03-07/demolicion-en-el-reina-sofia.html
#
# título:  El “No a la Guerra” evoca la gran manifestación de Barcelona. ¿Podría repetirse ahora?
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/espana/catalunya/2026-03-07/el-no-a-la-guerra-evoca-la-gran-manifestacion-de-barcelona-podria-repetirse-ahora.html
#
# título:  Muertos vivientes, vivos murientes
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/babelia/2026-03-07/muertos-vivientes-vivos-murientes.html
#
# título:  Los ataques de Irán amenazan el sueño de modernización de los países árabes del Golfo
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/internacional/2026-03-07/los-ataques-de-iran-amenazan-el-sueno-de-modernizacion-de-los-paises-arabes-del-golfo.html
#
# título:  Las propuestas económicas de los candidatos a la presidencia del Barcelona: Spotify Camp Nou y desarrollo digital y comercial para aumentar los ingresos
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/deportes/futbol/2026-03-07/las-propuestas-economicas-de-los-candidatos-a-la-presidencia-del-barcelona-spotify-camp-nou-y-desarrollo-digital-y-comercial-para-aumentar-los-ingresos.html
#
# título:  Rebecca Hall: “Hemos perdido la contracultura en algún momento del camino”
# fecha: Sat, 07 Mar 2026 04:30:01 GMT
# enlace: https://elpais.com/smoda/famosos/2026-03-07/rebecca-hall-hemos-perdido-la-contracultura-en-algun-momento-del-camino.html

# %% [markdown]
# Enlaces documentación
#
# https://docs.python.org/3/library/xml.etree.elementtree.html
#
# https://rico-schmidt.name/pymotw-3/xml.etree.ElementTree/parse.html
